# %%
import gc
import numpy as np
import pandas as pd
import polars as pl
import tensorflow as tf
from pathlib import Path
from tensorflow import shape, minimum
from tensorflow.keras import backend as k
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import pad_sequences, Sequence, to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import (
    Dense, Input, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Concatenate,
    BatchNormalization, GRU, Dropout, add, Activation, Multiply, Reshape,
    LayerNormalization, Add, Bidirectional, LSTM, UpSampling1D, Lambda, GaussianNoise, MultiHeadAttention
)
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, accuracy_score

from src.nn_blocks import tof_block, residual_se_cnn_block, TransformerBlock, tof_block_2, features_processing, unet_se_cnn

NUM_CLASSES = 18


# --- Gated Model 1: Based on CNN-RNN Hybrid ---
def create_gated_cnn_rnn(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # IMU branch
    x1 = residual_se_cnn_block(imu, 64, 3, drop=0.2, wd=wd) # Output: (None, 64, 64)
    x1 = residual_se_cnn_block(x1, 128, 5, drop=0.2, wd=wd) # Output: (None, 32, 128)
    x1 = Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer=l2(wd)))(x1) # Output: (None, 32, 256)
    
    # Standard ToF branch
    x2 = tof_block_2(tof, wd) # Output: (None, 32, 128)

    # --- FIX: Project x2 to match x1's feature dimension before processing ---
    x2_projected = Dense(256, activation='relu')(x2)

    # Now both inputs to features_processing have shape (None, 32, 256)
    x = features_processing(x1, x2_projected)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Gated Model 2: Based on UNet_Style ---
def create_gated_unet(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # IMU branch
    x1 = unet_se_cnn(imu, unet_depth=4, base_filters=64, kernel_size=5, drop=0.3) # Output: (None, 128, 64)
    
    # Standard ToF branch
    x2 = tof_block_2(tof, wd) # Output: (None, 32, 128)

    # --- FIX: This architecture is fundamentally incompatible. We will use a simpler merge. ---
    # The U-Net doesn't downsample time, making it hard to merge.
    # We will use a simpler approach for this model.
    x1_pooled = GlobalAveragePooling1D()(x1)
    x2_pooled = GlobalAveragePooling1D()(x2)
    x = Concatenate()([x1_pooled, x2_pooled])
    
    x = Dropout(0.4)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Gated Model 3: Based on CNN_Transformer ---
def create_gated_cnn_transformer(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # IMU branch
    x1 = residual_se_cnn_block(imu, 64, 3, drop=0.2, wd=wd) # Output: (None, 64, 64)
    x1 = residual_se_cnn_block(x1, 128, 5, drop=0.2, wd=wd) # Output: (None, 32, 128)
    x1 = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=128, rate=0.3)(x1) # Output: (None, 32, 128)
    x1 = residual_se_cnn_block(x1, 64, 3, drop=0.2, wd=wd) # Output: (None, 16, 64)
    x1 = residual_se_cnn_block(x1, 128, 5, drop=0.2, wd=wd) # Output: (None, 8, 128)    
    x1 = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=128, rate=0.3)(x1) # Output: (None, 8, 128)
    
    # Standard ToF branch
    x2 = tof_block_2(tof, wd) # Output: (None, 32, 128)
    x2 = tf.keras.layers.MaxPooling1D(4)(x2)

    x = features_processing(x1, x2)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

def best_unet_1(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    x1 = unet_se_cnn(imu, 3, base_filters=128, kernel_size=3)
    x2 = tof_block(tof, wd)

    x = features_processing(x1, x2)
    x = tf.keras.layers.Dropout(0.3)(x) 
    main_out = tf.keras.layers.Dense(18, activation="softmax", name="main_output")(x)
    gate_out = tf.keras.layers.Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return tf.keras.models.Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

def best_unet_2(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    x1 = unet_se_cnn(imu, 3, base_filters=128, kernel_size=3)
    x2 = tof_block_2(tof, wd)

    x = features_processing(x1, x2)
    x = tf.keras.layers.Dropout(0.3)(x) 
    main_out = tf.keras.layers.Dense(18, activation="softmax", name="main_output")(x)
    gate_out = tf.keras.layers.Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return tf.keras.models.Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})
# Out:
# 2025-08-15 20:46:06.734002: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755287166.776980 2128177 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755287166.789545 2128177 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755287166.838058 2128177 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755287166.838085 2128177 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755287166.838087 2128177 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755287166.838089 2128177 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-15 20:46:06.852095: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import polars as pl

from pathlib import Path
from src.merge_feats_dynamic import merge_feature_sets
from src.functions import create_sequence_dataset, generate_gate_targets, train_model
from src.nn_blocks import GatedMixupGenerator

# =====================================================================================
# TRAINING LOGIC
# =====================================================================================

FEATURE_DIR = Path('output')
RAW_DIR = Path('input/cmi-detect-behavior-with-sensor-data')
RANDOM_STATE = 42

files_to_merge = [
    'imu_basic_physics_feats.parquet',
    'tof_basic_kaggle_feats.parquet'
]
feature_paths = [FEATURE_DIR / f for f in files_to_merge]
base_df = pl.read_parquet(FEATURE_DIR / "cleaned_base_train_data.parquet")
demographics_df = pl.read_csv(RAW_DIR / "train_demographics.csv")
base_df = base_df.join(demographics_df, on='subject', how='left')

meta_cols = ['sequence_id', 'sequence_counter', 'subject', 'gesture']
thm_cols = ['thm_1', 'thm_2', 'thm_3', 'thm_4', 'thm_5']
base_df = base_df.select(meta_cols + thm_cols)

final_df = merge_feature_sets(base_df, feature_paths)
print(f"  Final merged DataFrame created with shape: {final_df.shape}")
final_df.columns
# Out:
#  Starting merge process...
#   Loading and joining features from: imu_basic_physics_feats.parquet
#   Loading and joining features from: tof_basic_kaggle_feats.parquet
#   Merge complete.
#   Final merged DataFrame created with shape: (574945, 45)
# ['sequence_id',
#  'sequence_counter',
#  'subject',
#  'gesture',
#  'thm_1',
#  'thm_2',
#  'thm_3',
#  'thm_4',
#  'thm_5',
#  'acc_x',
#  'acc_y',
#  'acc_z',
#  'rot_w',
#  'rot_x',
#  'rot_y',
#  'rot_z',
#  'linear_acc_x',
#  'linear_acc_y',
#  'linear_acc_z',
#  'linear_acc_mag',
#  'linear_acc_mag_jerk',
#  'angular_vel_x',
#  'angular_vel_y',
#  'angular_vel_z',
#  'angular_distance',
#  'tof_1_mean',
#  'tof_1_std',
#  'tof_1_min',
#  'tof_1_max',
#  'tof_2_mean',
#  'tof_2_std',
#  'tof_2_min',
#  'tof_2_max',
#  'tof_3_mean',
#  'tof_3_std',
#  'tof_3_min',
#  'tof_3_max',
#  'tof_4_mean',
#  'tof_4_std',
#  'tof_4_min',
#  'tof_4_max',
#  'tof_5_mean',
#  'tof_5_std',
#  'tof_5_min',
#  'tof_5_max']

# %%
df = pl.read_parquet('output/kaggle_0.8_feats.parquet')
df.columns
# Out:
# ['sequence_id',
#  'subject',
#  'gesture',
#  'gesture_int',
#  'linear_acc_x',
#  'linear_acc_y',
#  'linear_acc_z',
#  'rot_w',
#  'rot_x',
#  'rot_y',
#  'rot_z',
#  'linear_acc_mag',
#  'linear_acc_mag_jerk',
#  'angular_vel_x',
#  'angular_vel_y',
#  'angular_vel_z',
#  'angular_distance',
#  'thm_1',
#  'thm_2',
#  'thm_3',
#  'thm_4',
#  'thm_5',
#  'tof_1_mean',
#  'tof_1_std',
#  'tof_1_min',
#  'tof_1_max',
#  'tof_2_mean',
#  'tof_2_std',
#  'tof_2_min',
#  'tof_2_max',
#  'tof_3_mean',
#  'tof_3_std',
#  'tof_3_min',
#  'tof_3_max',
#  'tof_4_mean',
#  'tof_4_std',
#  'tof_4_min',
#  'tof_4_max',
#  'tof_5_mean',
#  'tof_5_std',
#  'tof_5_min',
#  'tof_5_max']

# %%
# =====================================================================================
# 5 NEW ADVANCED MODEL ARCHITECTURES
# =====================================================================================

from src.nn_blocks import match_time_steps, wave_block, res_se_cnn_decoder_block

# --- Advanced Model 2: Stacked Transformer Tower ---
# Hypothesis: Stacking multiple Transformer layers after a strong CNN backbone will
# allow the model to learn very complex global relationships within the sequence.
def create_advanced_model_2_transformer_tower(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # Strong CNN backbone to create rich features for the Transformer
    x1 = residual_se_cnn_block(imu, 64, 3, drop=0.2, wd=wd)
    x1 = residual_se_cnn_block(x1, 128, 5, drop=0.2, wd=wd) # Output shape: (None, 32, 128)
    
    # Stacked Transformer Tower
    # Each block attends to the output of the previous one, building deeper context.
    x1 = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=256, rate=0.3)(x1)
    x1 = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=256, rate=0.3)(x1)
    x1 = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=256, rate=0.3)(x1)
    x1 = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=256, rate=0.3)(x1)
    
    # Standard ToF branch
    x2 = tof_block_2(tof, wd) # Output shape: (None, 32, 128)

    # Merge and classify
    x = features_processing(x1, x2)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Advanced Model 3: Hybrid UNet + WaveNet ---
def create_advanced_model_3_unet_wave(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # U-Net branch
    x1_unet = unet_se_cnn(imu, unet_depth=3, base_filters=64, kernel_size=5)
    
    # Parallel WaveNet branch
    x1_wave = wave_block(imu, 64, 3, n=5, dropout_rate=0.3) # n=5 -> dilations up to 16
    
    # Match time steps and concatenate
    x1_unet_matched, x1_wave_matched = match_time_steps(x1_unet, x1_wave)
    x1 = Concatenate()([x1_unet_matched, x1_wave_matched])
    
    # Standard ToF branch
    x2 = tof_block_2(tof, wd)

    # Merge and classify
    x = features_processing(x1, x2)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Advanced Model 4: Triple Stacked Block Design ---
# Hypothesis: Repeatedly applying a powerful hybrid block (CNN + RNN) will
# progressively refine the feature representation.
def cnn_gru_block(x, filters, kernel_size, wd=1e-4):
    # A self-contained block combining CNN and GRU
    x_cnn = residual_se_cnn_block(x, filters, kernel_size, wd=wd)
    x_gru = Bidirectional(GRU(filters // 2, return_sequences=True))(x_cnn)
    return x_gru

def cnn_gru_block(x, filters, kernel_size, wd=1e-4):
    """
    A simplified and robust block that first applies a CNN, then a GRU.
    """
    # 1. CNN part for feature extraction and downsampling
    x = residual_se_cnn_block(x, filters, kernel_size, wd=wd)
    
    # 2. GRU part for sequence processing
    x = Bidirectional(GRU(filters, return_sequences=True, kernel_regularizer=l2(wd)))(x)
    
    return x

def create_advanced_model_4_stacked_blocks(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # Apply the hybrid block three times
    x1 = cnn_gru_block(imu, 64, 3)  # Output: (None, 64, 128)
    x1 = cnn_gru_block(x1, 128, 5) # Output: (None, 32, 256)
    
    # The final block will not return sequences to simplify the final merge
    x1 = Bidirectional(GRU(128, return_sequences=False))(x1) # Output: (None, 256)
    
    # Standard ToF branch, but we need to aggregate it to match x1
    x2 = tof_block_2(tof, wd) # Output: (None, 32, 128)
    x2 = GlobalAveragePooling1D()(x2) # Output: (None, 128)

    # Merge the two aggregated feature vectors
    x = Concatenate()([x1, x2]) # Output: (None, 256 + 128) = (None, 384)
    
    # Final classifier MLP
    x = Dropout(0.4)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Advanced Model 5: UNet with BiLSTM Bottleneck ---
# Hypothesis: Adding sequential processing (BiLSTM) at the point of maximum feature
# compression in the U-Net (the bottleneck) will improve context understanding.
def unet_se_cnn_bilstm(x, unet_depth=3, base_filters=64, kernel_size=3, drop=0.3):
    filters = base_filters
    skips = []
    for _ in range(unet_depth):
        x = residual_se_cnn_block(x, filters, kernel_size, drop=drop)
        skips.append(x)
        filters *= 2
    
    # --- BiLSTM Bottleneck ---
    # Process the most compressed representation sequentially
    x = Bidirectional(LSTM(filters // 2, return_sequences=True))(x)
    
    for skip in reversed(skips):
        filters //= 2
        x = res_se_cnn_decoder_block(x, filters, kernel_size, drop=drop, skip_connection=skip)
    return x

def create_advanced_model_1_deep_unet(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # --- IMU Branches ---
    x1_unet = unet_se_cnn(imu, unet_depth=4, base_filters=128, kernel_size=5, drop=0.3)
    x1_conv_k3 = residual_se_cnn_block(imu, 64, 3)
    x1_conv_k7 = residual_se_cnn_block(imu, 64, 7)
    
    # --- FIX: Aggregate each branch BEFORE merging ---
    # This creates a fixed-size vector from each branch, avoiding shape conflicts.
    p1 = GlobalAveragePooling1D()(x1_unet)
    p2 = GlobalAveragePooling1D()(x1_conv_k3)
    p3 = GlobalAveragePooling1D()(x1_conv_k7)
    
    # --- ToF Branch ---
    x2 = tof_block_2(tof, wd)
    p4 = GlobalAveragePooling1D()(x2)

    # Concatenate the aggregated feature vectors
    x = Concatenate()([p1, p2, p3, p4])
    
    # --- Final Classifier MLP ---
    x = Dropout(0.4)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(256, activation='relu')(x)
    
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

def create_advanced_model_5_unet_bilstm(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # Use the UNet with the BiLSTM bottleneck
    x1 = unet_se_cnn_bilstm(imu, unet_depth=3, base_filters=128, kernel_size=3)
    
    # Standard ToF branch
    x2 = tof_block_2(tof, wd)

    # --- FIX: Use the robust aggregation strategy instead of features_processing ---
    x1_pooled = GlobalAveragePooling1D()(x1)
    x2_pooled = GlobalAveragePooling1D()(x2)
    x = Concatenate()([x1_pooled, x2_pooled])

    # --- Final Classifier MLP ---
    x = Dropout(0.4)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(256, activation='relu')(x)
    
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# %%
# =====================================================================================
# 3 NEW ADVANCED MODEL ARCHITECTURES
# =====================================================================================
from src.nn_blocks import attention_layer

def create_advanced_model_A_dual_unet(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # Branch 1: A deep U-Net for the IMU data
    x1_raw = unet_se_cnn(imu, unet_depth=4, base_filters=128, kernel_size=5, drop=0.3)
    
    # Branch 2: A parallel, slightly lighter U-Net for the ToF/Thermal data
    x2_raw = unet_se_cnn(tof, unet_depth=3, base_filters=64, kernel_size=5, drop=0.3)

    # --- FIX: Project both branches to a common feature dimension (e.g., 128) ---
    # This ensures the input to features_processing is consistent.
    x1 = Conv1D(128, 1, padding='same', activation='relu', name='imu_projection')(x1_raw)
    x2 = Conv1D(128, 1, padding='same', activation='relu', name='tof_projection')(x2_raw)
    
    # Now both x1 and x2 have shape (None, 128, 128)
    # They can be safely passed to the features_processing block.
    x = features_processing(x1, x2)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Advanced Model B: Cross-Attention Fusion ---
# Hypothesis: Instead of just concatenating the IMU and ToF branches, we can create
# richer features by allowing them to "talk to each other." The IMU branch will learn
# what to pay attention to in the ToF data, and vice-versa.
def create_advanced_model_B_cross_attention(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # 1. Create strong, downsampled feature representations for both branches
    # Output Shape for both: (None, 32, 128)
    x1 = residual_se_cnn_block(imu, 64, 3, drop=0.2, wd=wd)
    x1 = residual_se_cnn_block(x1, 128, 5, drop=0.2, wd=wd)
    
    x2 = tof_block_2(tof, wd)

    # 2. Cross-Attention Fusion
    # The IMU branch queries the ToF branch for relevant context
    imu_attends_tof = tf.keras.layers.Attention()([x1, x2])
    # The ToF branch queries the IMU branch for relevant context
    tof_attends_imu = tf.keras.layers.Attention()([x2, x1])
    
    # 3. Create an enriched representation by concatenating all perspectives
    # The final tensor contains the original features plus the context-aware features.
    # Shape: (None, 32, 128 + 128 + 128 + 128) = (None, 32, 512)
    x = Concatenate()([x1, imu_attends_tof, x2, tof_attends_imu])
    
    # 4. Final Processing
    # We use a powerful sequence processor on this ultra-rich tensor
    x = Bidirectional(GRU(256, return_sequences=True, kernel_regularizer=l2(wd)))(x)
    x = attention_layer(x)
    
    x = Dropout(0.4)(x)
    x = Dense(256, activation='relu')(x)
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Advanced Model C: Stacked Hybrid Blocks ---
# Hypothesis: A single block of (CNN -> RNN) is good. Repeatedly stacking this
# hybrid block will allow the model to learn progressively more abstract and

# powerful spatio-temporal features.
def cnn_lstm_block(x, filters, kernel_size, drop=0.2, wd=1e-4):
    # A self-contained, reusable block
    x = residual_se_cnn_block(x, filters, kernel_size, drop=drop, wd=wd)
    x = Bidirectional(LSTM(filters, return_sequences=True, kernel_regularizer=l2(wd)))(x)
    return x

def create_advanced_model_C_stacked_hybrid(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # --- IMU Branch: Stacked Hybrid Blocks ---
    # Each block refines the output of the previous one
    # Input: (128, D) -> Block1: (64, 128) -> Block2: (32, 256)
    x1 = cnn_lstm_block(imu, 64, 3)
    x1 = cnn_lstm_block(x1, 128, 5)
    
    # --- ToF Branch ---
    # Output: (32, 128)
    x2 = tof_block_2(tof, wd)
    # Project ToF features to match the final IMU feature dimension (256)
    x2_projected = Dense(256, activation='relu')(x2)

    # Now both inputs have shape (None, 32, 256) and can be processed
    x = features_processing(x1, x2_projected)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# %%
# =====================================================================================
# CONFIGURATION
# =====================================================================================
LR_INIT = 5e-4
WD = 3e-3
NUM_CLASSES = 18
BATCH_SIZE = 64
N_SPLITS = 4 
MAX_PAD_LEN = 128


from src.merge_feats_dynamic import merge_feature_sets
from src.functions import create_sequence_dataset, generate_gate_targets, train_model
from src.nn_blocks import GatedMixupGenerator

# =====================================================================================
# TRAINING LOGIC
# =====================================================================================

FEATURE_DIR = Path('output')
RAW_DIR = Path('input/cmi-detect-behavior-with-sensor-data')
RANDOM_STATE = 42

files_to_merge = [
    'imu_basic_physics_feats.parquet',
    'tof_basic_kaggle_feats.parquet'
]
feature_paths = [FEATURE_DIR / f for f in files_to_merge]
base_df = pl.read_parquet(FEATURE_DIR / "cleaned_base_train_data.parquet")
demographics_df = pl.read_csv(RAW_DIR / "train_demographics.csv")
base_df = base_df.join(demographics_df, on='subject', how='left')

meta_cols = ['sequence_id', 'sequence_counter', 'subject', 'gesture']
thm_cols = ['thm_1', 'thm_2', 'thm_3', 'thm_4', 'thm_5']
base_df = base_df.select(meta_cols + thm_cols)

le = LabelEncoder()
gesture_encoded = le.fit_transform(base_df.get_column('gesture'))
base_df = base_df.with_columns(pl.Series("gesture_int", gesture_encoded))  

final_df = merge_feature_sets(base_df, feature_paths)
print(f"  Final merged DataFrame created with shape: {final_df.shape}")

# --- Step 2: Define FINAL Feature Columns ---
all_final_columns = final_df.columns
final_meta_cols = {'gesture', 'gesture_int', 'subject', 'sequence_id', 'sequence_counter'}
demographic_cols = {'adult_child', 'age', 'sex', 'handedness', 'height_cm', 'shoulder_to_wrist_cm', 'elbow_to_wrist_cm'}
all_feature_cols = [c for c in all_final_columns if c not in final_meta_cols and c not in demographic_cols]

# Define IMU and ToF columns from the final feature list
imu_cols = [c for c in all_feature_cols if c.startswith(('acc_', 'rot_', 'linear_', 'angular_'))]
tof_cols = [c for c in all_feature_cols if c.startswith(('tof_', 'thm_'))]
imu_dim = len(imu_cols)
print(f"  Training with {len(all_feature_cols)} total features ({imu_dim} IMU, {len(tof_cols)} ToF/Thm).")    

# --- Step 3: Prepare for Cross-Validation ---
cv_info = final_df.group_by("sequence_id").agg(pl.first("gesture_int")).sort("sequence_id")
all_sequence_ids = cv_info.get_column("sequence_id").to_numpy()
y_for_split = cv_info.get_column("gesture_int").to_numpy()

input_shape = (MAX_PAD_LEN, len(all_feature_cols)) 

# --- Step 4: Define the Model Architectures to Test ---
# model_builders = [
#     # ("Advanced_Transformer_Tower", lambda: create_advanced_model_2_transformer_tower(input_shape, imu_dim)),
#     # ("Advanced_UNet_Wave", lambda: create_advanced_model_3_unet_wave(input_shape, imu_dim)),
#     # ("Advanced_Stacked_Blocks", lambda: create_advanced_model_4_stacked_blocks(input_shape, imu_dim)),
#     # ("Advanced_Deep_UNet", lambda: create_advanced_model_1_deep_unet(input_shape, imu_dim)),
#     # ("Advanced_UNet_BiLSTM", lambda: create_advanced_model_5_unet_bilstm(input_shape, imu_dim)),
#     ("gated_cnn_transformer_2_blocks", lambda: create_gated_cnn_transformer(input_shape, imu_dim))
    
# ]

model_builders = [
    # ("Advanced_Dual_UNet", lambda: create_advanced_model_A_dual_unet(input_shape, imu_dim)),
    ("Advanced_Cross_Attention", lambda: create_advanced_model_B_cross_attention(input_shape, imu_dim)),
    ("Advanced_Stacked_Hybrid", lambda: create_advanced_model_C_stacked_hybrid(input_shape, imu_dim)),
]

# --- Step 5: Loop Through Each Model Architecture ---
for model_name, model_builder in model_builders:
    print("\n" + "="*60)
    print(f"▶ Training and Evaluating Model: {model_name}")
    print("="*60)

    kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
    fold_accuracies = []
    all_preds = []
    all_labels = []

    for fold_idx, (train_indices, val_indices) in enumerate(kf.split(all_sequence_ids, y_for_split)):
        print(f"\n=== Fold {fold_idx + 1}/{N_SPLITS} for {model_name} ===")
        train_ids = all_sequence_ids[train_indices]
        val_ids = all_sequence_ids[val_indices]

        train_df = final_df.filter(pl.col('sequence_id').is_in(train_ids))
        val_df = final_df.filter(pl.col('sequence_id').is_in(val_ids))
        
        scaler = StandardScaler()
        train_features_scaled = scaler.fit_transform(train_df[all_feature_cols])
        val_features_scaled = scaler.transform(val_df[all_feature_cols])
        X_train_scaled_features = pl.DataFrame(train_features_scaled, schema=all_feature_cols)
        X_val_scaled_features = pl.DataFrame(val_features_scaled, schema=all_feature_cols)

        meta_cols_to_keep = ['sequence_id', 'sequence_counter', 'gesture_int']
        train_df_final = train_df.select(meta_cols_to_keep).with_columns(X_train_scaled_features)
        val_df_final = val_df.select(meta_cols_to_keep).with_columns(X_val_scaled_features)

        # Use the full create_sequence_dataset for gate targets
        X_train, y_train, train_gate_target = create_sequence_dataset(train_df_final, all_feature_cols, generate_gate_targets(train_df, tof_cols))
        X_val, y_val, val_gate_target = create_sequence_dataset(val_df_final, all_feature_cols, generate_gate_targets(val_df, tof_cols))

        X_train_padded = pad_sequences(X_train, maxlen=MAX_PAD_LEN, padding='post', truncating='post', dtype='float32')
        X_val_padded = pad_sequences(X_val, maxlen=MAX_PAD_LEN, padding='post', truncating='post', dtype='float32')
        
        y_train_cat = to_categorical(y_train, num_classes=NUM_CLASSES)
        y_val_cat = to_categorical(y_val, num_classes=NUM_CLASSES)
        
        # Use the GatedMixupGenerator for the two-branch models
        train_dataset = GatedMixupGenerator(
            X=X_train_padded, y=y_train_cat, gate_targets=train_gate_target,
            batch_size=BATCH_SIZE, imu_dim=imu_dim, alpha=0.2, masking_prob=0.25
        )
        val_dataset = tf.data.Dataset.from_tensor_slices((
            X_val_padded, {'main_output': y_val_cat, 'tof_gate': val_gate_target[:, np.newaxis]}
        )).batch(BATCH_SIZE).cache().prefetch(tf.data.AUTOTUNE)

        del X_train, y_train, X_val, y_val, X_train_padded, X_val_padded
        gc.collect()
        
        model = model_builder()
        
        # Use the original train_model function for multi-output models
        history = train_model(model, train_dataset, val_dataset, 150, LR_INIT, WD)
        
        val_preds = model.predict(val_dataset)
        main_output_preds = val_preds['main_output']
        
        y_pred_fold = np.argmax(main_output_preds, axis=1)
        y_true_fold = np.argmax(y_val_cat, axis=1)
        fold_acc = accuracy_score(y_true_fold, y_pred_fold)
        fold_accuracies.append(fold_acc)
        print(f"Fold {fold_idx + 1} Accuracy: {fold_acc:.4f}")
        all_preds.append(y_pred_fold)
        all_labels.append(y_true_fold)

        del train_dataset, model, val_dataset
        gc.collect()

    # --- FINAL OOF REPORT for this model architecture ---
    print(f"\n=== OOF Summary for {model_name} ===")
    print(f"Per-fold Accuracies: {[round(a, 4) for a in fold_accuracies]}")
    print(f"Mean Accuracy: {np.mean(fold_accuracies):.4f} ± {np.std(fold_accuracies):.4f}")
    y_all_pred = np.concatenate(all_preds)
    y_all_true = np.concatenate(all_labels)
    print("\n=== Overall Classification Report ===")
    print(classification_report(y_all_true, y_all_pred, target_names=le.classes_, digits=4))
# Out:
#  Starting merge process...
#   Loading and joining features from: imu_basic_physics_feats.parquet
#   Loading and joining features from: tof_basic_kaggle_feats.parquet
#   Merge complete.
#   Final merged DataFrame created with shape: (574945, 46)
#   Training with 41 total features (16 IMU, 25 ToF/Thm).
#
# ============================================================
# ▶ Training and Evaluating Model: Advanced_Cross_Attention
# ============================================================
#
# === Fold 1/4 for Advanced_Cross_Attention ===
# LR Scheduler: 96 steps per epoch, 14400 total decay steps.
# Epoch 1/150
# /home/uallende/projects/kaggle/CMI/.venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# I0000 00:00:1755287275.909473 2128368 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 27s 120ms/step - loss: 3.0076 - main_output_accuracy: 0.1456 - main_output_loss: 2.7659 - tof_gate_loss: 0.3349 - val_loss: 2.3775 - val_main_output_accuracy: 0.3445 - val_main_output_loss: 2.1937 - val_tof_gate_loss: 0.0718
# Epoch 2/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 91ms/step - loss: 2.5718 - main_output_accuracy: 0.2896 - main_output_loss: 2.3603 - tof_gate_loss: 0.2244 - val_loss: 2.0886 - val_main_output_accuracy: 0.4411 - val_main_output_loss: 1.9117 - val_tof_gate_loss: 0.0665
# Epoch 3/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - loss: 2.2848 - main_output_accuracy: 0.3811 - main_output_loss: 2.0969 - tof_gate_loss: 0.1339 - val_loss: 1.9252 - val_main_output_accuracy: 0.4863 - val_main_output_loss: 1.7620 - val_tof_gate_loss: 0.0311
# Epoch 4/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 92ms/step - loss: 2.1501 - main_output_accuracy: 0.4273 - main_output_loss: 1.9678 - tof_gate_loss: 0.1293 - val_loss: 1.8591 - val_main_output_accuracy: 0.5064 - val_main_output_loss: 1.6997 - val_tof_gate_loss: 0.0388
# Epoch 5/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 2.1723 - main_output_accuracy: 0.4538 - main_output_loss: 1.9879 - tof_gate_loss: 0.1711 - val_loss: 1.7851 - val_main_output_accuracy: 0.5201 - val_main_output_loss: 1.6286 - val_tof_gate_loss: 0.0453
# Epoch 6/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - loss: 2.0561 - main_output_accuracy: 0.4786 - main_output_loss: 1.8792 - tof_gate_loss: 0.1404 - val_loss: 1.7065 - val_main_output_accuracy: 0.5540 - val_main_output_loss: 1.5558 - val_tof_gate_loss: 0.0346
# Epoch 7/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 2.1356 - main_output_accuracy: 0.4925 - main_output_loss: 1.9520 - tof_gate_loss: 0.1956 - val_loss: 1.6810 - val_main_output_accuracy: 0.5697 - val_main_output_loss: 1.5358 - val_tof_gate_loss: 0.0242
# Epoch 8/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 109ms/step - loss: 2.0387 - main_output_accuracy: 0.5211 - main_output_loss: 1.8613 - tof_gate_loss: 0.1758 - val_loss: 1.6330 - val_main_output_accuracy: 0.5824 - val_main_output_loss: 1.4894 - val_tof_gate_loss: 0.0311
# Epoch 9/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - loss: 1.9853 - main_output_accuracy: 0.5335 - main_output_loss: 1.8126 - tof_gate_loss: 0.1780 - val_loss: 1.6140 - val_main_output_accuracy: 0.5927 - val_main_output_loss: 1.4749 - val_tof_gate_loss: 0.0194
# Epoch 10/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - loss: 1.8595 - main_output_accuracy: 0.5485 - main_output_loss: 1.7002 - tof_gate_loss: 0.1227 - val_loss: 1.5954 - val_main_output_accuracy: 0.5962 - val_main_output_loss: 1.4576 - val_tof_gate_loss: 0.0249
# Epoch 11/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.9357 - main_output_accuracy: 0.5586 - main_output_loss: 1.7669 - tof_gate_loss: 0.1748 - val_loss: 1.6239 - val_main_output_accuracy: 0.5898 - val_main_output_loss: 1.4901 - val_tof_gate_loss: 0.0139
# Epoch 12/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 1.9355 - main_output_accuracy: 0.5588 - main_output_loss: 1.7704 - tof_gate_loss: 0.1692 - val_loss: 1.5528 - val_main_output_accuracy: 0.5986 - val_main_output_loss: 1.4180 - val_tof_gate_loss: 0.0272
# Epoch 13/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.8957 - main_output_accuracy: 0.5687 - main_output_loss: 1.7305 - tof_gate_loss: 0.1785 - val_loss: 1.5508 - val_main_output_accuracy: 0.6133 - val_main_output_loss: 1.4186 - val_tof_gate_loss: 0.0232
# Epoch 14/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - loss: 1.8119 - main_output_accuracy: 0.6016 - main_output_loss: 1.6561 - tof_gate_loss: 0.1470 - val_loss: 1.5197 - val_main_output_accuracy: 0.6310 - val_main_output_loss: 1.3871 - val_tof_gate_loss: 0.0327
# Epoch 15/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - loss: 1.8327 - main_output_accuracy: 0.6002 - main_output_loss: 1.6743 - tof_gate_loss: 0.1600 - val_loss: 1.5335 - val_main_output_accuracy: 0.6183 - val_main_output_loss: 1.4054 - val_tof_gate_loss: 0.0180
# Epoch 16/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - loss: 1.7751 - main_output_accuracy: 0.6125 - main_output_loss: 1.6191 - tof_gate_loss: 0.1390 - val_loss: 1.5189 - val_main_output_accuracy: 0.6281 - val_main_output_loss: 1.3886 - val_tof_gate_loss: 0.0341
# Epoch 17/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - loss: 1.7845 - main_output_accuracy: 0.6239 - main_output_loss: 1.6391 - tof_gate_loss: 0.1553 - val_loss: 1.5054 - val_main_output_accuracy: 0.6369 - val_main_output_loss: 1.3795 - val_tof_gate_loss: 0.0179
# Epoch 18/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.6582 - main_output_accuracy: 0.6507 - main_output_loss: 1.5133 - tof_gate_loss: 0.1081 - val_loss: 1.4700 - val_main_output_accuracy: 0.6521 - val_main_output_loss: 1.3430 - val_tof_gate_loss: 0.0283
# Epoch 19/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.7517 - main_output_accuracy: 0.6289 - main_output_loss: 1.6051 - tof_gate_loss: 0.1440 - val_loss: 1.4746 - val_main_output_accuracy: 0.6492 - val_main_output_loss: 1.3493 - val_tof_gate_loss: 0.0206
# Epoch 20/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - loss: 1.6488 - main_output_accuracy: 0.6544 - main_output_loss: 1.5033 - tof_gate_loss: 0.1292 - val_loss: 1.4725 - val_main_output_accuracy: 0.6492 - val_main_output_loss: 1.3391 - val_tof_gate_loss: 0.0680
# Epoch 21/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 11s 114ms/step - loss: 1.7969 - main_output_accuracy: 0.6159 - main_output_loss: 1.6422 - tof_gate_loss: 0.1733 - val_loss: 1.4663 - val_main_output_accuracy: 0.6487 - val_main_output_loss: 1.3432 - val_tof_gate_loss: 0.0193
# Epoch 22/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 11s 110ms/step - loss: 1.6926 - main_output_accuracy: 0.6617 - main_output_loss: 1.5448 - tof_gate_loss: 0.1478 - val_loss: 1.4446 - val_main_output_accuracy: 0.6595 - val_main_output_loss: 1.3206 - val_tof_gate_loss: 0.0259
# Epoch 23/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 12s 123ms/step - loss: 1.5876 - main_output_accuracy: 0.6854 - main_output_loss: 1.4453 - tof_gate_loss: 0.1165 - val_loss: 1.4422 - val_main_output_accuracy: 0.6595 - val_main_output_loss: 1.3180 - val_tof_gate_loss: 0.0296
# Epoch 24/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 11s 111ms/step - loss: 1.6260 - main_output_accuracy: 0.6825 - main_output_loss: 1.4831 - tof_gate_loss: 0.1220 - val_loss: 1.4425 - val_main_output_accuracy: 0.6516 - val_main_output_loss: 1.3228 - val_tof_gate_loss: 0.0113
# Epoch 25/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - loss: 1.5849 - main_output_accuracy: 0.6803 - main_output_loss: 1.4416 - tof_gate_loss: 0.1170 - val_loss: 1.4429 - val_main_output_accuracy: 0.6590 - val_main_output_loss: 1.3201 - val_tof_gate_loss: 0.0279
# Epoch 26/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 11s 110ms/step - loss: 1.6799 - main_output_accuracy: 0.6830 - main_output_loss: 1.5237 - tof_gate_loss: 0.1730 - val_loss: 1.4268 - val_main_output_accuracy: 0.6605 - val_main_output_loss: 1.3058 - val_tof_gate_loss: 0.0221
# Epoch 27/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - loss: 1.6897 - main_output_accuracy: 0.6878 - main_output_loss: 1.5450 - tof_gate_loss: 0.1614 - val_loss: 1.4085 - val_main_output_accuracy: 0.6840 - val_main_output_loss: 1.2867 - val_tof_gate_loss: 0.0271
# Epoch 28/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - loss: 1.5574 - main_output_accuracy: 0.7019 - main_output_loss: 1.4209 - tof_gate_loss: 0.1094 - val_loss: 1.4425 - val_main_output_accuracy: 0.6629 - val_main_output_loss: 1.3248 - val_tof_gate_loss: 0.0106
# Epoch 29/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - loss: 1.6618 - main_output_accuracy: 0.6949 - main_output_loss: 1.5128 - tof_gate_loss: 0.1764 - val_loss: 1.3964 - val_main_output_accuracy: 0.6850 - val_main_output_loss: 1.2741 - val_tof_gate_loss: 0.0341
# Epoch 30/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.6155 - main_output_accuracy: 0.6952 - main_output_loss: 1.4707 - tof_gate_loss: 0.1634 - val_loss: 1.3925 - val_main_output_accuracy: 0.6835 - val_main_output_loss: 1.2745 - val_tof_gate_loss: 0.0161
# Epoch 31/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.6166 - main_output_accuracy: 0.7107 - main_output_loss: 1.4744 - tof_gate_loss: 0.1459 - val_loss: 1.3949 - val_main_output_accuracy: 0.6762 - val_main_output_loss: 1.2744 - val_tof_gate_loss: 0.0287
# Epoch 32/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - loss: 1.6339 - main_output_accuracy: 0.7028 - main_output_loss: 1.4833 - tof_gate_loss: 0.1776 - val_loss: 1.4109 - val_main_output_accuracy: 0.6762 - val_main_output_loss: 1.2924 - val_tof_gate_loss: 0.0223
# Epoch 33/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.5875 - main_output_accuracy: 0.7170 - main_output_loss: 1.4423 - tof_gate_loss: 0.1483 - val_loss: 1.4058 - val_main_output_accuracy: 0.6717 - val_main_output_loss: 1.2864 - val_tof_gate_loss: 0.0278
# Epoch 34/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - loss: 1.5672 - main_output_accuracy: 0.7141 - main_output_loss: 1.4244 - tof_gate_loss: 0.1423 - val_loss: 1.4316 - val_main_output_accuracy: 0.6712 - val_main_output_loss: 1.3140 - val_tof_gate_loss: 0.0179
# Epoch 35/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 108ms/step - loss: 1.6867 - main_output_accuracy: 0.7002 - main_output_loss: 1.5336 - tof_gate_loss: 0.1841 - val_loss: 1.4024 - val_main_output_accuracy: 0.6806 - val_main_output_loss: 1.2849 - val_tof_gate_loss: 0.0194
# Epoch 36/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.5595 - main_output_accuracy: 0.7188 - main_output_loss: 1.4169 - tof_gate_loss: 0.1415 - val_loss: 1.4150 - val_main_output_accuracy: 0.6717 - val_main_output_loss: 1.2985 - val_tof_gate_loss: 0.0179
# Epoch 37/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - loss: 1.6168 - main_output_accuracy: 0.7249 - main_output_loss: 1.4673 - tof_gate_loss: 0.1764 - val_loss: 1.4049 - val_main_output_accuracy: 0.6850 - val_main_output_loss: 1.2872 - val_tof_gate_loss: 0.0221
# Epoch 38/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.4961 - main_output_accuracy: 0.7413 - main_output_loss: 1.3565 - tof_gate_loss: 0.1298 - val_loss: 1.4128 - val_main_output_accuracy: 0.6752 - val_main_output_loss: 1.2962 - val_tof_gate_loss: 0.0182
# Epoch 39/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.5189 - main_output_accuracy: 0.7388 - main_output_loss: 1.3750 - tof_gate_loss: 0.1457 - val_loss: 1.4211 - val_main_output_accuracy: 0.6806 - val_main_output_loss: 1.3016 - val_tof_gate_loss: 0.0309
# Epoch 40/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 1.4581 - main_output_accuracy: 0.7647 - main_output_loss: 1.3176 - tof_gate_loss: 0.1293 - val_loss: 1.4216 - val_main_output_accuracy: 0.6781 - val_main_output_loss: 1.3036 - val_tof_gate_loss: 0.0283
# Epoch 41/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.4221 - main_output_accuracy: 0.7707 - main_output_loss: 1.2853 - tof_gate_loss: 0.1198 - val_loss: 1.4013 - val_main_output_accuracy: 0.6791 - val_main_output_loss: 1.2857 - val_tof_gate_loss: 0.0170
# Epoch 42/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - loss: 1.3841 - main_output_accuracy: 0.7937 - main_output_loss: 1.2598 - tof_gate_loss: 0.1157 - val_loss: 1.4131 - val_main_output_accuracy: 0.6747 - val_main_output_loss: 1.2977 - val_tof_gate_loss: 0.0168
# Epoch 43/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 1.4504 - main_output_accuracy: 0.7701 - main_output_loss: 1.3116 - tof_gate_loss: 0.1318 - val_loss: 1.4033 - val_main_output_accuracy: 0.6884 - val_main_output_loss: 1.2884 - val_tof_gate_loss: 0.0159
# Epoch 44/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.5641 - main_output_accuracy: 0.7483 - main_output_loss: 1.4274 - tof_gate_loss: 0.1669 - val_loss: 1.3689 - val_main_output_accuracy: 0.6997 - val_main_output_loss: 1.2516 - val_tof_gate_loss: 0.0283
# Epoch 45/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.5313 - main_output_accuracy: 0.7547 - main_output_loss: 1.3860 - tof_gate_loss: 0.1602 - val_loss: 1.4269 - val_main_output_accuracy: 0.6874 - val_main_output_loss: 1.3115 - val_tof_gate_loss: 0.0203
# Epoch 46/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - loss: 1.5093 - main_output_accuracy: 0.7642 - main_output_loss: 1.3667 - tof_gate_loss: 0.1519 - val_loss: 1.4103 - val_main_output_accuracy: 0.6909 - val_main_output_loss: 1.2953 - val_tof_gate_loss: 0.0185
# Epoch 47/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 1.4339 - main_output_accuracy: 0.7875 - main_output_loss: 1.2936 - tof_gate_loss: 0.1344 - val_loss: 1.3771 - val_main_output_accuracy: 0.7105 - val_main_output_loss: 1.2610 - val_tof_gate_loss: 0.0223
# Epoch 48/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.5741 - main_output_accuracy: 0.7476 - main_output_loss: 1.4282 - tof_gate_loss: 0.1732 - val_loss: 1.4042 - val_main_output_accuracy: 0.6919 - val_main_output_loss: 1.2890 - val_tof_gate_loss: 0.0218
# Epoch 49/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - loss: 1.4301 - main_output_accuracy: 0.7862 - main_output_loss: 1.3002 - tof_gate_loss: 0.1281 - val_loss: 1.3969 - val_main_output_accuracy: 0.6997 - val_main_output_loss: 1.2832 - val_tof_gate_loss: 0.0123
# Epoch 50/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.5094 - main_output_accuracy: 0.7711 - main_output_loss: 1.3707 - tof_gate_loss: 0.1702 - val_loss: 1.4062 - val_main_output_accuracy: 0.6894 - val_main_output_loss: 1.2922 - val_tof_gate_loss: 0.0165
# Epoch 51/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 95ms/step - loss: 1.3863 - main_output_accuracy: 0.8164 - main_output_loss: 1.2488 - tof_gate_loss: 0.1294 - val_loss: 1.4000 - val_main_output_accuracy: 0.6923 - val_main_output_loss: 1.2854 - val_tof_gate_loss: 0.0173
# Epoch 52/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.4139 - main_output_accuracy: 0.7943 - main_output_loss: 1.2810 - tof_gate_loss: 0.1476 - val_loss: 1.4548 - val_main_output_accuracy: 0.6776 - val_main_output_loss: 1.3371 - val_tof_gate_loss: 0.0370
# Epoch 53/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.4201 - main_output_accuracy: 0.7934 - main_output_loss: 1.2806 - tof_gate_loss: 0.1399 - val_loss: 1.4113 - val_main_output_accuracy: 0.7022 - val_main_output_loss: 1.2971 - val_tof_gate_loss: 0.0175
# Epoch 54/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - loss: 1.3947 - main_output_accuracy: 0.8204 - main_output_loss: 1.2603 - tof_gate_loss: 0.1363 - val_loss: 1.4197 - val_main_output_accuracy: 0.6958 - val_main_output_loss: 1.3043 - val_tof_gate_loss: 0.0234
# Epoch 55/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 1.3304 - main_output_accuracy: 0.8167 - main_output_loss: 1.1984 - tof_gate_loss: 0.1127 - val_loss: 1.3961 - val_main_output_accuracy: 0.7012 - val_main_output_loss: 1.2829 - val_tof_gate_loss: 0.0156
# Epoch 56/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.4720 - main_output_accuracy: 0.7963 - main_output_loss: 1.3266 - tof_gate_loss: 0.1637 - val_loss: 1.3922 - val_main_output_accuracy: 0.7095 - val_main_output_loss: 1.2789 - val_tof_gate_loss: 0.0186
# Epoch 57/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.4429 - main_output_accuracy: 0.7966 - main_output_loss: 1.3028 - tof_gate_loss: 0.1433 - val_loss: 1.4091 - val_main_output_accuracy: 0.6958 - val_main_output_loss: 1.2952 - val_tof_gate_loss: 0.0211
# Epoch 58/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.4452 - main_output_accuracy: 0.7909 - main_output_loss: 1.3059 - tof_gate_loss: 0.1523 - val_loss: 1.4140 - val_main_output_accuracy: 0.7100 - val_main_output_loss: 1.3007 - val_tof_gate_loss: 0.0170
# Epoch 59/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - loss: 1.2881 - main_output_accuracy: 0.8372 - main_output_loss: 1.1556 - tof_gate_loss: 0.1068 - val_loss: 1.4134 - val_main_output_accuracy: 0.7002 - val_main_output_loss: 1.3009 - val_tof_gate_loss: 0.0133
# Epoch 60/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.4788 - main_output_accuracy: 0.8074 - main_output_loss: 1.3310 - tof_gate_loss: 0.1689 - val_loss: 1.4248 - val_main_output_accuracy: 0.6953 - val_main_output_loss: 1.3116 - val_tof_gate_loss: 0.0195
# Epoch 61/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.2159 - main_output_accuracy: 0.8524 - main_output_loss: 1.0913 - tof_gate_loss: 0.0908 - val_loss: 1.4128 - val_main_output_accuracy: 0.7026 - val_main_output_loss: 1.2987 - val_tof_gate_loss: 0.0206
# Epoch 62/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.4600 - main_output_accuracy: 0.8095 - main_output_loss: 1.3185 - tof_gate_loss: 0.1588 - val_loss: 1.4314 - val_main_output_accuracy: 0.6948 - val_main_output_loss: 1.3194 - val_tof_gate_loss: 0.0142
# Epoch 63/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 1.3536 - main_output_accuracy: 0.8292 - main_output_loss: 1.2149 - tof_gate_loss: 0.1340 - val_loss: 1.4107 - val_main_output_accuracy: 0.6987 - val_main_output_loss: 1.2985 - val_tof_gate_loss: 0.0153
# Epoch 64/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 1.3677 - main_output_accuracy: 0.8414 - main_output_loss: 1.2289 - tof_gate_loss: 0.1299 - val_loss: 1.4188 - val_main_output_accuracy: 0.6973 - val_main_output_loss: 1.3063 - val_tof_gate_loss: 0.0187
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# Fold 1 Accuracy: 0.6997
#
# === Fold 2/4 for Advanced_Cross_Attention ===
# LR Scheduler: 96 steps per epoch, 14400 total decay steps.
# Epoch 1/150
# /home/uallende/projects/kaggle/CMI/.venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 21s 114ms/step - loss: 3.0609 - main_output_accuracy: 0.1277 - main_output_loss: 2.8101 - tof_gate_loss: 0.3772 - val_loss: 2.3897 - val_main_output_accuracy: 0.3204 - val_main_output_loss: 2.2016 - val_tof_gate_loss: 0.0951
# Epoch 2/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 95ms/step - loss: 2.5160 - main_output_accuracy: 0.2808 - main_output_loss: 2.3155 - tof_gate_loss: 0.1600 - val_loss: 2.1634 - val_main_output_accuracy: 0.3891 - val_main_output_loss: 1.9916 - val_tof_gate_loss: 0.0481
# Epoch 3/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 2.3171 - main_output_accuracy: 0.3806 - main_output_loss: 2.1289 - tof_gate_loss: 0.1525 - val_loss: 1.9754 - val_main_output_accuracy: 0.4760 - val_main_output_loss: 1.8120 - val_tof_gate_loss: 0.0339
# Epoch 4/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - loss: 2.2175 - main_output_accuracy: 0.4233 - main_output_loss: 2.0323 - tof_gate_loss: 0.1482 - val_loss: 1.9146 - val_main_output_accuracy: 0.4892 - val_main_output_loss: 1.7581 - val_tof_gate_loss: 0.0230
# Epoch 5/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 2.2088 - main_output_accuracy: 0.4412 - main_output_loss: 2.0190 - tof_gate_loss: 0.1875 - val_loss: 1.8089 - val_main_output_accuracy: 0.5260 - val_main_output_loss: 1.6537 - val_tof_gate_loss: 0.0352
# Epoch 6/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 109ms/step - loss: 2.0612 - main_output_accuracy: 0.4928 - main_output_loss: 1.8822 - tof_gate_loss: 0.1549 - val_loss: 1.8034 - val_main_output_accuracy: 0.5285 - val_main_output_loss: 1.6525 - val_tof_gate_loss: 0.0338
# Epoch 7/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 1.9992 - main_output_accuracy: 0.5201 - main_output_loss: 1.8273 - tof_gate_loss: 0.1437 - val_loss: 1.7400 - val_main_output_accuracy: 0.5402 - val_main_output_loss: 1.5927 - val_tof_gate_loss: 0.0282
# Epoch 8/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 107ms/step - loss: 2.0819 - main_output_accuracy: 0.4899 - main_output_loss: 1.9018 - tof_gate_loss: 0.1971 - val_loss: 1.6994 - val_main_output_accuracy: 0.5721 - val_main_output_loss: 1.5512 - val_tof_gate_loss: 0.0477
# Epoch 9/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 2.0385 - main_output_accuracy: 0.5165 - main_output_loss: 1.8637 - tof_gate_loss: 0.1702 - val_loss: 1.6601 - val_main_output_accuracy: 0.5854 - val_main_output_loss: 1.5173 - val_tof_gate_loss: 0.0334
# Epoch 10/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - loss: 1.9225 - main_output_accuracy: 0.5476 - main_output_loss: 1.7573 - tof_gate_loss: 0.1491 - val_loss: 1.6394 - val_main_output_accuracy: 0.5888 - val_main_output_loss: 1.5007 - val_tof_gate_loss: 0.0242
# Epoch 11/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.9931 - main_output_accuracy: 0.5460 - main_output_loss: 1.8185 - tof_gate_loss: 0.1910 - val_loss: 1.6250 - val_main_output_accuracy: 0.5795 - val_main_output_loss: 1.4863 - val_tof_gate_loss: 0.0320
# Epoch 12/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 1.8724 - main_output_accuracy: 0.5759 - main_output_loss: 1.7124 - tof_gate_loss: 0.1489 - val_loss: 1.6214 - val_main_output_accuracy: 0.5942 - val_main_output_loss: 1.4820 - val_tof_gate_loss: 0.0471
# Epoch 13/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.8141 - main_output_accuracy: 0.5876 - main_output_loss: 1.6584 - tof_gate_loss: 0.1288 - val_loss: 1.6178 - val_main_output_accuracy: 0.5834 - val_main_output_loss: 1.4812 - val_tof_gate_loss: 0.0402
# Epoch 14/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - loss: 1.9371 - main_output_accuracy: 0.5713 - main_output_loss: 1.7677 - tof_gate_loss: 0.2077 - val_loss: 1.5720 - val_main_output_accuracy: 0.6266 - val_main_output_loss: 1.4310 - val_tof_gate_loss: 0.0676
# Epoch 15/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 1.7530 - main_output_accuracy: 0.6005 - main_output_loss: 1.6017 - tof_gate_loss: 0.1235 - val_loss: 1.5718 - val_main_output_accuracy: 0.6055 - val_main_output_loss: 1.4399 - val_tof_gate_loss: 0.0287
# Epoch 16/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.7748 - main_output_accuracy: 0.6243 - main_output_loss: 1.6210 - tof_gate_loss: 0.1396 - val_loss: 1.5598 - val_main_output_accuracy: 0.6133 - val_main_output_loss: 1.4291 - val_tof_gate_loss: 0.0285
# Epoch 17/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.7054 - main_output_accuracy: 0.6344 - main_output_loss: 1.5585 - tof_gate_loss: 0.1189 - val_loss: 1.5359 - val_main_output_accuracy: 0.6315 - val_main_output_loss: 1.4078 - val_tof_gate_loss: 0.0201
# Epoch 18/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 1.7925 - main_output_accuracy: 0.6129 - main_output_loss: 1.6344 - tof_gate_loss: 0.1593 - val_loss: 1.5246 - val_main_output_accuracy: 0.6276 - val_main_output_loss: 1.3925 - val_tof_gate_loss: 0.0421
# Epoch 19/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - loss: 1.7744 - main_output_accuracy: 0.6185 - main_output_loss: 1.6280 - tof_gate_loss: 0.1662 - val_loss: 1.5426 - val_main_output_accuracy: 0.6246 - val_main_output_loss: 1.4168 - val_tof_gate_loss: 0.0182
# Epoch 20/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 1.6839 - main_output_accuracy: 0.6558 - main_output_loss: 1.5377 - tof_gate_loss: 0.1194 - val_loss: 1.5308 - val_main_output_accuracy: 0.6271 - val_main_output_loss: 1.3971 - val_tof_gate_loss: 0.0597
# Epoch 21/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 1.6664 - main_output_accuracy: 0.6609 - main_output_loss: 1.5203 - tof_gate_loss: 0.1293 - val_loss: 1.4807 - val_main_output_accuracy: 0.6634 - val_main_output_loss: 1.3497 - val_tof_gate_loss: 0.0495
# Epoch 22/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.7471 - main_output_accuracy: 0.6379 - main_output_loss: 1.5915 - tof_gate_loss: 0.1765 - val_loss: 1.5245 - val_main_output_accuracy: 0.6315 - val_main_output_loss: 1.3966 - val_tof_gate_loss: 0.0408
# Epoch 23/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - loss: 1.7156 - main_output_accuracy: 0.6527 - main_output_loss: 1.5646 - tof_gate_loss: 0.1551 - val_loss: 1.4916 - val_main_output_accuracy: 0.6467 - val_main_output_loss: 1.3667 - val_tof_gate_loss: 0.0258
# Epoch 24/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.7378 - main_output_accuracy: 0.6505 - main_output_loss: 1.5827 - tof_gate_loss: 0.1805 - val_loss: 1.4867 - val_main_output_accuracy: 0.6511 - val_main_output_loss: 1.3616 - val_tof_gate_loss: 0.0311
# Epoch 25/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - loss: 1.7012 - main_output_accuracy: 0.6587 - main_output_loss: 1.5448 - tof_gate_loss: 0.1628 - val_loss: 1.4917 - val_main_output_accuracy: 0.6501 - val_main_output_loss: 1.3676 - val_tof_gate_loss: 0.0278
# Epoch 26/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.6233 - main_output_accuracy: 0.6866 - main_output_loss: 1.4781 - tof_gate_loss: 0.1339 - val_loss: 1.4935 - val_main_output_accuracy: 0.6516 - val_main_output_loss: 1.3694 - val_tof_gate_loss: 0.0293
# Epoch 27/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.6241 - main_output_accuracy: 0.7004 - main_output_loss: 1.4758 - tof_gate_loss: 0.1467 - val_loss: 1.4742 - val_main_output_accuracy: 0.6570 - val_main_output_loss: 1.3488 - val_tof_gate_loss: 0.0375
# Epoch 28/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - loss: 1.6738 - main_output_accuracy: 0.6816 - main_output_loss: 1.5215 - tof_gate_loss: 0.1641 - val_loss: 1.4608 - val_main_output_accuracy: 0.6639 - val_main_output_loss: 1.3400 - val_tof_gate_loss: 0.0162
# Epoch 29/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - loss: 1.6035 - main_output_accuracy: 0.6899 - main_output_loss: 1.4602 - tof_gate_loss: 0.1407 - val_loss: 1.4389 - val_main_output_accuracy: 0.6708 - val_main_output_loss: 1.3180 - val_tof_gate_loss: 0.0174
# Epoch 30/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.7051 - main_output_accuracy: 0.6787 - main_output_loss: 1.5540 - tof_gate_loss: 0.1726 - val_loss: 1.4307 - val_main_output_accuracy: 0.6752 - val_main_output_loss: 1.3075 - val_tof_gate_loss: 0.0327
# Epoch 31/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.6270 - main_output_accuracy: 0.7017 - main_output_loss: 1.4799 - tof_gate_loss: 0.1531 - val_loss: 1.4618 - val_main_output_accuracy: 0.6570 - val_main_output_loss: 1.3415 - val_tof_gate_loss: 0.0165
# Epoch 32/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.6679 - main_output_accuracy: 0.6980 - main_output_loss: 1.5193 - tof_gate_loss: 0.1639 - val_loss: 1.4857 - val_main_output_accuracy: 0.6492 - val_main_output_loss: 1.3631 - val_tof_gate_loss: 0.0332
# Epoch 33/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - loss: 1.6103 - main_output_accuracy: 0.7126 - main_output_loss: 1.4651 - tof_gate_loss: 0.1450 - val_loss: 1.4726 - val_main_output_accuracy: 0.6639 - val_main_output_loss: 1.3512 - val_tof_gate_loss: 0.0265
# Epoch 34/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.4274 - main_output_accuracy: 0.7452 - main_output_loss: 1.2945 - tof_gate_loss: 0.0882 - val_loss: 1.4183 - val_main_output_accuracy: 0.6816 - val_main_output_loss: 1.2962 - val_tof_gate_loss: 0.0316
# Epoch 35/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.6148 - main_output_accuracy: 0.7063 - main_output_loss: 1.4627 - tof_gate_loss: 0.1600 - val_loss: 1.4347 - val_main_output_accuracy: 0.6835 - val_main_output_loss: 1.3151 - val_tof_gate_loss: 0.0210
# Epoch 36/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - loss: 1.5385 - main_output_accuracy: 0.7303 - main_output_loss: 1.3950 - tof_gate_loss: 0.1428 - val_loss: 1.4222 - val_main_output_accuracy: 0.6801 - val_main_output_loss: 1.2991 - val_tof_gate_loss: 0.0379
# Epoch 37/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.5797 - main_output_accuracy: 0.7254 - main_output_loss: 1.4354 - tof_gate_loss: 0.1494 - val_loss: 1.4282 - val_main_output_accuracy: 0.6752 - val_main_output_loss: 1.3069 - val_tof_gate_loss: 0.0301
# Epoch 38/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.3981 - main_output_accuracy: 0.7718 - main_output_loss: 1.2641 - tof_gate_loss: 0.0955 - val_loss: 1.4356 - val_main_output_accuracy: 0.6860 - val_main_output_loss: 1.3160 - val_tof_gate_loss: 0.0244
# Epoch 39/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.5383 - main_output_accuracy: 0.7264 - main_output_loss: 1.3937 - tof_gate_loss: 0.1433 - val_loss: 1.4534 - val_main_output_accuracy: 0.6712 - val_main_output_loss: 1.3359 - val_tof_gate_loss: 0.0137
# Epoch 40/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 1.5665 - main_output_accuracy: 0.7499 - main_output_loss: 1.4208 - tof_gate_loss: 0.1554 - val_loss: 1.4073 - val_main_output_accuracy: 0.6953 - val_main_output_loss: 1.2892 - val_tof_gate_loss: 0.0164
# Epoch 41/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - loss: 1.5818 - main_output_accuracy: 0.7311 - main_output_loss: 1.4357 - tof_gate_loss: 0.1612 - val_loss: 1.4518 - val_main_output_accuracy: 0.6825 - val_main_output_loss: 1.3320 - val_tof_gate_loss: 0.0253
# Epoch 42/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - loss: 1.4725 - main_output_accuracy: 0.7637 - main_output_loss: 1.3307 - tof_gate_loss: 0.1348 - val_loss: 1.4159 - val_main_output_accuracy: 0.6820 - val_main_output_loss: 1.2946 - val_tof_gate_loss: 0.0341
# Epoch 43/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 107ms/step - loss: 1.4531 - main_output_accuracy: 0.7653 - main_output_loss: 1.3156 - tof_gate_loss: 0.1197 - val_loss: 1.4251 - val_main_output_accuracy: 0.6889 - val_main_output_loss: 1.3079 - val_tof_gate_loss: 0.0145
# Epoch 44/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 1.4442 - main_output_accuracy: 0.7743 - main_output_loss: 1.3047 - tof_gate_loss: 0.1309 - val_loss: 1.4027 - val_main_output_accuracy: 0.6933 - val_main_output_loss: 1.2816 - val_tof_gate_loss: 0.0328
# Epoch 45/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.4182 - main_output_accuracy: 0.7795 - main_output_loss: 1.2812 - tof_gate_loss: 0.1287 - val_loss: 1.4110 - val_main_output_accuracy: 0.6928 - val_main_output_loss: 1.2936 - val_tof_gate_loss: 0.0153
# Epoch 46/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.4981 - main_output_accuracy: 0.7472 - main_output_loss: 1.3706 - tof_gate_loss: 0.1615 - val_loss: 1.4174 - val_main_output_accuracy: 0.6865 - val_main_output_loss: 1.2988 - val_tof_gate_loss: 0.0244
# Epoch 47/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.3958 - main_output_accuracy: 0.7748 - main_output_loss: 1.2600 - tof_gate_loss: 0.1100 - val_loss: 1.3964 - val_main_output_accuracy: 0.7066 - val_main_output_loss: 1.2786 - val_tof_gate_loss: 0.0194
# Epoch 48/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.3962 - main_output_accuracy: 0.8004 - main_output_loss: 1.2610 - tof_gate_loss: 0.1216 - val_loss: 1.3880 - val_main_output_accuracy: 0.6923 - val_main_output_loss: 1.2701 - val_tof_gate_loss: 0.0223
# Epoch 49/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.4530 - main_output_accuracy: 0.7717 - main_output_loss: 1.3133 - tof_gate_loss: 0.1393 - val_loss: 1.4426 - val_main_output_accuracy: 0.6850 - val_main_output_loss: 1.3247 - val_tof_gate_loss: 0.0213
# Epoch 50/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.3879 - main_output_accuracy: 0.8016 - main_output_loss: 1.2496 - tof_gate_loss: 0.1275 - val_loss: 1.3902 - val_main_output_accuracy: 0.6963 - val_main_output_loss: 1.2733 - val_tof_gate_loss: 0.0172
# Epoch 51/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 109ms/step - loss: 1.4180 - main_output_accuracy: 0.7917 - main_output_loss: 1.2763 - tof_gate_loss: 0.1375 - val_loss: 1.3973 - val_main_output_accuracy: 0.6997 - val_main_output_loss: 1.2816 - val_tof_gate_loss: 0.0146
# Epoch 52/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 108ms/step - loss: 1.5169 - main_output_accuracy: 0.7627 - main_output_loss: 1.3714 - tof_gate_loss: 0.1508 - val_loss: 1.4253 - val_main_output_accuracy: 0.6776 - val_main_output_loss: 1.3075 - val_tof_gate_loss: 0.0244
# Epoch 53/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - loss: 1.3363 - main_output_accuracy: 0.8086 - main_output_loss: 1.1984 - tof_gate_loss: 0.1073 - val_loss: 1.3902 - val_main_output_accuracy: 0.7056 - val_main_output_loss: 1.2733 - val_tof_gate_loss: 0.0173
# Epoch 54/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.4115 - main_output_accuracy: 0.7954 - main_output_loss: 1.2732 - tof_gate_loss: 0.1320 - val_loss: 1.4273 - val_main_output_accuracy: 0.6869 - val_main_output_loss: 1.3083 - val_tof_gate_loss: 0.0299
# Epoch 55/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - loss: 1.5004 - main_output_accuracy: 0.7900 - main_output_loss: 1.3547 - tof_gate_loss: 0.1660 - val_loss: 1.4144 - val_main_output_accuracy: 0.6914 - val_main_output_loss: 1.2973 - val_tof_gate_loss: 0.0217
# Epoch 56/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.3375 - main_output_accuracy: 0.8131 - main_output_loss: 1.2040 - tof_gate_loss: 0.1173 - val_loss: 1.4101 - val_main_output_accuracy: 0.6958 - val_main_output_loss: 1.2917 - val_tof_gate_loss: 0.0296
# Epoch 57/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - loss: 1.2980 - main_output_accuracy: 0.8397 - main_output_loss: 1.1664 - tof_gate_loss: 0.1151 - val_loss: 1.4170 - val_main_output_accuracy: 0.6992 - val_main_output_loss: 1.3001 - val_tof_gate_loss: 0.0255
# Epoch 58/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 95ms/step - loss: 1.3021 - main_output_accuracy: 0.8153 - main_output_loss: 1.1738 - tof_gate_loss: 0.1137 - val_loss: 1.4096 - val_main_output_accuracy: 0.7110 - val_main_output_loss: 1.2932 - val_tof_gate_loss: 0.0210
# Epoch 59/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.3743 - main_output_accuracy: 0.8254 - main_output_loss: 1.2344 - tof_gate_loss: 0.1427 - val_loss: 1.3822 - val_main_output_accuracy: 0.7120 - val_main_output_loss: 1.2656 - val_tof_gate_loss: 0.0232
# Epoch 60/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.3776 - main_output_accuracy: 0.8227 - main_output_loss: 1.2408 - tof_gate_loss: 0.1432 - val_loss: 1.3914 - val_main_output_accuracy: 0.7026 - val_main_output_loss: 1.2737 - val_tof_gate_loss: 0.0333
# Epoch 61/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.3683 - main_output_accuracy: 0.8462 - main_output_loss: 1.2251 - tof_gate_loss: 0.1476 - val_loss: 1.4043 - val_main_output_accuracy: 0.7002 - val_main_output_loss: 1.2902 - val_tof_gate_loss: 0.0146
# Epoch 62/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 1.4425 - main_output_accuracy: 0.8242 - main_output_loss: 1.3006 - tof_gate_loss: 0.1604 - val_loss: 1.4224 - val_main_output_accuracy: 0.7012 - val_main_output_loss: 1.3049 - val_tof_gate_loss: 0.0322
# Epoch 63/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - loss: 1.3274 - main_output_accuracy: 0.8445 - main_output_loss: 1.1907 - tof_gate_loss: 0.1377 - val_loss: 1.4298 - val_main_output_accuracy: 0.7017 - val_main_output_loss: 1.3141 - val_tof_gate_loss: 0.0233
# Epoch 64/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - loss: 1.3464 - main_output_accuracy: 0.8287 - main_output_loss: 1.2076 - tof_gate_loss: 0.1422 - val_loss: 1.3874 - val_main_output_accuracy: 0.7125 - val_main_output_loss: 1.2722 - val_tof_gate_loss: 0.0220
# Epoch 65/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.3926 - main_output_accuracy: 0.8074 - main_output_loss: 1.2526 - tof_gate_loss: 0.1490 - val_loss: 1.4070 - val_main_output_accuracy: 0.7046 - val_main_output_loss: 1.2919 - val_tof_gate_loss: 0.0217
# Epoch 66/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 1.3042 - main_output_accuracy: 0.8327 - main_output_loss: 1.1714 - tof_gate_loss: 0.1182 - val_loss: 1.3928 - val_main_output_accuracy: 0.7105 - val_main_output_loss: 1.2758 - val_tof_gate_loss: 0.0305
# Epoch 67/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 92ms/step - loss: 1.3137 - main_output_accuracy: 0.8453 - main_output_loss: 1.1778 - tof_gate_loss: 0.1345 - val_loss: 1.4100 - val_main_output_accuracy: 0.7031 - val_main_output_loss: 1.2950 - val_tof_gate_loss: 0.0246
# Epoch 68/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - loss: 1.4305 - main_output_accuracy: 0.8116 - main_output_loss: 1.2861 - tof_gate_loss: 0.1725 - val_loss: 1.4007 - val_main_output_accuracy: 0.7149 - val_main_output_loss: 1.2885 - val_tof_gate_loss: 0.0117
# Epoch 69/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.3375 - main_output_accuracy: 0.8331 - main_output_loss: 1.1951 - tof_gate_loss: 0.1407 - val_loss: 1.3975 - val_main_output_accuracy: 0.7041 - val_main_output_loss: 1.2837 - val_tof_gate_loss: 0.0203
# Epoch 70/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.2556 - main_output_accuracy: 0.8605 - main_output_loss: 1.1251 - tof_gate_loss: 0.1154 - val_loss: 1.3996 - val_main_output_accuracy: 0.7125 - val_main_output_loss: 1.2858 - val_tof_gate_loss: 0.0204
# Epoch 71/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.2192 - main_output_accuracy: 0.8687 - main_output_loss: 1.0872 - tof_gate_loss: 0.1057 - val_loss: 1.4063 - val_main_output_accuracy: 0.7100 - val_main_output_loss: 1.2933 - val_tof_gate_loss: 0.0175
# Epoch 72/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - loss: 1.3233 - main_output_accuracy: 0.8288 - main_output_loss: 1.1971 - tof_gate_loss: 0.1430 - val_loss: 1.4352 - val_main_output_accuracy: 0.6894 - val_main_output_loss: 1.3218 - val_tof_gate_loss: 0.0190
# Epoch 73/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - loss: 1.3017 - main_output_accuracy: 0.8446 - main_output_loss: 1.1685 - tof_gate_loss: 0.1389 - val_loss: 1.4118 - val_main_output_accuracy: 0.7130 - val_main_output_loss: 1.2990 - val_tof_gate_loss: 0.0177
# Epoch 74/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - loss: 1.4288 - main_output_accuracy: 0.8194 - main_output_loss: 1.2853 - tof_gate_loss: 0.1711 - val_loss: 1.4018 - val_main_output_accuracy: 0.7144 - val_main_output_loss: 1.2875 - val_tof_gate_loss: 0.0269
# Epoch 75/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.3340 - main_output_accuracy: 0.8365 - main_output_loss: 1.1969 - tof_gate_loss: 0.1379 - val_loss: 1.4063 - val_main_output_accuracy: 0.7174 - val_main_output_loss: 1.2930 - val_tof_gate_loss: 0.0233
# Epoch 76/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.3584 - main_output_accuracy: 0.8559 - main_output_loss: 1.2193 - tof_gate_loss: 0.1559 - val_loss: 1.4282 - val_main_output_accuracy: 0.7090 - val_main_output_loss: 1.3171 - val_tof_gate_loss: 0.0143
# Epoch 77/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 1.3939 - main_output_accuracy: 0.8472 - main_output_loss: 1.2539 - tof_gate_loss: 0.1730 - val_loss: 1.4107 - val_main_output_accuracy: 0.7149 - val_main_output_loss: 1.2995 - val_tof_gate_loss: 0.0134
# Epoch 78/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 106ms/step - loss: 1.2978 - main_output_accuracy: 0.8582 - main_output_loss: 1.1606 - tof_gate_loss: 0.1432 - val_loss: 1.4075 - val_main_output_accuracy: 0.7095 - val_main_output_loss: 1.2947 - val_tof_gate_loss: 0.0239
# Epoch 79/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 104ms/step - loss: 1.2575 - main_output_accuracy: 0.8741 - main_output_loss: 1.1229 - tof_gate_loss: 0.1259 - val_loss: 1.3995 - val_main_output_accuracy: 0.7159 - val_main_output_loss: 1.2879 - val_tof_gate_loss: 0.0188
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# Fold 2 Accuracy: 0.7120
#
# === Fold 3/4 for Advanced_Cross_Attention ===
# LR Scheduler: 96 steps per epoch, 14400 total decay steps.
# Epoch 1/150
# /home/uallende/projects/kaggle/CMI/.venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 21s 113ms/step - loss: 3.0185 - main_output_accuracy: 0.1495 - main_output_loss: 2.7817 - tof_gate_loss: 0.3118 - val_loss: 2.3747 - val_main_output_accuracy: 0.3356 - val_main_output_loss: 2.1810 - val_tof_gate_loss: 0.1232
# Epoch 2/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 2.5305 - main_output_accuracy: 0.2912 - main_output_loss: 2.3278 - tof_gate_loss: 0.1772 - val_loss: 2.1427 - val_main_output_accuracy: 0.4107 - val_main_output_loss: 1.9520 - val_tof_gate_loss: 0.1423
# Epoch 3/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 2.3216 - main_output_accuracy: 0.3658 - main_output_loss: 2.1333 - tof_gate_loss: 0.1387 - val_loss: 1.9751 - val_main_output_accuracy: 0.4539 - val_main_output_loss: 1.8091 - val_tof_gate_loss: 0.0468
# Epoch 4/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 2.1964 - main_output_accuracy: 0.4153 - main_output_loss: 2.0127 - tof_gate_loss: 0.1401 - val_loss: 1.8589 - val_main_output_accuracy: 0.5020 - val_main_output_loss: 1.7028 - val_tof_gate_loss: 0.0212
# Epoch 5/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 91ms/step - loss: 2.1704 - main_output_accuracy: 0.4578 - main_output_loss: 1.9860 - tof_gate_loss: 0.1674 - val_loss: 1.8214 - val_main_output_accuracy: 0.5069 - val_main_output_loss: 1.6645 - val_tof_gate_loss: 0.0456
# Epoch 6/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - loss: 2.1285 - main_output_accuracy: 0.4666 - main_output_loss: 1.9433 - tof_gate_loss: 0.1839 - val_loss: 1.7841 - val_main_output_accuracy: 0.5123 - val_main_output_loss: 1.6328 - val_tof_gate_loss: 0.0372
# Epoch 7/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 2.0466 - main_output_accuracy: 0.4941 - main_output_loss: 1.8711 - tof_gate_loss: 0.1533 - val_loss: 1.7388 - val_main_output_accuracy: 0.5363 - val_main_output_loss: 1.5938 - val_tof_gate_loss: 0.0220
# Epoch 8/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - loss: 1.9582 - main_output_accuracy: 0.5193 - main_output_loss: 1.7916 - tof_gate_loss: 0.1345 - val_loss: 1.6770 - val_main_output_accuracy: 0.5648 - val_main_output_loss: 1.5336 - val_tof_gate_loss: 0.0278
# Epoch 9/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 93ms/step - loss: 1.9874 - main_output_accuracy: 0.5261 - main_output_loss: 1.8153 - tof_gate_loss: 0.1732 - val_loss: 1.6791 - val_main_output_accuracy: 0.5628 - val_main_output_loss: 1.5383 - val_tof_gate_loss: 0.0281
# Epoch 10/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - loss: 1.8870 - main_output_accuracy: 0.5604 - main_output_loss: 1.7254 - tof_gate_loss: 0.1310 - val_loss: 1.6345 - val_main_output_accuracy: 0.5795 - val_main_output_loss: 1.4937 - val_tof_gate_loss: 0.0384
# Epoch 11/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.8908 - main_output_accuracy: 0.5670 - main_output_loss: 1.7287 - tof_gate_loss: 0.1539 - val_loss: 1.6242 - val_main_output_accuracy: 0.5819 - val_main_output_loss: 1.4865 - val_tof_gate_loss: 0.0325
# Epoch 12/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 91ms/step - loss: 1.8975 - main_output_accuracy: 0.5632 - main_output_loss: 1.7343 - tof_gate_loss: 0.1602 - val_loss: 1.6087 - val_main_output_accuracy: 0.5981 - val_main_output_loss: 1.4705 - val_tof_gate_loss: 0.0425
# Epoch 13/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 93ms/step - loss: 1.7687 - main_output_accuracy: 0.6039 - main_output_loss: 1.6099 - tof_gate_loss: 0.1409 - val_loss: 1.5758 - val_main_output_accuracy: 0.5967 - val_main_output_loss: 1.4440 - val_tof_gate_loss: 0.0163
# Epoch 14/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.8181 - main_output_accuracy: 0.6006 - main_output_loss: 1.6576 - tof_gate_loss: 0.1576 - val_loss: 1.5856 - val_main_output_accuracy: 0.5972 - val_main_output_loss: 1.4453 - val_tof_gate_loss: 0.0668
# Epoch 15/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 1.7745 - main_output_accuracy: 0.6160 - main_output_loss: 1.6175 - tof_gate_loss: 0.1449 - val_loss: 1.5915 - val_main_output_accuracy: 0.6070 - val_main_output_loss: 1.4607 - val_tof_gate_loss: 0.0237
# Epoch 16/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 1.8196 - main_output_accuracy: 0.6024 - main_output_loss: 1.6625 - tof_gate_loss: 0.1582 - val_loss: 1.5688 - val_main_output_accuracy: 0.6035 - val_main_output_loss: 1.4369 - val_tof_gate_loss: 0.0349
# Epoch 17/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 97ms/step - loss: 1.7663 - main_output_accuracy: 0.6041 - main_output_loss: 1.6114 - tof_gate_loss: 0.1510 - val_loss: 1.5370 - val_main_output_accuracy: 0.6178 - val_main_output_loss: 1.4085 - val_tof_gate_loss: 0.0239
# Epoch 18/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 1.7669 - main_output_accuracy: 0.6391 - main_output_loss: 1.6110 - tof_gate_loss: 0.1451 - val_loss: 1.5095 - val_main_output_accuracy: 0.6398 - val_main_output_loss: 1.3834 - val_tof_gate_loss: 0.0165
# Epoch 19/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 93ms/step - loss: 1.7523 - main_output_accuracy: 0.6378 - main_output_loss: 1.5981 - tof_gate_loss: 0.1627 - val_loss: 1.5031 - val_main_output_accuracy: 0.6379 - val_main_output_loss: 1.3776 - val_tof_gate_loss: 0.0183
# Epoch 20/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 95ms/step - loss: 1.6774 - main_output_accuracy: 0.6589 - main_output_loss: 1.5309 - tof_gate_loss: 0.1367 - val_loss: 1.5038 - val_main_output_accuracy: 0.6398 - val_main_output_loss: 1.3767 - val_tof_gate_loss: 0.0312
# Epoch 21/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 1.6380 - main_output_accuracy: 0.6663 - main_output_loss: 1.4893 - tof_gate_loss: 0.1277 - val_loss: 1.4970 - val_main_output_accuracy: 0.6492 - val_main_output_loss: 1.3731 - val_tof_gate_loss: 0.0168
# Epoch 22/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 94ms/step - loss: 1.7612 - main_output_accuracy: 0.6380 - main_output_loss: 1.6035 - tof_gate_loss: 0.1819 - val_loss: 1.5086 - val_main_output_accuracy: 0.6364 - val_main_output_loss: 1.3832 - val_tof_gate_loss: 0.0276
# Epoch 23/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - loss: 1.5971 - main_output_accuracy: 0.6764 - main_output_loss: 1.4549 - tof_gate_loss: 0.1118 - val_loss: 1.5005 - val_main_output_accuracy: 0.6413 - val_main_output_loss: 1.3755 - val_tof_gate_loss: 0.0276
# Epoch 24/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 1.5920 - main_output_accuracy: 0.6903 - main_output_loss: 1.4492 - tof_gate_loss: 0.1304 - val_loss: 1.4812 - val_main_output_accuracy: 0.6497 - val_main_output_loss: 1.3560 - val_tof_gate_loss: 0.0335
# Epoch 25/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - loss: 1.6490 - main_output_accuracy: 0.6864 - main_output_loss: 1.4961 - tof_gate_loss: 0.1503 - val_loss: 1.4740 - val_main_output_accuracy: 0.6492 - val_main_output_loss: 1.3520 - val_tof_gate_loss: 0.0195
# Epoch 26/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 105ms/step - loss: 1.7248 - main_output_accuracy: 0.6735 - main_output_loss: 1.5724 - tof_gate_loss: 0.1728 - val_loss: 1.4517 - val_main_output_accuracy: 0.6693 - val_main_output_loss: 1.3297 - val_tof_gate_loss: 0.0219
# Epoch 27/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 99ms/step - loss: 1.5932 - main_output_accuracy: 0.6825 - main_output_loss: 1.4454 - tof_gate_loss: 0.1369 - val_loss: 1.4759 - val_main_output_accuracy: 0.6595 - val_main_output_loss: 1.3561 - val_tof_gate_loss: 0.0120
# Epoch 28/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 95ms/step - loss: 1.5514 - main_output_accuracy: 0.7146 - main_output_loss: 1.4109 - tof_gate_loss: 0.1234 - val_loss: 1.4898 - val_main_output_accuracy: 0.6492 - val_main_output_loss: 1.3708 - val_tof_gate_loss: 0.0125
# Epoch 29/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - loss: 1.5827 - main_output_accuracy: 0.7067 - main_output_loss: 1.4422 - tof_gate_loss: 0.1409 - val_loss: 1.4671 - val_main_output_accuracy: 0.6511 - val_main_output_loss: 1.3474 - val_tof_gate_loss: 0.0175
# Epoch 30/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 9s 96ms/step - loss: 1.5897 - main_output_accuracy: 0.7117 - main_output_loss: 1.4470 - tof_gate_loss: 0.1324 - val_loss: 1.4939 - val_main_output_accuracy: 0.6443 - val_main_output_loss: 1.3761 - val_tof_gate_loss: 0.0082
# Epoch 31/150
# ...
# Epoch 15/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - loss: 2.0193 - main_output_accuracy: 0.5790 - main_output_loss: 1.7503 - tof_gate_loss: 0.2088 - val_loss: 1.6404 - val_main_output_accuracy: 0.6259 - val_main_output_loss: 1.4031 - val_tof_gate_loss: 0.0695
# Epoch 16/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 164ms/step - loss: 2.0450 - main_output_accuracy: 0.5966 - main_output_loss: 1.7762 - tof_gate_loss: 0.2289 - val_loss: 1.6199 - val_main_output_accuracy: 0.6220 - val_main_output_loss: 1.3881 - val_tof_gate_loss: 0.0682
# Epoch 17/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 172ms/step - loss: 1.9984 - main_output_accuracy: 0.5981 - main_output_loss: 1.7391 - tof_gate_loss: 0.2131 - val_loss: 1.6144 - val_main_output_accuracy: 0.6338 - val_main_output_loss: 1.3889 - val_tof_gate_loss: 0.0610
# Epoch 18/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 168ms/step - loss: 1.9453 - main_output_accuracy: 0.6059 - main_output_loss: 1.6904 - tof_gate_loss: 0.2132 - val_loss: 1.6168 - val_main_output_accuracy: 0.6215 - val_main_output_loss: 1.3939 - val_tof_gate_loss: 0.0654
# Epoch 19/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 162ms/step - loss: 1.8395 - main_output_accuracy: 0.6290 - main_output_loss: 1.5957 - tof_gate_loss: 0.1859 - val_loss: 1.5547 - val_main_output_accuracy: 0.6524 - val_main_output_loss: 1.3355 - val_tof_gate_loss: 0.0670
# Epoch 20/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 162ms/step - loss: 1.8949 - main_output_accuracy: 0.6346 - main_output_loss: 1.6535 - tof_gate_loss: 0.1957 - val_loss: 1.5834 - val_main_output_accuracy: 0.6328 - val_main_output_loss: 1.3725 - val_tof_gate_loss: 0.0444
# Epoch 21/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 167ms/step - loss: 1.9044 - main_output_accuracy: 0.6355 - main_output_loss: 1.6634 - tof_gate_loss: 0.2051 - val_loss: 1.5605 - val_main_output_accuracy: 0.6436 - val_main_output_loss: 1.3502 - val_tof_gate_loss: 0.0545
# Epoch 22/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - loss: 1.9322 - main_output_accuracy: 0.6277 - main_output_loss: 1.6930 - tof_gate_loss: 0.2164 - val_loss: 1.5486 - val_main_output_accuracy: 0.6544 - val_main_output_loss: 1.3353 - val_tof_gate_loss: 0.0896
# Epoch 23/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 170ms/step - loss: 1.7973 - main_output_accuracy: 0.6577 - main_output_loss: 1.5629 - tof_gate_loss: 0.1898 - val_loss: 1.5343 - val_main_output_accuracy: 0.6608 - val_main_output_loss: 1.3307 - val_tof_gate_loss: 0.0532
# Epoch 24/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 182ms/step - loss: 1.8885 - main_output_accuracy: 0.6380 - main_output_loss: 1.6515 - tof_gate_loss: 0.2226 - val_loss: 1.5376 - val_main_output_accuracy: 0.6681 - val_main_output_loss: 1.3313 - val_tof_gate_loss: 0.0867
# Epoch 25/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 165ms/step - loss: 1.8108 - main_output_accuracy: 0.6553 - main_output_loss: 1.5836 - tof_gate_loss: 0.1950 - val_loss: 1.5472 - val_main_output_accuracy: 0.6500 - val_main_output_loss: 1.3457 - val_tof_gate_loss: 0.0696
# Epoch 26/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 177ms/step - loss: 1.8906 - main_output_accuracy: 0.6484 - main_output_loss: 1.6578 - tof_gate_loss: 0.2230 - val_loss: 1.5678 - val_main_output_accuracy: 0.6441 - val_main_output_loss: 1.3758 - val_tof_gate_loss: 0.0332
# Epoch 27/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 173ms/step - loss: 1.8879 - main_output_accuracy: 0.6474 - main_output_loss: 1.6594 - tof_gate_loss: 0.2202 - val_loss: 1.5877 - val_main_output_accuracy: 0.6289 - val_main_output_loss: 1.3957 - val_tof_gate_loss: 0.0467
# Epoch 28/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 187ms/step - loss: 1.6549 - main_output_accuracy: 0.6979 - main_output_loss: 1.4428 - tof_gate_loss: 0.1520 - val_loss: 1.5120 - val_main_output_accuracy: 0.6578 - val_main_output_loss: 1.3237 - val_tof_gate_loss: 0.0426
# Epoch 29/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 163ms/step - loss: 1.6870 - main_output_accuracy: 0.6971 - main_output_loss: 1.4731 - tof_gate_loss: 0.1713 - val_loss: 1.5307 - val_main_output_accuracy: 0.6618 - val_main_output_loss: 1.3405 - val_tof_gate_loss: 0.0591
# Epoch 30/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 174ms/step - loss: 1.7923 - main_output_accuracy: 0.6845 - main_output_loss: 1.5713 - tof_gate_loss: 0.2097 - val_loss: 1.5269 - val_main_output_accuracy: 0.6618 - val_main_output_loss: 1.3370 - val_tof_gate_loss: 0.0647
# Epoch 31/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - loss: 1.7647 - main_output_accuracy: 0.6988 - main_output_loss: 1.5412 - tof_gate_loss: 0.2000 - val_loss: 1.5150 - val_main_output_accuracy: 0.6573 - val_main_output_loss: 1.3341 - val_tof_gate_loss: 0.0304
# Epoch 32/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 169ms/step - loss: 1.6847 - main_output_accuracy: 0.7020 - main_output_loss: 1.4755 - tof_gate_loss: 0.1804 - val_loss: 1.5070 - val_main_output_accuracy: 0.6544 - val_main_output_loss: 1.3248 - val_tof_gate_loss: 0.0475
# Epoch 33/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 179ms/step - loss: 1.7653 - main_output_accuracy: 0.6958 - main_output_loss: 1.5553 - tof_gate_loss: 0.1994 - val_loss: 1.4756 - val_main_output_accuracy: 0.6794 - val_main_output_loss: 1.2951 - val_tof_gate_loss: 0.0478
# Epoch 34/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 172ms/step - loss: 1.7049 - main_output_accuracy: 0.6995 - main_output_loss: 1.4970 - tof_gate_loss: 0.1846 - val_loss: 1.4854 - val_main_output_accuracy: 0.6780 - val_main_output_loss: 1.3087 - val_tof_gate_loss: 0.0342
# Epoch 35/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 169ms/step - loss: 1.6849 - main_output_accuracy: 0.7271 - main_output_loss: 1.4777 - tof_gate_loss: 0.1817 - val_loss: 1.4892 - val_main_output_accuracy: 0.6667 - val_main_output_loss: 1.3129 - val_tof_gate_loss: 0.0381
# Epoch 36/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - loss: 1.7390 - main_output_accuracy: 0.7114 - main_output_loss: 1.5305 - tof_gate_loss: 0.1994 - val_loss: 1.5077 - val_main_output_accuracy: 0.6691 - val_main_output_loss: 1.3317 - val_tof_gate_loss: 0.0457
# Epoch 37/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 166ms/step - loss: 1.6173 - main_output_accuracy: 0.7428 - main_output_loss: 1.4156 - tof_gate_loss: 0.1758 - val_loss: 1.4686 - val_main_output_accuracy: 0.6775 - val_main_output_loss: 1.2907 - val_tof_gate_loss: 0.0621
# Epoch 38/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - loss: 1.7035 - main_output_accuracy: 0.7298 - main_output_loss: 1.4977 - tof_gate_loss: 0.2086 - val_loss: 1.4947 - val_main_output_accuracy: 0.6593 - val_main_output_loss: 1.3239 - val_tof_gate_loss: 0.0316
# Epoch 39/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - loss: 1.7027 - main_output_accuracy: 0.7243 - main_output_loss: 1.4972 - tof_gate_loss: 0.2093 - val_loss: 1.4976 - val_main_output_accuracy: 0.6632 - val_main_output_loss: 1.3254 - val_tof_gate_loss: 0.0443
# Epoch 40/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 164ms/step - loss: 1.7043 - main_output_accuracy: 0.7140 - main_output_loss: 1.5005 - tof_gate_loss: 0.1991 - val_loss: 1.4528 - val_main_output_accuracy: 0.6799 - val_main_output_loss: 1.2824 - val_tof_gate_loss: 0.0413
# Epoch 41/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 166ms/step - loss: 1.5769 - main_output_accuracy: 0.7570 - main_output_loss: 1.3821 - tof_gate_loss: 0.1674 - val_loss: 1.4466 - val_main_output_accuracy: 0.6824 - val_main_output_loss: 1.2808 - val_tof_gate_loss: 0.0255
# Epoch 42/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 188ms/step - loss: 1.5992 - main_output_accuracy: 0.7451 - main_output_loss: 1.4022 - tof_gate_loss: 0.1855 - val_loss: 1.4861 - val_main_output_accuracy: 0.6735 - val_main_output_loss: 1.3165 - val_tof_gate_loss: 0.0492
# Epoch 43/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 15s 158ms/step - loss: 1.6363 - main_output_accuracy: 0.7453 - main_output_loss: 1.4385 - tof_gate_loss: 0.1869 - val_loss: 1.4556 - val_main_output_accuracy: 0.6814 - val_main_output_loss: 1.2899 - val_tof_gate_loss: 0.0361
# Epoch 44/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - loss: 1.6045 - main_output_accuracy: 0.7727 - main_output_loss: 1.4051 - tof_gate_loss: 0.1945 - val_loss: 1.4635 - val_main_output_accuracy: 0.6804 - val_main_output_loss: 1.2935 - val_tof_gate_loss: 0.0611
# Epoch 45/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 182ms/step - loss: 1.6199 - main_output_accuracy: 0.7554 - main_output_loss: 1.4248 - tof_gate_loss: 0.1969 - val_loss: 1.4678 - val_main_output_accuracy: 0.6784 - val_main_output_loss: 1.3035 - val_tof_gate_loss: 0.0381
# Epoch 46/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 169ms/step - loss: 1.5941 - main_output_accuracy: 0.7702 - main_output_loss: 1.3990 - tof_gate_loss: 0.1895 - val_loss: 1.4313 - val_main_output_accuracy: 0.6966 - val_main_output_loss: 1.2692 - val_tof_gate_loss: 0.0308
# Epoch 47/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 166ms/step - loss: 1.5380 - main_output_accuracy: 0.7788 - main_output_loss: 1.3459 - tof_gate_loss: 0.1798 - val_loss: 1.4756 - val_main_output_accuracy: 0.6809 - val_main_output_loss: 1.3134 - val_tof_gate_loss: 0.0342
# Epoch 48/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 15s 155ms/step - loss: 1.5811 - main_output_accuracy: 0.7716 - main_output_loss: 1.3913 - tof_gate_loss: 0.1799 - val_loss: 1.4341 - val_main_output_accuracy: 0.6922 - val_main_output_loss: 1.2723 - val_tof_gate_loss: 0.0360
# Epoch 49/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 165ms/step - loss: 1.5448 - main_output_accuracy: 0.7818 - main_output_loss: 1.3519 - tof_gate_loss: 0.1951 - val_loss: 1.4563 - val_main_output_accuracy: 0.6838 - val_main_output_loss: 1.2971 - val_tof_gate_loss: 0.0309
# Epoch 50/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 165ms/step - loss: 1.6274 - main_output_accuracy: 0.7674 - main_output_loss: 1.4343 - tof_gate_loss: 0.2011 - val_loss: 1.4336 - val_main_output_accuracy: 0.6932 - val_main_output_loss: 1.2749 - val_tof_gate_loss: 0.0323
# Epoch 51/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 161ms/step - loss: 1.5796 - main_output_accuracy: 0.7901 - main_output_loss: 1.3868 - tof_gate_loss: 0.2015 - val_loss: 1.4565 - val_main_output_accuracy: 0.6775 - val_main_output_loss: 1.2975 - val_tof_gate_loss: 0.0390
# Epoch 52/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 15s 161ms/step - loss: 1.7815 - main_output_accuracy: 0.7214 - main_output_loss: 1.5956 - tof_gate_loss: 0.2413 - val_loss: 1.4643 - val_main_output_accuracy: 0.6765 - val_main_output_loss: 1.3075 - val_tof_gate_loss: 0.0328
# Epoch 53/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 15s 160ms/step - loss: 1.6491 - main_output_accuracy: 0.7729 - main_output_loss: 1.4564 - tof_gate_loss: 0.2106 - val_loss: 1.4488 - val_main_output_accuracy: 0.6888 - val_main_output_loss: 1.2927 - val_tof_gate_loss: 0.0306
# Epoch 54/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 15s 155ms/step - loss: 1.5594 - main_output_accuracy: 0.7839 - main_output_loss: 1.3713 - tof_gate_loss: 0.1919 - val_loss: 1.4742 - val_main_output_accuracy: 0.6824 - val_main_output_loss: 1.3139 - val_tof_gate_loss: 0.0551
# Epoch 55/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 166ms/step - loss: 1.5707 - main_output_accuracy: 0.7869 - main_output_loss: 1.3855 - tof_gate_loss: 0.2058 - val_loss: 1.4510 - val_main_output_accuracy: 0.6794 - val_main_output_loss: 1.2959 - val_tof_gate_loss: 0.0347
# Epoch 56/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 165ms/step - loss: 1.5236 - main_output_accuracy: 0.8111 - main_output_loss: 1.3408 - tof_gate_loss: 0.1956 - val_loss: 1.4564 - val_main_output_accuracy: 0.6888 - val_main_output_loss: 1.3030 - val_tof_gate_loss: 0.0242
# Epoch 57/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 163ms/step - loss: 1.5806 - main_output_accuracy: 0.7996 - main_output_loss: 1.3906 - tof_gate_loss: 0.2049 - val_loss: 1.4610 - val_main_output_accuracy: 0.6799 - val_main_output_loss: 1.3080 - val_tof_gate_loss: 0.0300
# Epoch 58/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 174ms/step - loss: 1.6107 - main_output_accuracy: 0.7783 - main_output_loss: 1.4209 - tof_gate_loss: 0.2092 - val_loss: 1.4373 - val_main_output_accuracy: 0.6951 - val_main_output_loss: 1.2841 - val_tof_gate_loss: 0.0332
# Epoch 59/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 168ms/step - loss: 1.4665 - main_output_accuracy: 0.8192 - main_output_loss: 1.2822 - tof_gate_loss: 0.1851 - val_loss: 1.4634 - val_main_output_accuracy: 0.6897 - val_main_output_loss: 1.3089 - val_tof_gate_loss: 0.0415
# Epoch 60/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 168ms/step - loss: 1.6022 - main_output_accuracy: 0.7864 - main_output_loss: 1.4103 - tof_gate_loss: 0.2231 - val_loss: 1.4517 - val_main_output_accuracy: 0.6902 - val_main_output_loss: 1.3006 - val_tof_gate_loss: 0.0275
# Epoch 61/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 176ms/step - loss: 1.5163 - main_output_accuracy: 0.8038 - main_output_loss: 1.3336 - tof_gate_loss: 0.1804 - val_loss: 1.4713 - val_main_output_accuracy: 0.6819 - val_main_output_loss: 1.3187 - val_tof_gate_loss: 0.0361
# Epoch 62/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 15s 161ms/step - loss: 1.3842 - main_output_accuracy: 0.8269 - main_output_loss: 1.2125 - tof_gate_loss: 0.1596 - val_loss: 1.4745 - val_main_output_accuracy: 0.6829 - val_main_output_loss: 1.3251 - val_tof_gate_loss: 0.0247
# Epoch 63/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 175ms/step - loss: 1.4207 - main_output_accuracy: 0.8322 - main_output_loss: 1.2461 - tof_gate_loss: 0.1536 - val_loss: 1.4331 - val_main_output_accuracy: 0.7108 - val_main_output_loss: 1.2827 - val_tof_gate_loss: 0.0308
# Epoch 64/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 15s 161ms/step - loss: 1.3395 - main_output_accuracy: 0.8438 - main_output_loss: 1.1659 - tof_gate_loss: 0.1503 - val_loss: 1.4740 - val_main_output_accuracy: 0.6799 - val_main_output_loss: 1.3237 - val_tof_gate_loss: 0.0349
# Epoch 65/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 17s 174ms/step - loss: 1.5279 - main_output_accuracy: 0.8150 - main_output_loss: 1.3455 - tof_gate_loss: 0.1992 - val_loss: 1.4444 - val_main_output_accuracy: 0.7005 - val_main_output_loss: 1.2953 - val_tof_gate_loss: 0.0299
# Epoch 66/150
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 16s 171ms/step - loss: 1.4685 - main_output_accuracy: 0.8357 - main_output_loss: 1.2872 - tof_gate_loss: 0.1916 - val_loss: 1.4344 - val_main_output_accuracy: 0.7015 - val_main_output_loss: 1.2862 - val_tof_gate_loss: 0.0305
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step
# Fold 4 Accuracy: 0.6966
#
# === OOF Summary for Advanced_Stacked_Hybrid ===
# Per-fold Accuracies: [0.7125, 0.7056, 0.6963, 0.6966]
# Mean Accuracy: 0.7027 ± 0.0067
#
# === Overall Classification Report ===
#                                             precision    recall  f1-score   support
#
#                      Above ear - pull hair     0.8055    0.7853    0.7952       638
#                         Cheek - pinch skin     0.6053    0.5777    0.5912       637
#                      Drink from bottle/cup     0.9554    0.9317    0.9434       161
#                        Eyebrow - pull hair     0.4871    0.4734    0.4801       638
#                        Eyelash - pull hair     0.5369    0.5344    0.5356       640
# Feel around in tray and pull out an object     0.8882    0.8385    0.8626       161
#                   Forehead - pull hairline     0.7248    0.7203    0.7226       640
#                         Forehead - scratch     0.7889    0.8000    0.7944       640
#                             Glasses on/off     0.9427    0.9193    0.9308       161
#                          Neck - pinch skin     0.5174    0.6281    0.5674       640
#                             Neck - scratch     0.5785    0.5125    0.5435       640
#                        Pinch knee/leg skin     0.4695    0.6211    0.5348       161
#                  Pull air toward your face     0.9479    0.9161    0.9318       477
#                      Scratch knee/leg skin     0.4581    0.4410    0.4494       161
#                              Text on phone     0.9168    0.9297    0.9232       640
#                                 Wave hello     0.8689    0.8870    0.8778       478
#                          Write name in air     0.8313    0.8470    0.8390       477
#                          Write name on leg     0.4103    0.2981    0.3453       161
#
#                                   accuracy                         0.7027      8151
#                                  macro avg     0.7074    0.7034    0.7038      8151
#                               weighted avg     0.7040    0.7027    0.7023      8151

# %%
import traceback
# =====================================================================================
# ARCHITECTURE SANITY CHECK
# =====================================================================================

# --- Step 1: Get a sample batch and define shapes ---
# (This part of your code is correct)
# Make sure your train_dataset is created before this block
try:
    sample_batch = next(iter(train_dataset))
    sample_input = sample_batch[0]
    input_shape = sample_input.shape[1:]
    imu_dim = len(imu_cols) # Assuming imu_cols is defined
    print(f"Sample input shape for testing: {sample_input.shape}\n")
except Exception as e:
    print(f"Could not get a sample from the dataset. Error: {e}")
    # Exit if we can't get a sample to test with
    exit()

# --- Step 2: Create a list of all model-building functions ---
# (This part of your code is correct)
model_builders = [
    ("CNN_Baseline", lambda: create_model_1_cnn_baseline(input_shape)),
    ("GRU_Baseline", lambda: create_model_2_gru_baseline(input_shape)),
    ("CNN_RNN_Hybrid", lambda: create_model_3_cnn_rnn_hybrid(input_shape)),
    ("WaveNet_Style", lambda: create_model_4_wavenet_style(input_shape)),
    ("UNet_Style", lambda: create_model_5_unet_style(input_shape)),
    ("Transformer", lambda: create_model_6_transformer(input_shape)),
    ("CNN_Transformer", lambda: create_model_7_cnn_transformer(input_shape)),
    # For your two-branch model, you'll need the full IMU+ToF dataset
    # ("Two_Branch", lambda: create_model_8_two_branch(input_shape, imu_dim)),
]

# --- Step 3: Loop through the models, build them, and test with the sample ---
print("--- Testing all model architectures with a sample batch ---")
for model_name, model_builder in model_builders:
    print("\n" + "="*60)
    print(f"▶ Testing Model: {model_name}")
    print("="*60)
    
    try:
        # 1. Build the model using the builder function
        model = model_builder()
        
        # Optional: Print the model summary to check its structure
        print(f"Model Summary for {model_name}:")
        model.summary()
        
        # 2. Pass the sample input through the model
        print(f"\nPerforming forward pass for {model_name}...")
        output = model(sample_input)
        
        # 3. Print the output shape to verify it's correct
        print(f"✅ SUCCESS: Model '{model_name}' ran successfully.")
        # For multi-output models, output might be a list/dict. For single, it's a tensor.
        if isinstance(output, dict):
            for key, value in output.items():
                print(f"   Output '{key}' shape: {value.shape}")
        elif isinstance(output, list):
            for i, value in enumerate(output):
                print(f"   Output {i} shape: {value.shape}")
        else:
            print(f"   Output shape: {output.shape}")

    except Exception as e:
        print(f"❌ ERROR: Model '{model_name}' failed to build or run.")
        traceback.print_exc() # This will print the full error traceback
        
    # Clean up the created model to save memory
    del model
    gc.collect()

print("\n--- Model architecture testing complete. ---")
# Out:
# Could not get a sample from the dataset. Error: name 'train_dataset' is not defined
# --- Testing all model architectures with a sample batch ---
#
# ============================================================
# ▶ Testing Model: CNN_Baseline
# ============================================================
# ❌ ERROR: Model 'CNN_Baseline' failed to build or run.
# Traceback (most recent call last):
#   File "/tmp/ipykernel_1943241/937420362.py", line 43, in <module>
#     model = model_builder()
#             ^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_1943241/937420362.py", line 23, in <lambda>
#     ("CNN_Baseline", lambda: create_model_1_cnn_baseline(input_shape)),
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# NameError: name 'create_model_1_cnn_baseline' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 70
#      67         traceback.print_exc() # This will print the full error traceback
#      69     # Clean up the created model to save memory
# ---> 70     del model
#      71     gc.collect()
#      73 print("\n--- Model architecture testing complete. ---")
#
# NameError: name 'model' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
