# %%
import gc
import numpy as np
import polars as pl
import tensorflow as tf
from pathlib import Path
from tensorflow import shape, minimum
from tensorflow.keras import backend as k
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import pad_sequences, Sequence, to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import (
    Dense, Input, Conv1D, MaxPooling1D, GlobalAveragePooling1D, GlobalMaxPooling1D, Concatenate,
    BatchNormalization, GRU, Dropout, add, Activation, Multiply, Reshape,
    LayerNormalization, Add, Bidirectional, LSTM, UpSampling1D, Lambda, GaussianNoise, MultiHeadAttention
)
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report, accuracy_score

from src.nn_blocks import tof_block, residual_se_cnn_block, TransformerBlock, tof_block_2, features_processing, unet_se_cnn

NUM_CLASSES = 18


# --- Gated Model 1: Based on CNN-RNN Hybrid ---
def create_gated_cnn_rnn(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # IMU branch
    x1 = residual_se_cnn_block(imu, 64, 3, drop=0.2, wd=wd) # Output: (None, 64, 64)
    x1 = residual_se_cnn_block(x1, 128, 5, drop=0.2, wd=wd) # Output: (None, 32, 128)
    x1 = Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer=l2(wd)))(x1) # Output: (None, 32, 256)
    
    # Standard ToF branch
    x2 = tof_block_2(tof, wd) # Output: (None, 32, 128)

    # --- FIX: Project x2 to match x1's feature dimension before processing ---
    x2_projected = Dense(256, activation='relu')(x2)

    # Now both inputs to features_processing have shape (None, 32, 256)
    x = features_processing(x1, x2_projected)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Gated Model 2: Based on UNet_Style ---
def create_gated_unet(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # IMU branch
    x1 = unet_se_cnn(imu, unet_depth=4, base_filters=64, kernel_size=5, drop=0.3) # Output: (None, 128, 64)
    
    # Standard ToF branch
    x2 = tof_block_2(tof, wd) # Output: (None, 32, 128)

    # We will use a simpler approach for this model.
    x1_pooled = GlobalAveragePooling1D()(x1)
    x2_pooled = GlobalAveragePooling1D()(x2)
    x = Concatenate()([x1_pooled, x2_pooled])
    
    x = Dropout(0.4)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Gated Model 3: Based on CNN_Transformer ---
def create_gated_cnn_transformer(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # IMU branch
    x1 = residual_se_cnn_block(imu, 64, 3, drop=0.2, wd=wd) # Output: (None, 64, 64)
    x1 = residual_se_cnn_block(x1, 128, 5, drop=0.2, wd=wd) # Output: (None, 32, 128)
    x1 = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=128, rate=0.3)(x1) # Output: (None, 32, 128)
    x1 = residual_se_cnn_block(x1, 64, 3, drop=0.2, wd=wd) # Output: (None, 16, 64)
    x1 = residual_se_cnn_block(x1, 128, 5, drop=0.2, wd=wd) # Output: (None, 8, 128)    
    x1 = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=128, rate=0.3)(x1) # Output: (None, 8, 128)
    
    # Standard ToF branch
    x2 = tof_block_2(tof, wd) # Output: (None, 32, 128)
    x2 = tf.keras.layers.MaxPooling1D(4)(x2)

    x = features_processing(x1, x2)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

def best_unet_1(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    x1 = unet_se_cnn(imu, 3, base_filters=128, kernel_size=3)
    x2 = tof_block(tof, wd)

    x = features_processing(x1, x2)
    x = tf.keras.layers.Dropout(0.3)(x) 
    main_out = tf.keras.layers.Dense(18, activation="softmax", name="main_output")(x)
    gate_out = tf.keras.layers.Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return tf.keras.models.Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

def best_unet_2(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    x1 = unet_se_cnn(imu, 3, base_filters=128, kernel_size=3)
    x2 = tof_block_2(tof, wd)

    x = features_processing(x1, x2)
    x = tf.keras.layers.Dropout(0.3)(x) 
    main_out = tf.keras.layers.Dense(18, activation="softmax", name="main_output")(x)
    gate_out = tf.keras.layers.Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return tf.keras.models.Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})
# Out:
# 2025-08-23 20:59:08.848228: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755979148.870711 4081569 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755979148.876568 4081569 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755979148.892881 4081569 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755979148.892910 4081569 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755979148.892912 4081569 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1755979148.892914 4081569 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-23 20:59:08.898567: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# =====================================================================================
# 5 NEW ADVANCED MODEL ARCHITECTURES
# =====================================================================================

from src.nn_blocks import match_time_steps, wave_block, res_se_cnn_decoder_block

# --- Advanced Model 2: Stacked Transformer Tower ---
def create_advanced_model_2_transformer_tower(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # Strong CNN backbone to create rich features for the Transformer
    x1 = residual_se_cnn_block(imu, 64, 3, drop=0.2, wd=wd)
    x1 = residual_se_cnn_block(x1, 128, 5, drop=0.2, wd=wd) # Output shape: (None, 32, 128)
    
    # Stacked Transformer Tower
    # Each block attends to the output of the previous one, building deeper context.
    x1 = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=256, rate=0.3)(x1)
    x1 = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=256, rate=0.3)(x1)
    x1 = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=256, rate=0.3)(x1)
    x1 = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=256, rate=0.3)(x1)
    
    # Standard ToF branch
    x2 = tof_block_2(tof, wd) # Output shape: (None, 32, 128)

    # Merge and classify
    x = features_processing(x1, x2)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Advanced Model 3: Hybrid UNet + WaveNet ---
def create_advanced_model_3_unet_wave(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    x1_unet = unet_se_cnn(imu, unet_depth=3, base_filters=64, kernel_size=5)
    x1_wave = wave_block(imu, 64, 3, n=5, dropout_rate=0.3) # n=5 -> dilations up to 16
    
    x1_unet_matched, x1_wave_matched = match_time_steps(x1_unet, x1_wave)
    x1 = Concatenate()([x1_unet_matched, x1_wave_matched])
    
    x2 = tof_block(tof, wd)

    x = features_processing(x1, x2)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

def create_wave_net(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    x1 = wave_block(imu, 128, 3, n=4, dropout_rate=0.3) 
    x2 = tof_block(tof, wd)

    x = features_processing(x1, x2)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Advanced Model 4: Triple Stacked Block Design ---
def cnn_gru_block(x, filters, kernel_size, wd=1e-4):
    # A self-contained block combining CNN and GRU
    x_cnn = residual_se_cnn_block(x, filters, kernel_size, wd=wd)
    x_gru = Bidirectional(GRU(filters // 2, return_sequences=True))(x_cnn)
    return x_gru

def cnn_gru_block(x, filters, kernel_size, wd=1e-4):
    """
    A simplified and robust block that first applies a CNN, then a GRU.
    """
    # 1. CNN part for feature extraction and downsampling
    x = residual_se_cnn_block(x, filters, kernel_size, wd=wd)
    
    # 2. GRU part for sequence processing
    x = Bidirectional(GRU(filters, return_sequences=True, kernel_regularizer=l2(wd)))(x)
    
    return x

def create_advanced_model_4_stacked_blocks(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # Apply the hybrid block three times
    x1 = cnn_gru_block(imu, 64, 3)  # Output: (None, 64, 128)
    x1 = cnn_gru_block(x1, 128, 5) # Output: (None, 32, 256)
    
    # The final block will not return sequences to simplify the final merge
    x1 = Bidirectional(GRU(128, return_sequences=False))(x1) # Output: (None, 256)
    
    # Standard ToF branch, but we need to aggregate it to match x1
    x2 = tof_block_2(tof, wd) # Output: (None, 32, 128)
    x2 = GlobalAveragePooling1D()(x2) # Output: (None, 128)

    # Merge the two aggregated feature vectors
    x = Concatenate()([x1, x2]) # Output: (None, 256 + 128) = (None, 384)
    
    # Final classifier MLP
    x = Dropout(0.4)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Advanced Model 5: UNet with BiLSTM Bottleneck ---
def unet_se_cnn_bilstm(x, unet_depth=3, base_filters=64, kernel_size=3, drop=0.3):
    filters = base_filters
    skips = []
    for _ in range(unet_depth):
        x = residual_se_cnn_block(x, filters, kernel_size, drop=drop)
        skips.append(x)
        filters *= 2
    
    # --- BiLSTM Bottleneck ---
    # Process the most compressed representation sequentially
    x = Bidirectional(LSTM(filters // 2, return_sequences=True))(x)
    
    for skip in reversed(skips):
        filters //= 2
        x = res_se_cnn_decoder_block(x, filters, kernel_size, drop=drop, skip_connection=skip)
    return x

def create_advanced_model_1_deep_unet(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # --- IMU Branches ---
    x1_unet = unet_se_cnn(imu, unet_depth=4, base_filters=128, kernel_size=5, drop=0.3)
    x1_conv_k3 = residual_se_cnn_block(imu, 64, 3)
    x1_conv_k7 = residual_se_cnn_block(imu, 64, 7)
    
    # --- FIX: Aggregate each branch BEFORE merging ---
    # This creates a fixed-size vector from each branch, avoiding shape conflicts.
    p1 = GlobalAveragePooling1D()(x1_unet)
    p2 = GlobalAveragePooling1D()(x1_conv_k3)
    p3 = GlobalAveragePooling1D()(x1_conv_k7)
    
    # --- ToF Branch ---
    x2 = tof_block_2(tof, wd)
    p4 = GlobalAveragePooling1D()(x2)

    # Concatenate the aggregated feature vectors
    x = Concatenate()([p1, p2, p3, p4])
    
    # --- Final Classifier MLP ---
    x = Dropout(0.4)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(256, activation='relu')(x)
    
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

def create_advanced_model_5_unet_bilstm(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # Use the UNet with the BiLSTM bottleneck
    x1 = unet_se_cnn_bilstm(imu, unet_depth=3, base_filters=128, kernel_size=3)
    
    # Standard ToF branch
    x2 = tof_block_2(tof, wd)

    # --- FIX: Use the robust aggregation strategy instead of features_processing ---
    x1_pooled = GlobalAveragePooling1D()(x1)
    x2_pooled = GlobalAveragePooling1D()(x2)
    x = Concatenate()([x1_pooled, x2_pooled])

    # --- Final Classifier MLP ---
    x = Dropout(0.4)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(256, activation='relu')(x)
    
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# %%
# =====================================================================================
# 3 NEW ADVANCED MODEL ARCHITECTURES
# =====================================================================================
from src.nn_blocks import attention_layer

def create_advanced_model_A_dual_unet(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # Branch 1: A deep U-Net for the IMU data
    x1_raw = unet_se_cnn(imu, unet_depth=4, base_filters=128, kernel_size=5, drop=0.3)
    
    # Branch 2: A parallel, slightly lighter U-Net for the ToF/Thermal data
    x2_raw = unet_se_cnn(tof, unet_depth=3, base_filters=64, kernel_size=5, drop=0.3)

    # --- FIX: Project both branches to a common feature dimension (e.g., 128) ---
    # This ensures the input to features_processing is consistent.
    x1 = Conv1D(128, 1, padding='same', activation='relu', name='imu_projection')(x1_raw)
    x2 = Conv1D(128, 1, padding='same', activation='relu', name='tof_projection')(x2_raw)
    
    # Now both x1 and x2 have shape (None, 128, 128)
    # They can be safely passed to the features_processing block.
    x = features_processing(x1, x2)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Advanced Model B: Cross-Attention Fusion ---
# Hypothesis: Instead of just concatenating the IMU and ToF branches, we can create
# richer features by allowing them to "talk to each other." The IMU branch will learn
# what to pay attention to in the ToF data, and vice-versa.
def create_advanced_model_B_cross_attention(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # 1. Create strong, downsampled feature representations for both branches
    # Output Shape for both: (None, 32, 128)
    x1 = residual_se_cnn_block(imu, 64, 3, drop=0.2, wd=wd)
    x1 = residual_se_cnn_block(x1, 128, 5, drop=0.2, wd=wd)
    
    x2 = tof_block_2(tof, wd)

    # 2. Cross-Attention Fusion
    # The IMU branch queries the ToF branch for relevant context
    imu_attends_tof = tf.keras.layers.Attention()([x1, x2])
    # The ToF branch queries the IMU branch for relevant context
    tof_attends_imu = tf.keras.layers.Attention()([x2, x1])
    
    # 3. Create an enriched representation by concatenating all perspectives
    # The final tensor contains the original features plus the context-aware features.
    # Shape: (None, 32, 128 + 128 + 128 + 128) = (None, 32, 512)
    x = Concatenate()([x1, imu_attends_tof, x2, tof_attends_imu])
    
    # 4. Final Processing
    # We use a powerful sequence processor on this ultra-rich tensor
    x = Bidirectional(GRU(256, return_sequences=True, kernel_regularizer=l2(wd)))(x)
    x = attention_layer(x)
    
    x = Dropout(0.4)(x)
    x = Dense(256, activation='relu')(x)
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Advanced Model C: Stacked Hybrid Blocks ---
# Hypothesis: A single block of (CNN -> RNN) is good. Repeatedly stacking this
# hybrid block will allow the model to learn progressively more abstract and

# powerful spatio-temporal features.
def cnn_lstm_block(x, filters, kernel_size, drop=0.2, wd=1e-4):
    # A self-contained, reusable block
    x = residual_se_cnn_block(x, filters, kernel_size, drop=drop, wd=wd)
    x = Bidirectional(LSTM(filters, return_sequences=True, kernel_regularizer=l2(wd)))(x)
    return x

def create_advanced_model_C_stacked_hybrid(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # --- IMU Branch: Stacked Hybrid Blocks ---
    # Each block refines the output of the previous one
    # Input: (128, D) -> Block1: (64, 128) -> Block2: (32, 256)
    x1 = cnn_lstm_block(imu, 64, 3)
    x1 = cnn_lstm_block(x1, 128, 5)
    
    # --- ToF Branch ---
    # Output: (32, 128)
    x2 = tof_block_2(tof, wd)
    # Project ToF features to match the final IMU feature dimension (256)
    x2_projected = Dense(256, activation='relu')(x2)

    # Now both inputs have shape (None, 32, 256) and can be processed
    x = features_processing(x1, x2_projected)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# %%
# =====================================================================================
# 3 NEW ADVANCED MODEL ARCHITECTURES
# =====================================================================================

# --- Advanced Model A: BERT-Fusion (Keras Implementation) ---
# Hypothesis: Using a Transformer (BERT) as a late-stage fusion layer for features
# from three separate, specialized branches will create the most powerful representation.
# This is a direct translation of the PyTorch model's core idea.
def create_advanced_model_A_bert_fusion(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof_and_thm = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)
    
    # We need to split ToF and Thermal for separate processing
    # Assuming thm_cols are the first 5 in the tof_and_thm tensor
    thm = tf.keras.layers.Lambda(lambda t: t[:, :, :5])(tof_and_thm)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, 5:])(tof_and_thm)

    # 1. Create three separate feature extraction branches
    # IMU Branch
    x_imu = residual_se_cnn_block(imu, 128, 3)
    x_imu = residual_se_cnn_block(x_imu, 256, 5) # Shape: (None, 32, 256)
    
    # Thermal Branch
    x_thm = residual_se_cnn_block(thm, 64, 3)
    x_thm = residual_se_cnn_block(x_thm, 128, 5)
    x_thm = Conv1D(256, 1, padding='same', activation='relu')(x_thm) # Project to 256 features
    
    # ToF Branch
    x_tof = residual_se_cnn_block(tof, 128, 3)
    x_tof = residual_se_cnn_block(x_tof, 256, 5) # Shape: (None, 32, 256)
    
    # 2. Concatenate along the feature axis and feed into a Transformer
    # Shape: (None, 32, 256+256+256) -> (None, 32, 768)
    x = Concatenate()([x_imu, x_thm, x_tof])
    
    # Transformer (BERT-like) layers for deep fusion
    x = TransformerBlock(embed_dim=768, num_heads=8, ff_dim=1024, rate=0.2)(x)
    x = TransformerBlock(embed_dim=768, num_heads=8, ff_dim=1024, rate=0.2)(x)
    
    # 3. Use Global Pooling to aggregate the time dimension
    x = GlobalAveragePooling1D()(x)
    
    # 4. Final Classifier MLP
    x = Dropout(0.4)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Advanced Model B: Hyper-UNet ---
# Hypothesis: Since U-Nets are the top performers, an even deeper and wider U-Net
# with more filters and a deeper encoder/decoder structure will capture more complex features.
def create_advanced_model_B_hyper_unet(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # Branch 1: A very deep and wide U-Net for IMU data
    # unet_depth=5 creates a very deep model, base_filters=128 makes it wide.
    x1 = unet_se_cnn(imu, unet_depth=5, base_filters=128, kernel_size=5, drop=0.3)
    
    # Branch 2: A standard ToF block
    x2 = tof_block_2(tof, wd)

    # Project both branches to a common, large feature dimension before merging
    x1_proj = Conv1D(128, 1, padding='same', activation='relu')(x1)
    x2_proj = Conv1D(128, 1, padding='same', activation='relu')(x2)
    
    # Use the standard features_processing block to merge and classify
    x = features_processing(x1_proj, x2_proj)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# --- Advanced Model C: Parallel UNet-Transformer Hybrid ---
# Hypothesis: The IMU signal contains both local patterns (best for U-Net) and global
# context (best for Transformer). Processing the IMU with both backbones in parallel
# and fusing their outputs will create the ultimate feature representation.
def create_advanced_model_C_parallel_hybrid(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # --- IMU Branch is now two parallel streams ---
    
    # Stream 1: U-Net for multi-resolution analysis
    imu_unet = unet_se_cnn(imu, unet_depth=4, base_filters=128, kernel_size=5)
    
    # Stream 2: CNN -> Transformer Tower for global context
    imu_cnn = residual_se_cnn_block(imu, 64, 3)
    imu_cnn = residual_se_cnn_block(imu_cnn, 128, 5) # Shape: (None, 32, 128)
    imu_transformer = TransformerBlock(embed_dim=128, num_heads=4, ff_dim=256)(imu_cnn)
    
    # --- Fusion of IMU streams ---
    imu_unet_matched, imu_transformer_matched = match_time_steps(imu_unet, imu_transformer)
    x1 = Concatenate()([imu_unet_matched, imu_transformer_matched]) # Shape: (None, 32, 256)
    
    # --- ToF Branch ---
    x2 = tof_block_2(tof, wd) # Shape: (None, 32, 128)

    # --- FIX: Project both branches to a common, predictable feature dimension ---
    # Let's project both to 256 features, so the merged result is 512.
    x1_proj = Conv1D(256, 1, padding='same', activation='relu', name='imu_projection')(x1)
    x2_proj = Conv1D(256, 1, padding='same', activation='relu', name='tof_projection')(x2)
    
    # Now both x1_proj and x2_proj have shape (None, 32, 256)
    # They can be safely passed to the features_processing block.
    x = features_processing(x1_proj, x2_proj)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# %%
# import polars as pl
# df = pl.read_parquet('output/imu_physics_feats.parquet')
# df.columns

# %%
from tensorflow.keras import Layer, Sequential

def ImuFeatureExtractorLayer(imu_input):
    """A Keras layer to perform on-the-fly feature engineering."""
    acc = imu_input[:, :, :3]  # Assuming raw acc_x, y, z are the first 3 features
    gyro = imu_input[:, :, 3:6] # Assuming raw rot_w,x,y,z -> angular velocity are next
    
    acc_mag = tf.norm(acc, axis=-1, keepdims=True)
    gyro_mag = tf.norm(gyro, axis=-1, keepdims=True)
    
    # Jerk (diff) requires padding to maintain time dimension
    jerk = tf.pad(acc[:, 1:, :] - acc[:, :-1, :], [[0, 0], [1, 0], [0, 0]])
    
    # Squared values
    acc_pow = tf.square(acc)
    
    # Concatenate all derived features
    return Concatenate()([acc, gyro, acc_mag, gyro_mag, jerk, acc_pow])

def create_new_model_1_in_model_fe(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    # IMPORTANT: This model expects the RAW acc/rot features, not the engineered ones.
    # You will need to adjust your data pipeline to feed the raw features.
    imu_raw = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # 1. On-the-fly feature engineering branch
    x1 = ImuFeatureExtractorLayer(imu_raw)
    
    # 2. Standard CNN backbone to process these rich features
    x1 = residual_se_cnn_block(x1, 128, 5)
    x1 = residual_se_cnn_block(x1, 256, 7)
    
    # 3. Standard ToF branch
    x2 = tof_block_2(tof, wd)

    # 4. Merge and classify
    x = features_processing(x1, x2)
    x = Dropout(0.3)(x) 
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# =====================================================================================
# 3 NEW ADVANCED PANNs-BASED MODEL ARCHITECTURES
# =====================================================================================

def create_panns_model_A_rnn_head(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # --- IMU Branch: Parallel CNNs (PANNs Backbone) ---
    # Each branch downsamples time to 32 and outputs 128 features
    k3 = residual_se_cnn_block(imu, 128, 3)
    k5 = residual_se_cnn_block(imu, 128, 5)
    k7 = residual_se_cnn_block(imu, 128, 7)
    
    # Concatenate the multi-scale features
    # Shape: (None, 32, 128 + 128 + 128) = (None, 32, 384)
    x1 = Concatenate()([k3, k5, k7])
    
    # --- ToF Branch ---
    x2 = tof_block(tof, wd) # Shape: (None, 32, 128)

    # --- Merge and Process with RNN Head ---
    # Project ToF features to match the IMU feature dimension for a cleaner merge
    x2_proj = Conv1D(384, 1, padding='same', activation='relu')(x2)
    
    # Concatenate the full feature set
    x = Concatenate()([x1, x2_proj]) # Shape: (None, 32, 384 + 384) = (None, 32, 768)
    
    # Add a powerful RNN head to learn sequential patterns from the rich features
    x = Bidirectional(GRU(384, return_sequences=True, kernel_regularizer=l2(wd)))(x)
    x = attention_layer(x) # Use attention to summarize the sequence
    
    # --- Final Classifier MLP ---
    x = Dropout(0.4)(x)
    x = Dense(256, activation='relu')(x)
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

def pann_rnn_head_feat_processing(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # --- IMU Branch: Parallel CNNs (PANNs Backbone) ---
    # Each branch downsamples time to 32 and outputs 128 features
    k3 = residual_se_cnn_block(imu, 128, 3)
    k5 = residual_se_cnn_block(imu, 128, 5)
    k7 = residual_se_cnn_block(imu, 128, 7)
    
    # Shape: (None, 32, 128 + 128 + 128) = (None, 32, 384)
    x1 = Concatenate()([k3, k5, k7])
    x2 = tof_block(tof, wd) # Shape: (None, 32, 128)
    x2_proj = Conv1D(384, 1, padding='same', activation='relu')(x2)
    
    x = features_processing(x1, x2_proj)
    x = Dropout(0.4)(x)
    x = Dense(256, activation='relu')(x)
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# %%
def ImuFeatureExtractorLayer(imu_input):
    """A Keras layer to perform on-the-fly feature engineering."""
    acc = tf.keras.layers.Lambda(lambda t: t[:, :, :3])(imu_input)
    gyro = tf.keras.layers.Lambda(lambda t: t[:, :, 3:6])(imu_input)
    
    # --- THIS IS THE FIX ---
    # Wrap each raw TensorFlow function in a Keras Lambda layer.
    
    acc_mag = tf.keras.layers.Lambda(lambda t: tf.norm(t, axis=-1, keepdims=True))(acc)
    gyro_mag = tf.keras.layers.Lambda(lambda t: tf.norm(t, axis=-1, keepdims=True))(gyro)
    
    # The tf.pad function also needs to be wrapped.
    jerk = tf.keras.layers.Lambda(
        lambda t: tf.pad(t[:, 1:, :] - t[:, :-1, :], [[0, 0], [1, 0], [0, 0]])
    )(acc)
    
    # tf.square is a simple operation, but for consistency, we can wrap it too.
    acc_pow = tf.keras.layers.Lambda(tf.square)(acc)
    
    # Concatenate all the resulting KerasTensors
    return Concatenate()([acc, gyro, acc_mag, gyro_mag, jerk, acc_pow])

def create_new_model_1_in_model_fe(input_shape, imu_dim, wd=1e-4):
    inp = tf.keras.layers.Input(shape=input_shape)
    imu_raw = tf.keras.layers.Lambda(lambda t: t[:, :, :imu_dim])(inp)
    tof = tf.keras.layers.Lambda(lambda t: t[:, :, imu_dim:])(inp)

    # 1. On-the-fly feature engineering branch
    x1 = ImuFeatureExtractorLayer(imu_raw)
    
    # 2. Standard CNN backbone to process these rich features
    x1 = residual_se_cnn_block(x1, 128, 5)
    x1 = residual_se_cnn_block(x1, 256, 7)
    
    # 3. Standard ToF branch
    x2 = tof_block_2(tof, wd)

    # --- FIX: Aggregate each branch BEFORE merging ---
    # This creates fixed-size vectors and avoids all shape conflicts.
    x1_pooled = GlobalAveragePooling1D()(x1)
    x2_pooled = GlobalAveragePooling1D()(x2)
    
    # Concatenate the aggregated feature vectors
    x = Concatenate()([x1_pooled, x2_pooled])
    
    # --- Final Classifier MLP ---
    x = Dropout(0.4)(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.3)(x)
    x = Dense(256, activation='relu')(x)
    
    main_out = Dense(NUM_CLASSES, activation="softmax", name="main_output")(x)
    gate_out = Dense(1, activation="sigmoid", name="tof_gate")(x)
    
    return Model(inputs=inp, outputs={"main_output": main_out, "tof_gate": gate_out})

# %%
def generate_tof_features_for_inference(df: pl.DataFrame) -> pl.DataFrame:
    decay_weights = np.power(0.9, np.arange(64))
    x_coords, y_coords = np.meshgrid(np.arange(8), np.arange(8))
    feature_expressions = []
    for i in range(1, 6):
        pixel_cols = [f"tof_{i}_v{p}" for p in range(64)]
        if not all(col in df.columns for col in pixel_cols): continue
        list_expr = pl.concat_list([pl.when(pl.col(c) == -1).then(None).otherwise(pl.col(c)) for c in pixel_cols]).alias(f"tof_{i}_list")
        feature_expressions.extend([list_expr.list.mean().alias(f'tof_{i}_mean'), list_expr.list.std().alias(f'tof_{i}_std'),
                                    list_expr.list.min().alias(f'tof_{i}_min'), list_expr.list.max().alias(f'tof_{i}_max'),
                                    list_expr.list.median().alias(f'tof_{i}_median'), list_expr.list.diff().list.mean().alias(f'tof_{i}_diff_mean'),
                                    list_expr.list.drop_nulls().list.len().alias(f'tof_{i}_active_pixels'),
                                    # list_expr.list.drop_nulls().map_elements(pl_skew, return_dtype=pl.Float64).alias(f'tof_{i}_skew'),
                                    # list_expr.list.drop_nulls().map_elements(pl_kurtosis, return_dtype=pl.Float64).alias(f'tof_{i}_kurtosis')
                                    ])
        tof_data_exprs = [pl.when(pl.col(c) == -1).then(None).otherwise(pl.col(c)) for c in pixel_cols]
        feature_expressions.append(pl.sum_horizontal([(expr * weight).fill_null(0) for expr, weight in zip(tof_data_exprs, decay_weights)]).alias(f'tof_{i}_mean_decay'))
        weights_exprs = [(1 / (expr + 1e-6)).fill_null(0) for expr in tof_data_exprs]
        total_weight_expr = pl.sum_horizontal(weights_exprs)
        centroid_x_expr = pl.when(total_weight_expr > 1e-9).then(pl.sum_horizontal([(w * c) for w, c in zip(weights_exprs, x_coords.ravel())]) / total_weight_expr).otherwise(None)
        centroid_y_expr = pl.when(total_weight_expr > 1e-9).then(pl.sum_horizontal([(w * c) for w, c in zip(weights_exprs, y_coords.ravel())]) / total_weight_expr).otherwise(None)
        feature_expressions.extend([centroid_x_expr.alias(f'tof_{i}_centroid_x'), centroid_y_expr.alias(f'tof_{i}_centroid_y')])
    if feature_expressions:
        df = df.with_columns(feature_expressions)
    return df

# %%
# =====================================================================================
# CONFIGURATION
# =====================================================================================
LR_INIT = 5e-4
WD = 3e-3
NUM_CLASSES = 18
BATCH_SIZE = 64
N_SPLITS = 5 
MAX_PAD_LEN = 128
FEATURE_DIR = Path('output')
RAW_DIR = Path('input/cmi-detect-behavior-with-sensor-data')
RANDOM_STATE = 42
SAMPLING_RATE_HZ = 200 # Use the correct sampling rate

from src.merge_feats_dynamic import merge_feature_sets
from src.functions import create_sequence_dataset, generate_gate_targets, train_model
from src.imu_physics_feats import calculate_angular_velocity
from src.nn_blocks import GatedMixupGenerator

# =====================================================================================
# TRAINING LOGIC
# =====================================================================================


final_df = pl.read_parquet(FEATURE_DIR / "cleaned_base_train_data.parquet")
demographics_df = pl.read_csv(RAW_DIR / "train_demographics.csv")
final_df = final_df.join(demographics_df, on='subject', how='left')
meta_cols = ['sequence_id', 'sequence_counter', 'subject', 'gesture']


le = LabelEncoder()
gesture_encoded = le.fit_transform(final_df.get_column('gesture'))
final_df = final_df.with_columns(pl.Series("gesture_int", gesture_encoded))  
print(f"  Final merged DataFrame created with shape: {final_df.shape}")

all_columns = final_df.columns
thm_cols = [c for c in all_columns if c.startswith('thm')]
tof_cols = [c for c in all_columns if c.startswith('tof')]
imu_cols = [c for c in all_columns if c.startswith('acc_') or c.startswith('rot_')]
# 2. Create the final, ordered list of all features.
all_feature_cols = imu_cols + thm_cols + tof_cols
imu_dim = len(imu_cols)
print(f"  Training with {len(all_feature_cols)} total features ({imu_dim} IMU, {len(tof_cols)} ToF/Thm).")    

# 3. Reorder the DataFrame to match the required structure for the model.
metadata_to_keep = ['sequence_id', 'sequence_counter', 'gesture', 'gesture_int', 'subject']
final_df = final_df.select(metadata_to_keep + all_feature_cols)
print("  DataFrame columns have been reordered for the model.")

# --- Step 3: Prepare for Cross-Validation ---
cv_info = final_df.group_by("sequence_id").agg(pl.first("gesture_int")).sort("sequence_id")
all_sequence_ids = cv_info.get_column("sequence_id").to_numpy()
y_for_split = cv_info.get_column("gesture_int").to_numpy()

input_shape = (MAX_PAD_LEN, len(all_feature_cols)) 

model_results = {}

# Your new list of experiments
model_builders = [
    ("fe_nn_model", lambda: create_new_model_1_in_model_fe(input_shape, imu_dim)),
]

print("  Loading clean base DataFrame...")
final_df = pl.read_parquet(FEATURE_DIR / "cleaned_base_train_data.parquet")
demographics_df = pl.read_csv(RAW_DIR / "train_demographics.csv")
final_df = final_df.join(demographics_df, on='subject', how='left')

le = LabelEncoder()
gesture_encoded = le.fit_transform(final_df.get_column('gesture'))
final_df = final_df.with_columns(pl.Series("gesture_int", gesture_encoded))  

# --- Step 2: Engineer ToF/Thm Features ---
# We must create the engineered ToF/Thm features as the model expects them.
print("  Engineering ToF/Thermal features...")
final_df = generate_tof_features_for_inference(final_df) # Assuming this function is defined

# --- Step 3: Define the specific feature columns for THIS model ---
# This model requires RAW IMU features and ENGINEERED ToF/Thm features.

# Raw IMU features for the on-the-fly feature extractor layer
# IMPORTANT: The ImuFeatureExtractorLayer expects acc_x,y,z then angular_vel_x,y,z.
# We must calculate angular velocity here.

grouped = final_df.partition_by("sequence_id", maintain_order=True)
angular_vel_dfs = []
for group in grouped:
    rot_df = group.select(["rot_x", "rot_y", "rot_z", "rot_w"])
    angular_vel = calculate_angular_velocity(rot_df, SAMPLING_RATE_HZ)
    av_df = pl.DataFrame(angular_vel, schema=["angular_vel_x", "angular_vel_y", "angular_vel_z"])
    av_df = av_df.with_columns(pl.Series("sequence_counter", group["sequence_counter"]))
    av_df = av_df.with_columns(pl.Series("sequence_id", group["sequence_id"]))
    angular_vel_dfs.append(av_df)
angular_vel_df = pl.concat(angular_vel_dfs)
final_df = final_df.join(angular_vel_df, on=['sequence_id', 'sequence_counter'], how='left').fill_null(0)

raw_imu_cols = [
    'acc_x', 'acc_y', 'acc_z',
    'angular_vel_x', 'angular_vel_y', 'angular_vel_z'
]

# Engineered ToF/Thm features
engineered_tof_cols = [c for c in final_df.columns if c.startswith(('tof_', 'thm_')) and '_v' not in c]

# Create the final, ordered list of all features for the model input
all_feature_cols = raw_imu_cols + engineered_tof_cols
imu_dim = len(raw_imu_cols) # The split point is the number of RAW features
print(f"  Training with {len(all_feature_cols)} total features ({imu_dim} raw IMU).")    

# Reorder the DataFrame to match the required structure
metadata_to_keep = ['sequence_id', 'sequence_counter', 'gesture', 'gesture_int', 'subject']
final_df = final_df.select(metadata_to_keep + all_feature_cols)
print("  DataFrame columns have been reordered for the model.")

# --- Step 4: Prepare for Cross-Validation ---
cv_info = final_df.group_by("sequence_id").agg(pl.first("gesture_int")).sort("sequence_id")
all_sequence_ids = cv_info.get_column("sequence_id").to_numpy()
y_for_split = cv_info.get_column("gesture_int").to_numpy()

input_shape = (MAX_PAD_LEN, len(all_feature_cols)) 
model_results = {}
model_builders = [("In_Model_FE", lambda: create_new_model_1_in_model_fe(input_shape, imu_dim))]

for model_name, model_builder in model_builders:
    print("\n" + "="*60)
    print(f"▶ Training and Evaluating Model: {model_name}")
    print("="*60)

    kf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=RANDOM_STATE)
    fold_accuracies = []
    all_preds = []
    all_labels = []
    best_epochs = []

    for fold_idx, (train_indices, val_indices) in enumerate(kf.split(all_sequence_ids, y_for_split)):
        print(f"\n=== Fold {fold_idx + 1}/{N_SPLITS} for {model_name} ===")
        train_ids = all_sequence_ids[train_indices]
        val_ids = all_sequence_ids[val_indices]

        train_df = final_df.filter(pl.col('sequence_id').is_in(train_ids))
        val_df = final_df.filter(pl.col('sequence_id').is_in(val_ids))
        
        scaler = StandardScaler()
        train_features_scaled = scaler.fit_transform(train_df.select(all_feature_cols))
        val_features_scaled = scaler.transform(val_df.select(all_feature_cols))
        
        X_train_scaled_features = pl.DataFrame(train_features_scaled, schema=all_feature_cols)
        X_val_scaled_features = pl.DataFrame(val_features_scaled, schema=all_feature_cols)

        meta_cols_to_keep = ['sequence_id', 'sequence_counter', 'gesture_int']
        train_df_final = train_df.select(meta_cols_to_keep).with_columns(X_train_scaled_features)
        val_df_final = val_df.select(meta_cols_to_keep).with_columns(X_val_scaled_features)

        # The gate target needs to be based on the raw ToF columns
        train_gate_target_df = generate_gate_targets(train_df, [c for c in train_df.columns if c.startswith('tof_v')])
        val_gate_target_df = generate_gate_targets(val_df, [c for c in val_df.columns if c.startswith('tof_v')])

        X_train, y_train, train_gate_target = create_sequence_dataset(train_df_final, all_feature_cols, train_gate_target_df)
        X_val, y_val, val_gate_target = create_sequence_dataset(val_df_final, all_feature_cols, val_gate_target_df)

        X_train_padded = pad_sequences(X_train, maxlen=MAX_PAD_LEN, padding='post', truncating='post', dtype='float32')
        X_val_padded = pad_sequences(X_val, maxlen=MAX_PAD_LEN, padding='post', truncating='post', dtype='float32')
        
        y_train_cat = to_categorical(y_train, num_classes=NUM_CLASSES)
        y_val_cat = to_categorical(y_val, num_classes=NUM_CLASSES)
        
        train_dataset = GatedMixupGenerator(
            X=X_train_padded, y=y_train_cat, gate_targets=train_gate_target,
            batch_size=BATCH_SIZE, imu_dim=imu_dim, alpha=0.2, masking_prob=0.25
        )
        val_dataset = tf.data.Dataset.from_tensor_slices((
            X_val_padded, {'main_output': y_val_cat, 'tof_gate': val_gate_target[:, np.newaxis]}
        )).batch(BATCH_SIZE).cache().prefetch(tf.data.AUTOTUNE)

        del X_train, y_train, X_val, y_val, X_train_padded, X_val_padded
        gc.collect()
        
        model = model_builder()
        history = train_model(model, train_dataset, val_dataset, 150, LR_INIT, WD)
    
        monitor_metric = 'val_main_output_accuracy' if isinstance(model.output, dict) else 'val_accuracy'
        best_epoch = np.argmax(history.history[monitor_metric]) + 1
        best_epochs.append(best_epoch)
        print(f"--- Fold {fold_idx + 1} Best Epoch: {best_epoch} ---")

        # --- EVALUATION ---
        val_preds = model.predict(val_dataset)
        main_output_preds = val_preds['main_output']
        
        y_pred_fold = np.argmax(main_output_preds, axis=1)
        y_true_fold = np.argmax(y_val_cat, axis=1)
        fold_acc = accuracy_score(y_true_fold, y_pred_fold)
        fold_accuracies.append(fold_acc)
        print(f"Fold {fold_idx + 1} Accuracy: {fold_acc:.4f}")
        all_preds.append(y_pred_fold)
        all_labels.append(y_true_fold)

        del train_dataset, model, val_dataset
        gc.collect()

    # --- FINAL OOF REPORT for this model architecture ---
    print(f"\n=== OOF Summary for {model_name} ===")
    print(f"Per-fold Accuracies: {[round(a, 4) for a in fold_accuracies]}")
    print(f"Mean Accuracy: {np.mean(fold_accuracies):.4f} ± {np.std(fold_accuracies):.4f}")
    
    # --- NEW: Report on the best epochs found ---
    avg_best_epoch = int(np.mean(best_epochs))
    print(f"Best epochs per fold: {best_epochs}")
    print(f"Average best epoch: {avg_best_epoch}")
    
    # Store the results for this model
    model_results[model_name] = {
        'mean_accuracy': np.mean(fold_accuracies),
        'avg_best_epoch': avg_best_epoch
    }

    y_all_pred = np.concatenate(all_preds)
    y_all_true = np.concatenate(all_labels)
    print("\n=== Overall Classification Report ===")
    print(classification_report(y_all_true, y_all_pred, target_names=le.classes_, digits=4))

# --- FINAL SUMMARY ACROSS ALL MODELS ---
print("\n" + "="*60)
print("▶ FINAL MODEL EXPERIMENT SUMMARY")
print("="*60)
for model_name, results in model_results.items():
    print(f"  - {model_name}: Mean Accuracy = {results['mean_accuracy']:.4f}, Avg Best Epoch = {results['avg_best_epoch']}")
# Out:
#   Final merged DataFrame created with shape: (574945, 356)
#   Training with 332 total features (7 IMU, 320 ToF/Thm).
#   DataFrame columns have been reordered for the model.
#   Loading clean base DataFrame...
#   Engineering ToF/Thermal features...
#   Training with 61 total features (6 raw IMU).
#   DataFrame columns have been reordered for the model.
#
# ============================================================
# ▶ Training and Evaluating Model: In_Model_FE
# ============================================================
#
# === Fold 1/5 for In_Model_FE ===
# I0000 00:00:1755979285.256308 4081569 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4714 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2025-08-23 21:01:25.268325: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 50939392 exceeds 10% of free system memory.
# 2025-08-23 21:01:25.542469: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 50939392 exceeds 10% of free system memory.
# LR Scheduler: 102 steps per epoch, 15300 total decay steps.
# Epoch 1/150
# /home/uallende/projects/kaggle/CMI/.venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755979295.032878 4081826 service.cc:152] XLA service 0x7b02a8001b80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1755979295.032926 4081826 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce GTX 1060, Compute Capability 6.1
# 2025-08-23 21:01:35.363622: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1755979296.914054 4081826 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-08-23 21:01:39.569495: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 12.11GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-23 21:01:40.185664: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 10.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-23 21:01:42.039935: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 8.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#   7/102 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 3.1167 - main_output_accuracy: 0.0843 - main_output_loss: 2.9572 - tof_gate_loss: 0.3371
# I0000 00:00:1755979311.577409 4081826 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-08-23 21:01:54.441442: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 11.61GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-23 21:01:54.909895: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.92GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-23 21:01:57.128786: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 8.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 2.8338 - main_output_accuracy: 0.1512 - main_output_loss: 2.7241 - tof_gate_loss: 0.0928
# 2025-08-23 21:02:08.711933: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 50939392 exceeds 10% of free system memory.
# 2025-08-23 21:02:11.618407: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 10.03GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 47s 219ms/step - loss: 2.8323 - main_output_accuracy: 0.1517 - main_output_loss: 2.7227 - tof_gate_loss: 0.0923 - val_loss: 2.4670 - val_main_output_accuracy: 0.3237 - val_main_output_loss: 2.3576 - val_tof_gate_loss: 0.1002
# Epoch 2/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 2.3609 - main_output_accuracy: 0.3267 - main_output_loss: 2.2705 - tof_gate_loss: 0.0057 - val_loss: 2.0356 - val_main_output_accuracy: 0.4543 - val_main_output_loss: 1.9445 - val_tof_gate_loss: 0.0286
# Epoch 3/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 2.1989 - main_output_accuracy: 0.3979 - main_output_loss: 2.1111 - tof_gate_loss: 0.0041 - val_loss: 1.8666 - val_main_output_accuracy: 0.5089 - val_main_output_loss: 1.7819 - val_tof_gate_loss: 0.0090
# Epoch 4/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 2.0631 - main_output_accuracy: 0.4510 - main_output_loss: 1.9778 - tof_gate_loss: 0.0021 - val_loss: 1.7497 - val_main_output_accuracy: 0.5500 - val_main_output_loss: 1.6680 - val_tof_gate_loss: 0.0083
# Epoch 5/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.9868 - main_output_accuracy: 0.4947 - main_output_loss: 1.9032 - tof_gate_loss: 0.0017 - val_loss: 1.6629 - val_main_output_accuracy: 0.5812 - val_main_output_loss: 1.5822 - val_tof_gate_loss: 0.0066
# Epoch 6/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.9771 - main_output_accuracy: 0.5120 - main_output_loss: 1.8957 - tof_gate_loss: 0.0019 - val_loss: 1.6402 - val_main_output_accuracy: 0.5806 - val_main_output_loss: 1.5636 - val_tof_gate_loss: 0.0039
# Epoch 7/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.9005 - main_output_accuracy: 0.5446 - main_output_loss: 1.8208 - tof_gate_loss: 0.0011 - val_loss: 1.5787 - val_main_output_accuracy: 0.6033 - val_main_output_loss: 1.5028 - val_tof_gate_loss: 0.0023
# Epoch 8/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.8535 - main_output_accuracy: 0.5432 - main_output_loss: 1.7749 - tof_gate_loss: 9.3098e-04 - val_loss: 1.5613 - val_main_output_accuracy: 0.5984 - val_main_output_loss: 1.4876 - val_tof_gate_loss: 0.0014
# Epoch 9/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.8592 - main_output_accuracy: 0.5535 - main_output_loss: 1.7822 - tof_gate_loss: 8.6086e-04 - val_loss: 1.5937 - val_main_output_accuracy: 0.6027 - val_main_output_loss: 1.5224 - val_tof_gate_loss: 0.0049
# Epoch 10/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.8059 - main_output_accuracy: 0.5776 - main_output_loss: 1.7305 - tof_gate_loss: 9.9189e-04 - val_loss: 1.5220 - val_main_output_accuracy: 0.6315 - val_main_output_loss: 1.4501 - val_tof_gate_loss: 0.0012
# Epoch 11/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.7572 - main_output_accuracy: 0.5962 - main_output_loss: 1.6832 - tof_gate_loss: 6.5070e-04 - val_loss: 1.5045 - val_main_output_accuracy: 0.6309 - val_main_output_loss: 1.4333 - val_tof_gate_loss: 0.0022
# Epoch 12/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.7567 - main_output_accuracy: 0.5960 - main_output_loss: 1.6833 - tof_gate_loss: 6.3850e-04 - val_loss: 1.5262 - val_main_output_accuracy: 0.6137 - val_main_output_loss: 1.4568 - val_tof_gate_loss: 0.0010
# Epoch 13/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.7856 - main_output_accuracy: 0.6139 - main_output_loss: 1.7130 - tof_gate_loss: 7.4150e-04 - val_loss: 1.4474 - val_main_output_accuracy: 0.6511 - val_main_output_loss: 1.3801 - val_tof_gate_loss: 8.9233e-04
# Epoch 14/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.7340 - main_output_accuracy: 0.6223 - main_output_loss: 1.6631 - tof_gate_loss: 5.6198e-04 - val_loss: 1.4722 - val_main_output_accuracy: 0.6352 - val_main_output_loss: 1.4071 - val_tof_gate_loss: 9.9222e-04
# Epoch 15/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.7308 - main_output_accuracy: 0.6198 - main_output_loss: 1.6593 - tof_gate_loss: 4.8037e-04 - val_loss: 1.4288 - val_main_output_accuracy: 0.6646 - val_main_output_loss: 1.3632 - val_tof_gate_loss: 9.1478e-04
# Epoch 16/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.6734 - main_output_accuracy: 0.6394 - main_output_loss: 1.6029 - tof_gate_loss: 3.5784e-04 - val_loss: 1.4050 - val_main_output_accuracy: 0.6757 - val_main_output_loss: 1.3406 - val_tof_gate_loss: 5.6564e-04
# Epoch 17/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.6709 - main_output_accuracy: 0.6446 - main_output_loss: 1.6009 - tof_gate_loss: 3.5377e-04 - val_loss: 1.4315 - val_main_output_accuracy: 0.6536 - val_main_output_loss: 1.3676 - val_tof_gate_loss: 6.8612e-04
# Epoch 18/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5967 - main_output_accuracy: 0.6571 - main_output_loss: 1.5265 - tof_gate_loss: 3.0953e-04 - val_loss: 1.3975 - val_main_output_accuracy: 0.6806 - val_main_output_loss: 1.3343 - val_tof_gate_loss: 5.6299e-04
# Epoch 19/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5569 - main_output_accuracy: 0.6786 - main_output_loss: 1.4875 - tof_gate_loss: 2.7338e-04 - val_loss: 1.3861 - val_main_output_accuracy: 0.6775 - val_main_output_loss: 1.3220 - val_tof_gate_loss: 3.9218e-04
# Epoch 20/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.6330 - main_output_accuracy: 0.6599 - main_output_loss: 1.5635 - tof_gate_loss: 3.1213e-04 - val_loss: 1.4381 - val_main_output_accuracy: 0.6640 - val_main_output_loss: 1.3730 - val_tof_gate_loss: 0.0010
# Epoch 21/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.4938 - main_output_accuracy: 0.6981 - main_output_loss: 1.4243 - tof_gate_loss: 2.5021e-04 - val_loss: 1.3499 - val_main_output_accuracy: 0.6965 - val_main_output_loss: 1.2869 - val_tof_gate_loss: 3.0696e-04
# Epoch 22/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5675 - main_output_accuracy: 0.6905 - main_output_loss: 1.4987 - tof_gate_loss: 2.6749e-04 - val_loss: 1.4048 - val_main_output_accuracy: 0.6646 - val_main_output_loss: 1.3387 - val_tof_gate_loss: 4.6694e-04
# Epoch 23/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.5309 - main_output_accuracy: 0.7029 - main_output_loss: 1.4628 - tof_gate_loss: 1.9631e-04 - val_loss: 1.3398 - val_main_output_accuracy: 0.6959 - val_main_output_loss: 1.2746 - val_tof_gate_loss: 2.3809e-04
# Epoch 24/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.5260 - main_output_accuracy: 0.7138 - main_output_loss: 1.4575 - tof_gate_loss: 1.7938e-04 - val_loss: 1.3399 - val_main_output_accuracy: 0.6965 - val_main_output_loss: 1.2783 - val_tof_gate_loss: 1.5400e-04
# Epoch 25/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5787 - main_output_accuracy: 0.6964 - main_output_loss: 1.5099 - tof_gate_loss: 2.0315e-04 - val_loss: 1.3931 - val_main_output_accuracy: 0.6750 - val_main_output_loss: 1.3296 - val_tof_gate_loss: 1.6570e-04
# Epoch 26/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5416 - main_output_accuracy: 0.7003 - main_output_loss: 1.4733 - tof_gate_loss: 1.4770e-04 - val_loss: 1.3546 - val_main_output_accuracy: 0.6867 - val_main_output_loss: 1.2897 - val_tof_gate_loss: 1.5588e-04
# Epoch 27/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4164 - main_output_accuracy: 0.7310 - main_output_loss: 1.3478 - tof_gate_loss: 9.9634e-05 - val_loss: 1.3803 - val_main_output_accuracy: 0.6818 - val_main_output_loss: 1.3150 - val_tof_gate_loss: 8.5732e-05
# Epoch 28/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.4218 - main_output_accuracy: 0.7448 - main_output_loss: 1.3536 - tof_gate_loss: 1.1490e-04 - val_loss: 1.3233 - val_main_output_accuracy: 0.7167 - val_main_output_loss: 1.2598 - val_tof_gate_loss: 1.0634e-04
# Epoch 29/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.5095 - main_output_accuracy: 0.7291 - main_output_loss: 1.4411 - tof_gate_loss: 1.4076e-04 - val_loss: 1.3616 - val_main_output_accuracy: 0.7002 - val_main_output_loss: 1.2983 - val_tof_gate_loss: 1.4223e-04
# Epoch 30/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.5467 - main_output_accuracy: 0.7084 - main_output_loss: 1.4775 - tof_gate_loss: 1.7406e-04 - val_loss: 1.3312 - val_main_output_accuracy: 0.6983 - val_main_output_loss: 1.2696 - val_tof_gate_loss: 8.1786e-05
# Epoch 31/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3918 - main_output_accuracy: 0.7524 - main_output_loss: 1.3245 - tof_gate_loss: 8.9253e-05 - val_loss: 1.3312 - val_main_output_accuracy: 0.7131 - val_main_output_loss: 1.2688 - val_tof_gate_loss: 8.5319e-05
# Epoch 32/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.4609 - main_output_accuracy: 0.7438 - main_output_loss: 1.3922 - tof_gate_loss: 1.0714e-04 - val_loss: 1.2998 - val_main_output_accuracy: 0.7272 - val_main_output_loss: 1.2373 - val_tof_gate_loss: 9.7035e-05
# Epoch 33/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5169 - main_output_accuracy: 0.7361 - main_output_loss: 1.4492 - tof_gate_loss: 1.2704e-04 - val_loss: 1.3500 - val_main_output_accuracy: 0.6806 - val_main_output_loss: 1.2895 - val_tof_gate_loss: 9.6049e-05
# Epoch 34/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.5548 - main_output_accuracy: 0.7305 - main_output_loss: 1.4874 - tof_gate_loss: 1.5424e-04 - val_loss: 1.3521 - val_main_output_accuracy: 0.7008 - val_main_output_loss: 1.2918 - val_tof_gate_loss: 1.0813e-04
# Epoch 35/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.5276 - main_output_accuracy: 0.7392 - main_output_loss: 1.4587 - tof_gate_loss: 1.2613e-04 - val_loss: 1.2987 - val_main_output_accuracy: 0.7063 - val_main_output_loss: 1.2350 - val_tof_gate_loss: 7.7922e-05
# Epoch 36/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4311 - main_output_accuracy: 0.7552 - main_output_loss: 1.3636 - tof_gate_loss: 9.6021e-05 - val_loss: 1.3351 - val_main_output_accuracy: 0.7075 - val_main_output_loss: 1.2749 - val_tof_gate_loss: 3.0441e-05
# Epoch 37/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3718 - main_output_accuracy: 0.7781 - main_output_loss: 1.3037 - tof_gate_loss: 7.1437e-05 - val_loss: 1.3745 - val_main_output_accuracy: 0.6959 - val_main_output_loss: 1.3123 - val_tof_gate_loss: 4.9792e-05
# Epoch 38/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5007 - main_output_accuracy: 0.7605 - main_output_loss: 1.4320 - tof_gate_loss: 1.0619e-04 - val_loss: 1.3554 - val_main_output_accuracy: 0.7002 - val_main_output_loss: 1.2921 - val_tof_gate_loss: 3.4385e-05
# Epoch 39/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3975 - main_output_accuracy: 0.7769 - main_output_loss: 1.3289 - tof_gate_loss: 7.6071e-05 - val_loss: 1.2918 - val_main_output_accuracy: 0.7180 - val_main_output_loss: 1.2285 - val_tof_gate_loss: 3.6822e-05
# Epoch 40/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3330 - main_output_accuracy: 0.7769 - main_output_loss: 1.2644 - tof_gate_loss: 5.8001e-05 - val_loss: 1.3553 - val_main_output_accuracy: 0.7088 - val_main_output_loss: 1.2933 - val_tof_gate_loss: 4.3120e-05
# Epoch 41/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3895 - main_output_accuracy: 0.7752 - main_output_loss: 1.3221 - tof_gate_loss: 6.6455e-05 - val_loss: 1.3367 - val_main_output_accuracy: 0.7075 - val_main_output_loss: 1.2724 - val_tof_gate_loss: 1.0181e-05
# Epoch 42/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.4360 - main_output_accuracy: 0.7653 - main_output_loss: 1.3668 - tof_gate_loss: 7.7627e-05 - val_loss: 1.2819 - val_main_output_accuracy: 0.7327 - val_main_output_loss: 1.2187 - val_tof_gate_loss: 4.7058e-05
# Epoch 43/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.4076 - main_output_accuracy: 0.7820 - main_output_loss: 1.3397 - tof_gate_loss: 7.7574e-05 - val_loss: 1.3438 - val_main_output_accuracy: 0.7088 - val_main_output_loss: 1.2774 - val_tof_gate_loss: 1.5852e-05
# Epoch 44/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3331 - main_output_accuracy: 0.8003 - main_output_loss: 1.2641 - tof_gate_loss: 4.3751e-05 - val_loss: 1.3044 - val_main_output_accuracy: 0.7180 - val_main_output_loss: 1.2405 - val_tof_gate_loss: 3.2804e-05
# Epoch 45/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3870 - main_output_accuracy: 0.7930 - main_output_loss: 1.3167 - tof_gate_loss: 6.1640e-05 - val_loss: 1.2907 - val_main_output_accuracy: 0.7247 - val_main_output_loss: 1.2286 - val_tof_gate_loss: 1.8205e-05
# Epoch 46/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.4369 - main_output_accuracy: 0.7618 - main_output_loss: 1.3673 - tof_gate_loss: 8.7166e-05 - val_loss: 1.3147 - val_main_output_accuracy: 0.7204 - val_main_output_loss: 1.2525 - val_tof_gate_loss: 2.0681e-05
# Epoch 47/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3385 - main_output_accuracy: 0.8051 - main_output_loss: 1.2698 - tof_gate_loss: 5.3959e-05 - val_loss: 1.3334 - val_main_output_accuracy: 0.7094 - val_main_output_loss: 1.2682 - val_tof_gate_loss: 1.5859e-05
# Epoch 48/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3773 - main_output_accuracy: 0.8031 - main_output_loss: 1.3089 - tof_gate_loss: 5.9687e-05 - val_loss: 1.3440 - val_main_output_accuracy: 0.7112 - val_main_output_loss: 1.2811 - val_tof_gate_loss: 3.3612e-05
# Epoch 49/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3188 - main_output_accuracy: 0.8168 - main_output_loss: 1.2499 - tof_gate_loss: 4.6588e-05 - val_loss: 1.3445 - val_main_output_accuracy: 0.7124 - val_main_output_loss: 1.2828 - val_tof_gate_loss: 1.5635e-05
# Epoch 50/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3661 - main_output_accuracy: 0.7866 - main_output_loss: 1.2984 - tof_gate_loss: 5.3053e-05 - val_loss: 1.3394 - val_main_output_accuracy: 0.7216 - val_main_output_loss: 1.2774 - val_tof_gate_loss: 2.1573e-05
# Epoch 51/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2662 - main_output_accuracy: 0.8444 - main_output_loss: 1.1973 - tof_gate_loss: 2.2333e-05 - val_loss: 1.3509 - val_main_output_accuracy: 0.7026 - val_main_output_loss: 1.2850 - val_tof_gate_loss: 1.8303e-05
# Epoch 52/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.2915 - main_output_accuracy: 0.8332 - main_output_loss: 1.2224 - tof_gate_loss: 2.9767e-05 - val_loss: 1.2834 - val_main_output_accuracy: 0.7394 - val_main_output_loss: 1.2223 - val_tof_gate_loss: 1.6040e-05
# Epoch 53/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3111 - main_output_accuracy: 0.8164 - main_output_loss: 1.2415 - tof_gate_loss: 3.6062e-05 - val_loss: 1.4175 - val_main_output_accuracy: 0.6977 - val_main_output_loss: 1.3544 - val_tof_gate_loss: 8.5476e-06
# Epoch 54/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2332 - main_output_accuracy: 0.8502 - main_output_loss: 1.1640 - tof_gate_loss: 2.3504e-05 - val_loss: 1.3263 - val_main_output_accuracy: 0.7161 - val_main_output_loss: 1.2637 - val_tof_gate_loss: 1.8408e-05
# Epoch 55/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.2606 - main_output_accuracy: 0.8302 - main_output_loss: 1.1924 - tof_gate_loss: 3.7290e-05 - val_loss: 1.3531 - val_main_output_accuracy: 0.7186 - val_main_output_loss: 1.2902 - val_tof_gate_loss: 1.4785e-05
# Epoch 56/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2503 - main_output_accuracy: 0.8416 - main_output_loss: 1.1808 - tof_gate_loss: 2.7399e-05 - val_loss: 1.3402 - val_main_output_accuracy: 0.7223 - val_main_output_loss: 1.2760 - val_tof_gate_loss: 1.6230e-05
# Epoch 57/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1875 - main_output_accuracy: 0.8637 - main_output_loss: 1.1188 - tof_gate_loss: 1.9734e-05 - val_loss: 1.3226 - val_main_output_accuracy: 0.7272 - val_main_output_loss: 1.2587 - val_tof_gate_loss: 1.2448e-05
# Epoch 58/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2825 - main_output_accuracy: 0.8399 - main_output_loss: 1.2136 - tof_gate_loss: 2.9825e-05 - val_loss: 1.3341 - val_main_output_accuracy: 0.7229 - val_main_output_loss: 1.2737 - val_tof_gate_loss: 8.1328e-06
# Epoch 59/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.2545 - main_output_accuracy: 0.8408 - main_output_loss: 1.1863 - tof_gate_loss: 2.2560e-05 - val_loss: 1.3415 - val_main_output_accuracy: 0.7204 - val_main_output_loss: 1.2775 - val_tof_gate_loss: 7.8944e-06
# Epoch 60/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1817 - main_output_accuracy: 0.8702 - main_output_loss: 1.1132 - tof_gate_loss: 2.5705e-05 - val_loss: 1.3057 - val_main_output_accuracy: 0.7339 - val_main_output_loss: 1.2424 - val_tof_gate_loss: 4.8620e-06
# Epoch 61/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2649 - main_output_accuracy: 0.8501 - main_output_loss: 1.1963 - tof_gate_loss: 2.3804e-05 - val_loss: 1.3103 - val_main_output_accuracy: 0.7198 - val_main_output_loss: 1.2430 - val_tof_gate_loss: 8.4142e-06
# Epoch 62/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.3164 - main_output_accuracy: 0.8426 - main_output_loss: 1.2483 - tof_gate_loss: 2.2306e-05 - val_loss: 1.3255 - val_main_output_accuracy: 0.7345 - val_main_output_loss: 1.2640 - val_tof_gate_loss: 5.0207e-06
# Epoch 63/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1375 - main_output_accuracy: 0.8831 - main_output_loss: 1.0685 - tof_gate_loss: 9.7312e-06 - val_loss: 1.3457 - val_main_output_accuracy: 0.7161 - val_main_output_loss: 1.2846 - val_tof_gate_loss: 7.1286e-06
# Epoch 64/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2234 - main_output_accuracy: 0.8740 - main_output_loss: 1.1548 - tof_gate_loss: 1.5522e-05 - val_loss: 1.3008 - val_main_output_accuracy: 0.7321 - val_main_output_loss: 1.2377 - val_tof_gate_loss: 7.6264e-06
# Epoch 65/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1214 - main_output_accuracy: 0.9010 - main_output_loss: 1.0529 - tof_gate_loss: 9.6012e-06 - val_loss: 1.3176 - val_main_output_accuracy: 0.7449 - val_main_output_loss: 1.2559 - val_tof_gate_loss: 1.1530e-05
# Epoch 66/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1518 - main_output_accuracy: 0.8881 - main_output_loss: 1.0834 - tof_gate_loss: 1.1926e-05 - val_loss: 1.3589 - val_main_output_accuracy: 0.7149 - val_main_output_loss: 1.2981 - val_tof_gate_loss: 7.7086e-06
# Epoch 67/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1428 - main_output_accuracy: 0.8881 - main_output_loss: 1.0746 - tof_gate_loss: 1.3702e-05 - val_loss: 1.3909 - val_main_output_accuracy: 0.7106 - val_main_output_loss: 1.3316 - val_tof_gate_loss: 4.4350e-06
# Epoch 68/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1580 - main_output_accuracy: 0.8809 - main_output_loss: 1.0895 - tof_gate_loss: 1.8598e-05 - val_loss: 1.2953 - val_main_output_accuracy: 0.7437 - val_main_output_loss: 1.2351 - val_tof_gate_loss: 3.4015e-06
# Epoch 69/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.2314 - main_output_accuracy: 0.8713 - main_output_loss: 1.1636 - tof_gate_loss: 1.7009e-05 - val_loss: 1.3357 - val_main_output_accuracy: 0.7351 - val_main_output_loss: 1.2742 - val_tof_gate_loss: 4.3168e-06
# Epoch 70/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1958 - main_output_accuracy: 0.8619 - main_output_loss: 1.1280 - tof_gate_loss: 1.6729e-05 - val_loss: 1.3426 - val_main_output_accuracy: 0.7333 - val_main_output_loss: 1.2805 - val_tof_gate_loss: 6.6555e-06
# Epoch 71/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 1.1737 - main_output_accuracy: 0.8899 - main_output_loss: 1.1059 - tof_gate_loss: 1.1699e-05 - val_loss: 1.3095 - val_main_output_accuracy: 0.7351 - val_main_output_loss: 1.2486 - val_tof_gate_loss: 3.4272e-06
# Epoch 72/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.1019 - main_output_accuracy: 0.8991 - main_output_loss: 1.0342 - tof_gate_loss: 7.6839e-06 - val_loss: 1.3181 - val_main_output_accuracy: 0.7339 - val_main_output_loss: 1.2563 - val_tof_gate_loss: 3.8642e-06
# Epoch 73/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1942 - main_output_accuracy: 0.8839 - main_output_loss: 1.1269 - tof_gate_loss: 1.2564e-05 - val_loss: 1.3302 - val_main_output_accuracy: 0.7327 - val_main_output_loss: 1.2703 - val_tof_gate_loss: 2.4209e-06
# Epoch 74/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1577 - main_output_accuracy: 0.8922 - main_output_loss: 1.0903 - tof_gate_loss: 9.9191e-06 - val_loss: 1.3397 - val_main_output_accuracy: 0.7290 - val_main_output_loss: 1.2799 - val_tof_gate_loss: 3.4126e-06
# Epoch 75/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1346 - main_output_accuracy: 0.8847 - main_output_loss: 1.0674 - tof_gate_loss: 1.0931e-05 - val_loss: 1.3616 - val_main_output_accuracy: 0.7253 - val_main_output_loss: 1.3040 - val_tof_gate_loss: 5.4241e-06
# Epoch 76/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1692 - main_output_accuracy: 0.8964 - main_output_loss: 1.1015 - tof_gate_loss: 1.2120e-05 - val_loss: 1.3530 - val_main_output_accuracy: 0.7278 - val_main_output_loss: 1.2915 - val_tof_gate_loss: 4.0796e-06
# Epoch 77/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.1149 - main_output_accuracy: 0.8899 - main_output_loss: 1.0479 - tof_gate_loss: 1.0859e-05 - val_loss: 1.3228 - val_main_output_accuracy: 0.7413 - val_main_output_loss: 1.2641 - val_tof_gate_loss: 2.2376e-06
# Epoch 78/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0733 - main_output_accuracy: 0.9246 - main_output_loss: 1.0064 - tof_gate_loss: 6.6315e-06 - val_loss: 1.3782 - val_main_output_accuracy: 0.7161 - val_main_output_loss: 1.3172 - val_tof_gate_loss: 2.1227e-06
# Epoch 79/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0864 - main_output_accuracy: 0.9042 - main_output_loss: 1.0199 - tof_gate_loss: 8.7598e-06 - val_loss: 1.3192 - val_main_output_accuracy: 0.7364 - val_main_output_loss: 1.2582 - val_tof_gate_loss: 2.3319e-06
# Epoch 80/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0947 - main_output_accuracy: 0.9111 - main_output_loss: 1.0286 - tof_gate_loss: 9.2660e-06 - val_loss: 1.3014 - val_main_output_accuracy: 0.7431 - val_main_output_loss: 1.2406 - val_tof_gate_loss: 6.2305e-06
# Epoch 81/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1212 - main_output_accuracy: 0.8993 - main_output_loss: 1.0559 - tof_gate_loss: 1.0674e-05 - val_loss: 1.3476 - val_main_output_accuracy: 0.7339 - val_main_output_loss: 1.2882 - val_tof_gate_loss: 1.6059e-06
# Epoch 82/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.2036 - main_output_accuracy: 0.9004 - main_output_loss: 1.1376 - tof_gate_loss: 1.3094e-05 - val_loss: 1.3239 - val_main_output_accuracy: 0.7382 - val_main_output_loss: 1.2659 - val_tof_gate_loss: 3.3027e-06
# Epoch 83/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0914 - main_output_accuracy: 0.9173 - main_output_loss: 1.0269 - tof_gate_loss: 1.0066e-05 - val_loss: 1.3054 - val_main_output_accuracy: 0.7474 - val_main_output_loss: 1.2457 - val_tof_gate_loss: 2.9438e-06
# Epoch 84/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1303 - main_output_accuracy: 0.9153 - main_output_loss: 1.0647 - tof_gate_loss: 7.0861e-06 - val_loss: 1.3497 - val_main_output_accuracy: 0.7339 - val_main_output_loss: 1.2901 - val_tof_gate_loss: 2.7633e-06
# Epoch 85/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.2061 - main_output_accuracy: 0.8939 - main_output_loss: 1.1411 - tof_gate_loss: 1.1199e-05 - val_loss: 1.3950 - val_main_output_accuracy: 0.7229 - val_main_output_loss: 1.3395 - val_tof_gate_loss: 3.2146e-06
# Epoch 86/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0195 - main_output_accuracy: 0.9297 - main_output_loss: 0.9538 - tof_gate_loss: 6.8556e-06 - val_loss: 1.3380 - val_main_output_accuracy: 0.7364 - val_main_output_loss: 1.2802 - val_tof_gate_loss: 2.8209e-06
# Epoch 87/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2117 - main_output_accuracy: 0.8889 - main_output_loss: 1.1465 - tof_gate_loss: 1.1193e-05 - val_loss: 1.3255 - val_main_output_accuracy: 0.7449 - val_main_output_loss: 1.2712 - val_tof_gate_loss: 2.0558e-06
# Epoch 88/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0962 - main_output_accuracy: 0.9225 - main_output_loss: 1.0314 - tof_gate_loss: 5.9723e-06 - val_loss: 1.3258 - val_main_output_accuracy: 0.7357 - val_main_output_loss: 1.2667 - val_tof_gate_loss: 2.7372e-06
# Epoch 89/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1445 - main_output_accuracy: 0.9099 - main_output_loss: 1.0795 - tof_gate_loss: 7.5077e-06 - val_loss: 1.3028 - val_main_output_accuracy: 0.7364 - val_main_output_loss: 1.2439 - val_tof_gate_loss: 3.3538e-06
# Epoch 90/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.2072 - main_output_accuracy: 0.8834 - main_output_loss: 1.1419 - tof_gate_loss: 8.7670e-06 - val_loss: 1.3025 - val_main_output_accuracy: 0.7498 - val_main_output_loss: 1.2474 - val_tof_gate_loss: 2.2093e-06
# Epoch 91/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0688 - main_output_accuracy: 0.9295 - main_output_loss: 1.0044 - tof_gate_loss: 5.5740e-06 - val_loss: 1.3107 - val_main_output_accuracy: 0.7529 - val_main_output_loss: 1.2527 - val_tof_gate_loss: 1.2137e-06
# Epoch 92/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1416 - main_output_accuracy: 0.9201 - main_output_loss: 1.0777 - tof_gate_loss: 6.4760e-06 - val_loss: 1.3499 - val_main_output_accuracy: 0.7308 - val_main_output_loss: 1.2950 - val_tof_gate_loss: 3.4382e-06
# Epoch 93/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0673 - main_output_accuracy: 0.9201 - main_output_loss: 1.0052 - tof_gate_loss: 7.0048e-06 - val_loss: 1.3283 - val_main_output_accuracy: 0.7400 - val_main_output_loss: 1.2718 - val_tof_gate_loss: 1.0336e-06
# Epoch 94/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0419 - main_output_accuracy: 0.9328 - main_output_loss: 0.9787 - tof_gate_loss: 4.5703e-06 - val_loss: 1.3332 - val_main_output_accuracy: 0.7462 - val_main_output_loss: 1.2734 - val_tof_gate_loss: 1.5887e-06
# Epoch 95/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.0466 - main_output_accuracy: 0.9294 - main_output_loss: 0.9829 - tof_gate_loss: 4.1274e-06 - val_loss: 1.3388 - val_main_output_accuracy: 0.7400 - val_main_output_loss: 1.2806 - val_tof_gate_loss: 1.4686e-06
# Epoch 96/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.9912 - main_output_accuracy: 0.9386 - main_output_loss: 0.9276 - tof_gate_loss: 3.7363e-06 - val_loss: 1.3374 - val_main_output_accuracy: 0.7376 - val_main_output_loss: 1.2800 - val_tof_gate_loss: 2.0186e-06
# Epoch 97/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0372 - main_output_accuracy: 0.9229 - main_output_loss: 0.9748 - tof_gate_loss: 4.6460e-06 - val_loss: 1.3710 - val_main_output_accuracy: 0.7376 - val_main_output_loss: 1.3118 - val_tof_gate_loss: 1.5436e-06
# Epoch 98/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0116 - main_output_accuracy: 0.9499 - main_output_loss: 0.9479 - tof_gate_loss: 3.3257e-06 - val_loss: 1.3328 - val_main_output_accuracy: 0.7443 - val_main_output_loss: 1.2784 - val_tof_gate_loss: 1.3910e-06
# Epoch 99/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0867 - main_output_accuracy: 0.9026 - main_output_loss: 1.0239 - tof_gate_loss: 6.1564e-06 - val_loss: 1.3033 - val_main_output_accuracy: 0.7492 - val_main_output_loss: 1.2478 - val_tof_gate_loss: 1.4040e-06
# Epoch 100/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.1311 - main_output_accuracy: 0.9071 - main_output_loss: 1.0677 - tof_gate_loss: 6.6236e-06 - val_loss: 1.3043 - val_main_output_accuracy: 0.7615 - val_main_output_loss: 1.2476 - val_tof_gate_loss: 2.4508e-06
# Epoch 101/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1151 - main_output_accuracy: 0.8977 - main_output_loss: 1.0527 - tof_gate_loss: 7.7435e-06 - val_loss: 1.3053 - val_main_output_accuracy: 0.7498 - val_main_output_loss: 1.2500 - val_tof_gate_loss: 1.4404e-06
# Epoch 102/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0737 - main_output_accuracy: 0.9273 - main_output_loss: 1.0114 - tof_gate_loss: 4.6017e-06 - val_loss: 1.3236 - val_main_output_accuracy: 0.7462 - val_main_output_loss: 1.2686 - val_tof_gate_loss: 1.4655e-06
# Epoch 103/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0676 - main_output_accuracy: 0.9295 - main_output_loss: 1.0054 - tof_gate_loss: 3.3889e-06 - val_loss: 1.3081 - val_main_output_accuracy: 0.7523 - val_main_output_loss: 1.2536 - val_tof_gate_loss: 2.1501e-06
# Epoch 104/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.1750 - main_output_accuracy: 0.9011 - main_output_loss: 1.1136 - tof_gate_loss: 5.4487e-06 - val_loss: 1.3190 - val_main_output_accuracy: 0.7425 - val_main_output_loss: 1.2626 - val_tof_gate_loss: 1.0767e-06
# Epoch 105/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0750 - main_output_accuracy: 0.9135 - main_output_loss: 1.0132 - tof_gate_loss: 4.5679e-06 - val_loss: 1.3219 - val_main_output_accuracy: 0.7443 - val_main_output_loss: 1.2659 - val_tof_gate_loss: 1.6374e-06
# Epoch 106/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0195 - main_output_accuracy: 0.9414 - main_output_loss: 0.9580 - tof_gate_loss: 3.5295e-06 - val_loss: 1.3192 - val_main_output_accuracy: 0.7492 - val_main_output_loss: 1.2630 - val_tof_gate_loss: 1.3849e-06
# Epoch 107/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.1081 - main_output_accuracy: 0.9243 - main_output_loss: 1.0468 - tof_gate_loss: 3.8052e-06 - val_loss: 1.3338 - val_main_output_accuracy: 0.7406 - val_main_output_loss: 1.2782 - val_tof_gate_loss: 1.4619e-06
# Epoch 108/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0047 - main_output_accuracy: 0.9627 - main_output_loss: 0.9440 - tof_gate_loss: 2.4096e-06 - val_loss: 1.3159 - val_main_output_accuracy: 0.7590 - val_main_output_loss: 1.2617 - val_tof_gate_loss: 1.5261e-06
# Epoch 109/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.1055 - main_output_accuracy: 0.9331 - main_output_loss: 1.0439 - tof_gate_loss: 4.3447e-06 - val_loss: 1.3251 - val_main_output_accuracy: 0.7498 - val_main_output_loss: 1.2733 - val_tof_gate_loss: 1.2305e-06
# Epoch 110/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0881 - main_output_accuracy: 0.9234 - main_output_loss: 1.0264 - tof_gate_loss: 4.0055e-06 - val_loss: 1.3234 - val_main_output_accuracy: 0.7431 - val_main_output_loss: 1.2701 - val_tof_gate_loss: 9.8956e-07
# Epoch 111/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.9851 - main_output_accuracy: 0.9515 - main_output_loss: 0.9247 - tof_gate_loss: 2.2227e-06 - val_loss: 1.3115 - val_main_output_accuracy: 0.7498 - val_main_output_loss: 1.2584 - val_tof_gate_loss: 1.8334e-06
# Epoch 112/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0943 - main_output_accuracy: 0.9123 - main_output_loss: 1.0334 - tof_gate_loss: 4.6033e-06 - val_loss: 1.3041 - val_main_output_accuracy: 0.7505 - val_main_output_loss: 1.2510 - val_tof_gate_loss: 1.5867e-06
# Epoch 113/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.9961 - main_output_accuracy: 0.9554 - main_output_loss: 0.9357 - tof_gate_loss: 2.8813e-06 - val_loss: 1.3303 - val_main_output_accuracy: 0.7517 - val_main_output_loss: 1.2774 - val_tof_gate_loss: 1.4154e-06
# Epoch 114/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1209 - main_output_accuracy: 0.9211 - main_output_loss: 1.0599 - tof_gate_loss: 4.0577e-06 - val_loss: 1.3263 - val_main_output_accuracy: 0.7388 - val_main_output_loss: 1.2721 - val_tof_gate_loss: 1.5767e-06
# Epoch 115/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0626 - main_output_accuracy: 0.9448 - main_output_loss: 1.0025 - tof_gate_loss: 3.2887e-06 - val_loss: 1.3162 - val_main_output_accuracy: 0.7511 - val_main_output_loss: 1.2622 - val_tof_gate_loss: 1.4638e-06
# Epoch 116/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0230 - main_output_accuracy: 0.9364 - main_output_loss: 0.9631 - tof_gate_loss: 2.9326e-06 - val_loss: 1.2941 - val_main_output_accuracy: 0.7529 - val_main_output_loss: 1.2403 - val_tof_gate_loss: 1.5136e-06
# Epoch 117/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0982 - main_output_accuracy: 0.9363 - main_output_loss: 1.0382 - tof_gate_loss: 3.0903e-06 - val_loss: 1.2950 - val_main_output_accuracy: 0.7584 - val_main_output_loss: 1.2422 - val_tof_gate_loss: 1.4476e-06
# Epoch 118/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0464 - main_output_accuracy: 0.9478 - main_output_loss: 0.9868 - tof_gate_loss: 2.2303e-06 - val_loss: 1.3097 - val_main_output_accuracy: 0.7554 - val_main_output_loss: 1.2573 - val_tof_gate_loss: 1.0490e-06
# Epoch 119/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1179 - main_output_accuracy: 0.8987 - main_output_loss: 1.0587 - tof_gate_loss: 3.2012e-06 - val_loss: 1.2981 - val_main_output_accuracy: 0.7664 - val_main_output_loss: 1.2450 - val_tof_gate_loss: 1.0412e-06
# Epoch 120/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0706 - main_output_accuracy: 0.9309 - main_output_loss: 1.0111 - tof_gate_loss: 2.8354e-06 - val_loss: 1.3117 - val_main_output_accuracy: 0.7529 - val_main_output_loss: 1.2586 - val_tof_gate_loss: 1.2320e-06
# Epoch 121/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0248 - main_output_accuracy: 0.9359 - main_output_loss: 0.9665 - tof_gate_loss: 2.8364e-06 - val_loss: 1.3025 - val_main_output_accuracy: 0.7603 - val_main_output_loss: 1.2488 - val_tof_gate_loss: 1.1989e-06
# Epoch 122/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1534 - main_output_accuracy: 0.9027 - main_output_loss: 1.0939 - tof_gate_loss: 3.5292e-06 - val_loss: 1.3220 - val_main_output_accuracy: 0.7548 - val_main_output_loss: 1.2676 - val_tof_gate_loss: 1.2087e-06
# Epoch 123/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1713 - main_output_accuracy: 0.9166 - main_output_loss: 1.1121 - tof_gate_loss: 3.9753e-06 - val_loss: 1.3030 - val_main_output_accuracy: 0.7609 - val_main_output_loss: 1.2505 - val_tof_gate_loss: 1.1312e-06
# Epoch 124/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0086 - main_output_accuracy: 0.9548 - main_output_loss: 0.9493 - tof_gate_loss: 1.6575e-06 - val_loss: 1.3219 - val_main_output_accuracy: 0.7578 - val_main_output_loss: 1.2693 - val_tof_gate_loss: 7.1892e-07
# Epoch 125/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.9842 - main_output_accuracy: 0.9572 - main_output_loss: 0.9265 - tof_gate_loss: 2.0288e-06 - val_loss: 1.3224 - val_main_output_accuracy: 0.7541 - val_main_output_loss: 1.2704 - val_tof_gate_loss: 9.6375e-07
# Epoch 126/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1005 - main_output_accuracy: 0.9144 - main_output_loss: 1.0419 - tof_gate_loss: 2.4258e-06 - val_loss: 1.3096 - val_main_output_accuracy: 0.7566 - val_main_output_loss: 1.2567 - val_tof_gate_loss: 9.5117e-07
# Epoch 127/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.9724 - main_output_accuracy: 0.9543 - main_output_loss: 0.9134 - tof_gate_loss: 1.7059e-06 - val_loss: 1.3024 - val_main_output_accuracy: 0.7597 - val_main_output_loss: 1.2492 - val_tof_gate_loss: 6.6852e-07
# Epoch 128/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.9472 - main_output_accuracy: 0.9761 - main_output_loss: 0.8882 - tof_gate_loss: 1.0461e-06 - val_loss: 1.3099 - val_main_output_accuracy: 0.7578 - val_main_output_loss: 1.2579 - val_tof_gate_loss: 7.3654e-07
# Epoch 129/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.1675 - main_output_accuracy: 0.9063 - main_output_loss: 1.1085 - tof_gate_loss: 2.9935e-06 - val_loss: 1.3163 - val_main_output_accuracy: 0.7498 - val_main_output_loss: 1.2632 - val_tof_gate_loss: 1.1144e-06
# Epoch 130/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0343 - main_output_accuracy: 0.9316 - main_output_loss: 0.9755 - tof_gate_loss: 2.0926e-06 - val_loss: 1.3154 - val_main_output_accuracy: 0.7517 - val_main_output_loss: 1.2630 - val_tof_gate_loss: 7.5707e-07
# Epoch 131/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.0944 - main_output_accuracy: 0.9321 - main_output_loss: 1.0354 - tof_gate_loss: 2.1897e-06 - val_loss: 1.3115 - val_main_output_accuracy: 0.7566 - val_main_output_loss: 1.2589 - val_tof_gate_loss: 9.0670e-07
# Epoch 132/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0660 - main_output_accuracy: 0.9395 - main_output_loss: 1.0069 - tof_gate_loss: 2.2320e-06 - val_loss: 1.3122 - val_main_output_accuracy: 0.7541 - val_main_output_loss: 1.2602 - val_tof_gate_loss: 8.0460e-07
# Epoch 133/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0609 - main_output_accuracy: 0.9415 - main_output_loss: 1.0020 - tof_gate_loss: 1.9084e-06 - val_loss: 1.3009 - val_main_output_accuracy: 0.7566 - val_main_output_loss: 1.2494 - val_tof_gate_loss: 9.0607e-07
# Epoch 134/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0031 - main_output_accuracy: 0.9494 - main_output_loss: 0.9445 - tof_gate_loss: 2.6527e-06 - val_loss: 1.3029 - val_main_output_accuracy: 0.7609 - val_main_output_loss: 1.2506 - val_tof_gate_loss: 7.9501e-07
# Epoch 135/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0032 - main_output_accuracy: 0.9496 - main_output_loss: 0.9442 - tof_gate_loss: 1.6598e-06 - val_loss: 1.3084 - val_main_output_accuracy: 0.7560 - val_main_output_loss: 1.2556 - val_tof_gate_loss: 8.6173e-07
# Epoch 136/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0320 - main_output_accuracy: 0.9517 - main_output_loss: 0.9727 - tof_gate_loss: 1.7317e-06 - val_loss: 1.3086 - val_main_output_accuracy: 0.7590 - val_main_output_loss: 1.2563 - val_tof_gate_loss: 7.4804e-07
# Epoch 137/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.0806 - main_output_accuracy: 0.9145 - main_output_loss: 1.0221 - tof_gate_loss: 2.7397e-06 - val_loss: 1.3045 - val_main_output_accuracy: 0.7584 - val_main_output_loss: 1.2515 - val_tof_gate_loss: 1.0178e-06
# Epoch 138/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0072 - main_output_accuracy: 0.9534 - main_output_loss: 0.9488 - tof_gate_loss: 2.0061e-06 - val_loss: 1.3017 - val_main_output_accuracy: 0.7597 - val_main_output_loss: 1.2490 - val_tof_gate_loss: 8.3724e-07
# Epoch 139/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 0.9848 - main_output_accuracy: 0.9583 - main_output_loss: 0.9261 - tof_gate_loss: 1.5749e-06 - val_loss: 1.3019 - val_main_output_accuracy: 0.7572 - val_main_output_loss: 1.2491 - val_tof_gate_loss: 9.8285e-07
# --- Fold 1 Best Epoch: 119 ---
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step
# Fold 1 Accuracy: 0.7664
#
# === Fold 2/5 for In_Model_FE ===
# 2025-08-23 21:09:18.754180: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 50908160 exceeds 10% of free system memory.
# 2025-08-23 21:09:18.819515: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 50908160 exceeds 10% of free system memory.
# LR Scheduler: 102 steps per epoch, 15300 total decay steps.
# Epoch 1/150
# /home/uallende/projects/kaggle/CMI/.venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  34/102 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.0499 - main_output_accuracy: 0.0925 - main_output_loss: 2.8797 - tof_gate_loss: 0.3906
# 2025-08-23 21:09:43.281884: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 11.67GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-23 21:09:43.829406: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.95GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-08-23 21:09:45.959230: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 8.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 43s 231ms/step - loss: 2.8605 - main_output_accuracy: 0.1375 - main_output_loss: 2.7318 - tof_gate_loss: 0.1845 - val_loss: 2.4369 - val_main_output_accuracy: 0.3196 - val_main_output_loss: 2.3296 - val_tof_gate_loss: 0.0808
# Epoch 2/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 2.4057 - main_output_accuracy: 0.3076 - main_output_loss: 2.3151 - tof_gate_loss: 0.0082 - val_loss: 2.1308 - val_main_output_accuracy: 0.4166 - val_main_output_loss: 2.0395 - val_tof_gate_loss: 0.0222
# Epoch 3/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 2.1825 - main_output_accuracy: 0.3890 - main_output_loss: 2.0960 - tof_gate_loss: 0.0044 - val_loss: 1.8820 - val_main_output_accuracy: 0.5098 - val_main_output_loss: 1.7923 - val_tof_gate_loss: 0.0116
# Epoch 4/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 2.0704 - main_output_accuracy: 0.4622 - main_output_loss: 1.9856 - tof_gate_loss: 0.0033 - val_loss: 1.7627 - val_main_output_accuracy: 0.5337 - val_main_output_loss: 1.6765 - val_tof_gate_loss: 0.0076
# Epoch 5/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.9644 - main_output_accuracy: 0.4889 - main_output_loss: 1.8823 - tof_gate_loss: 0.0024 - val_loss: 1.6939 - val_main_output_accuracy: 0.5632 - val_main_output_loss: 1.6087 - val_tof_gate_loss: 0.0054
# Epoch 6/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.9560 - main_output_accuracy: 0.4961 - main_output_loss: 1.8751 - tof_gate_loss: 0.0020 - val_loss: 1.6736 - val_main_output_accuracy: 0.5663 - val_main_output_loss: 1.5901 - val_tof_gate_loss: 0.0052
# Epoch 7/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.8918 - main_output_accuracy: 0.5336 - main_output_loss: 1.8128 - tof_gate_loss: 0.0016 - val_loss: 1.6280 - val_main_output_accuracy: 0.5871 - val_main_output_loss: 1.5477 - val_tof_gate_loss: 0.0065
# Epoch 8/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.8446 - main_output_accuracy: 0.5559 - main_output_loss: 1.7669 - tof_gate_loss: 0.0015 - val_loss: 1.5772 - val_main_output_accuracy: 0.5859 - val_main_output_loss: 1.4982 - val_tof_gate_loss: 0.0037
# Epoch 9/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.8193 - main_output_accuracy: 0.5624 - main_output_loss: 1.7439 - tof_gate_loss: 0.0012 - val_loss: 1.5700 - val_main_output_accuracy: 0.6080 - val_main_output_loss: 1.4923 - val_tof_gate_loss: 0.0030
# Epoch 10/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.7943 - main_output_accuracy: 0.5742 - main_output_loss: 1.7192 - tof_gate_loss: 9.0026e-04 - val_loss: 1.5334 - val_main_output_accuracy: 0.6258 - val_main_output_loss: 1.4540 - val_tof_gate_loss: 0.0037
# Epoch 11/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.8193 - main_output_accuracy: 0.5856 - main_output_loss: 1.7450 - tof_gate_loss: 0.0013 - val_loss: 1.5411 - val_main_output_accuracy: 0.6209 - val_main_output_loss: 1.4651 - val_tof_gate_loss: 0.0032
# Epoch 12/150
# ...
# Epoch 47/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1477 - main_output_accuracy: 0.8566 - main_output_loss: 1.0795 - tof_gate_loss: 1.7136e-05 - val_loss: 1.3368 - val_main_output_accuracy: 0.7061 - val_main_output_loss: 1.2682 - val_tof_gate_loss: 1.9550e-05
# Epoch 48/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 1.4013 - main_output_accuracy: 0.8027 - main_output_loss: 1.3328 - tof_gate_loss: 5.8825e-05 - val_loss: 1.3473 - val_main_output_accuracy: 0.7178 - val_main_output_loss: 1.2825 - val_tof_gate_loss: 1.7087e-05
# Epoch 49/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 1.2010 - main_output_accuracy: 0.8507 - main_output_loss: 1.1326 - tof_gate_loss: 2.1493e-05 - val_loss: 1.3377 - val_main_output_accuracy: 0.7147 - val_main_output_loss: 1.2668 - val_tof_gate_loss: 1.0714e-05
# Epoch 50/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 1.4136 - main_output_accuracy: 0.7894 - main_output_loss: 1.3431 - tof_gate_loss: 5.8515e-05 - val_loss: 1.2902 - val_main_output_accuracy: 0.7356 - val_main_output_loss: 1.2233 - val_tof_gate_loss: 2.2951e-05
# Epoch 51/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.2381 - main_output_accuracy: 0.8434 - main_output_loss: 1.1689 - tof_gate_loss: 2.7816e-05 - val_loss: 1.3779 - val_main_output_accuracy: 0.7074 - val_main_output_loss: 1.3136 - val_tof_gate_loss: 1.2507e-05
# Epoch 52/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.2805 - main_output_accuracy: 0.8238 - main_output_loss: 1.2118 - tof_gate_loss: 3.1863e-05 - val_loss: 1.3331 - val_main_output_accuracy: 0.7209 - val_main_output_loss: 1.2657 - val_tof_gate_loss: 6.2783e-06
# Epoch 53/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.3522 - main_output_accuracy: 0.8026 - main_output_loss: 1.2843 - tof_gate_loss: 2.9902e-05 - val_loss: 1.3685 - val_main_output_accuracy: 0.7166 - val_main_output_loss: 1.3037 - val_tof_gate_loss: 6.1627e-06
# Epoch 54/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.2841 - main_output_accuracy: 0.8335 - main_output_loss: 1.2158 - tof_gate_loss: 3.1293e-05 - val_loss: 1.3048 - val_main_output_accuracy: 0.7147 - val_main_output_loss: 1.2346 - val_tof_gate_loss: 5.6073e-06
# Epoch 55/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.2644 - main_output_accuracy: 0.8403 - main_output_loss: 1.1960 - tof_gate_loss: 2.3865e-05 - val_loss: 1.3401 - val_main_output_accuracy: 0.7135 - val_main_output_loss: 1.2744 - val_tof_gate_loss: 1.4722e-05
# Epoch 56/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.2796 - main_output_accuracy: 0.8221 - main_output_loss: 1.2145 - tof_gate_loss: 2.9999e-05 - val_loss: 1.3514 - val_main_output_accuracy: 0.7215 - val_main_output_loss: 1.2833 - val_tof_gate_loss: 9.4729e-06
# Epoch 57/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.2633 - main_output_accuracy: 0.8460 - main_output_loss: 1.1940 - tof_gate_loss: 2.6977e-05 - val_loss: 1.3311 - val_main_output_accuracy: 0.7325 - val_main_output_loss: 1.2647 - val_tof_gate_loss: 1.6418e-05
# Epoch 58/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.3276 - main_output_accuracy: 0.8188 - main_output_loss: 1.2598 - tof_gate_loss: 3.5220e-05 - val_loss: 1.3357 - val_main_output_accuracy: 0.7160 - val_main_output_loss: 1.2677 - val_tof_gate_loss: 5.8735e-06
# Epoch 59/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.3463 - main_output_accuracy: 0.8358 - main_output_loss: 1.2780 - tof_gate_loss: 2.5719e-05 - val_loss: 1.3143 - val_main_output_accuracy: 0.7270 - val_main_output_loss: 1.2497 - val_tof_gate_loss: 7.7768e-06
# Epoch 60/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.2091 - main_output_accuracy: 0.8447 - main_output_loss: 1.1416 - tof_gate_loss: 1.9779e-05 - val_loss: 1.3198 - val_main_output_accuracy: 0.7282 - val_main_output_loss: 1.2514 - val_tof_gate_loss: 4.8801e-06
# Epoch 61/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1857 - main_output_accuracy: 0.8761 - main_output_loss: 1.1175 - tof_gate_loss: 1.2466e-05 - val_loss: 1.3876 - val_main_output_accuracy: 0.6933 - val_main_output_loss: 1.3153 - val_tof_gate_loss: 6.2439e-06
# Epoch 62/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1014 - main_output_accuracy: 0.9017 - main_output_loss: 1.0344 - tof_gate_loss: 8.6916e-06 - val_loss: 1.3706 - val_main_output_accuracy: 0.7252 - val_main_output_loss: 1.3059 - val_tof_gate_loss: 6.1624e-06
# Epoch 63/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.2132 - main_output_accuracy: 0.8728 - main_output_loss: 1.1444 - tof_gate_loss: 2.3461e-05 - val_loss: 1.3425 - val_main_output_accuracy: 0.7399 - val_main_output_loss: 1.2742 - val_tof_gate_loss: 6.8258e-06
# Epoch 64/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.2311 - main_output_accuracy: 0.8639 - main_output_loss: 1.1630 - tof_gate_loss: 2.2790e-05 - val_loss: 1.4706 - val_main_output_accuracy: 0.6939 - val_main_output_loss: 1.4048 - val_tof_gate_loss: 4.3186e-06
# Epoch 65/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.0839 - main_output_accuracy: 0.8883 - main_output_loss: 1.0157 - tof_gate_loss: 1.1237e-05 - val_loss: 1.3326 - val_main_output_accuracy: 0.7374 - val_main_output_loss: 1.2667 - val_tof_gate_loss: 4.6164e-06
# Epoch 66/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.0895 - main_output_accuracy: 0.8998 - main_output_loss: 1.0217 - tof_gate_loss: 1.0909e-05 - val_loss: 1.3103 - val_main_output_accuracy: 0.7393 - val_main_output_loss: 1.2417 - val_tof_gate_loss: 1.2459e-05
# Epoch 67/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1106 - main_output_accuracy: 0.8908 - main_output_loss: 1.0428 - tof_gate_loss: 1.8734e-05 - val_loss: 1.3667 - val_main_output_accuracy: 0.7270 - val_main_output_loss: 1.2984 - val_tof_gate_loss: 5.6225e-06
# Epoch 68/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1666 - main_output_accuracy: 0.8842 - main_output_loss: 1.0983 - tof_gate_loss: 1.5719e-05 - val_loss: 1.3013 - val_main_output_accuracy: 0.7448 - val_main_output_loss: 1.2342 - val_tof_gate_loss: 6.3646e-06
# Epoch 69/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.2160 - main_output_accuracy: 0.8745 - main_output_loss: 1.1486 - tof_gate_loss: 2.0214e-05 - val_loss: 1.3445 - val_main_output_accuracy: 0.7313 - val_main_output_loss: 1.2785 - val_tof_gate_loss: 4.3837e-06
# Epoch 70/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.1696 - main_output_accuracy: 0.8781 - main_output_loss: 1.1023 - tof_gate_loss: 1.2390e-05 - val_loss: 1.2972 - val_main_output_accuracy: 0.7423 - val_main_output_loss: 1.2312 - val_tof_gate_loss: 2.2473e-06
# Epoch 71/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1586 - main_output_accuracy: 0.9003 - main_output_loss: 1.0921 - tof_gate_loss: 1.2463e-05 - val_loss: 1.3575 - val_main_output_accuracy: 0.7362 - val_main_output_loss: 1.2944 - val_tof_gate_loss: 6.7920e-06
# Epoch 72/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1495 - main_output_accuracy: 0.8915 - main_output_loss: 1.0831 - tof_gate_loss: 1.1059e-05 - val_loss: 1.3165 - val_main_output_accuracy: 0.7399 - val_main_output_loss: 1.2532 - val_tof_gate_loss: 3.1243e-06
# Epoch 73/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1365 - main_output_accuracy: 0.9000 - main_output_loss: 1.0695 - tof_gate_loss: 8.1511e-06 - val_loss: 1.3458 - val_main_output_accuracy: 0.7221 - val_main_output_loss: 1.2806 - val_tof_gate_loss: 2.4408e-06
# Epoch 74/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.1252 - main_output_accuracy: 0.8856 - main_output_loss: 1.0576 - tof_gate_loss: 6.8670e-06 - val_loss: 1.3352 - val_main_output_accuracy: 0.7362 - val_main_output_loss: 1.2694 - val_tof_gate_loss: 5.2562e-06
# Epoch 75/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.2458 - main_output_accuracy: 0.8742 - main_output_loss: 1.1791 - tof_gate_loss: 1.1304e-05 - val_loss: 1.3235 - val_main_output_accuracy: 0.7454 - val_main_output_loss: 1.2569 - val_tof_gate_loss: 4.5177e-06
# Epoch 76/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1964 - main_output_accuracy: 0.8903 - main_output_loss: 1.1299 - tof_gate_loss: 1.1992e-05 - val_loss: 1.3364 - val_main_output_accuracy: 0.7417 - val_main_output_loss: 1.2756 - val_tof_gate_loss: 1.5912e-06
# Epoch 77/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0840 - main_output_accuracy: 0.9084 - main_output_loss: 1.0177 - tof_gate_loss: 7.6967e-06 - val_loss: 1.3299 - val_main_output_accuracy: 0.7356 - val_main_output_loss: 1.2666 - val_tof_gate_loss: 2.4523e-06
# Epoch 78/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0624 - main_output_accuracy: 0.9217 - main_output_loss: 0.9957 - tof_gate_loss: 7.3468e-06 - val_loss: 1.3496 - val_main_output_accuracy: 0.7368 - val_main_output_loss: 1.2905 - val_tof_gate_loss: 1.7246e-06
# Epoch 79/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.1367 - main_output_accuracy: 0.8985 - main_output_loss: 1.0707 - tof_gate_loss: 9.5187e-06 - val_loss: 1.3955 - val_main_output_accuracy: 0.7215 - val_main_output_loss: 1.3339 - val_tof_gate_loss: 3.7994e-06
# Epoch 80/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.1082 - main_output_accuracy: 0.8906 - main_output_loss: 1.0431 - tof_gate_loss: 6.4484e-06 - val_loss: 1.3728 - val_main_output_accuracy: 0.7307 - val_main_output_loss: 1.3099 - val_tof_gate_loss: 3.0743e-06
# Epoch 81/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1809 - main_output_accuracy: 0.8681 - main_output_loss: 1.1151 - tof_gate_loss: 1.0290e-05 - val_loss: 1.3237 - val_main_output_accuracy: 0.7448 - val_main_output_loss: 1.2611 - val_tof_gate_loss: 4.3360e-06
# Epoch 82/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1443 - main_output_accuracy: 0.8922 - main_output_loss: 1.0789 - tof_gate_loss: 8.5242e-06 - val_loss: 1.3316 - val_main_output_accuracy: 0.7436 - val_main_output_loss: 1.2674 - val_tof_gate_loss: 3.2488e-06
# Epoch 83/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1737 - main_output_accuracy: 0.8906 - main_output_loss: 1.1081 - tof_gate_loss: 8.4348e-06 - val_loss: 1.3640 - val_main_output_accuracy: 0.7331 - val_main_output_loss: 1.3004 - val_tof_gate_loss: 2.1902e-06
# Epoch 84/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0335 - main_output_accuracy: 0.9152 - main_output_loss: 0.9688 - tof_gate_loss: 4.8692e-06 - val_loss: 1.3992 - val_main_output_accuracy: 0.7258 - val_main_output_loss: 1.3369 - val_tof_gate_loss: 3.9838e-06
# Epoch 85/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.1230 - main_output_accuracy: 0.8984 - main_output_loss: 1.0580 - tof_gate_loss: 7.4458e-06 - val_loss: 1.3113 - val_main_output_accuracy: 0.7405 - val_main_output_loss: 1.2470 - val_tof_gate_loss: 1.5372e-06
# Epoch 86/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.3429 - main_output_accuracy: 0.8389 - main_output_loss: 1.2778 - tof_gate_loss: 1.0659e-05 - val_loss: 1.3370 - val_main_output_accuracy: 0.7442 - val_main_output_loss: 1.2757 - val_tof_gate_loss: 4.0927e-06
# Epoch 87/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0713 - main_output_accuracy: 0.9221 - main_output_loss: 1.0063 - tof_gate_loss: 5.1627e-06 - val_loss: 1.3169 - val_main_output_accuracy: 0.7374 - val_main_output_loss: 1.2532 - val_tof_gate_loss: 2.4443e-06
# Epoch 88/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.2241 - main_output_accuracy: 0.8728 - main_output_loss: 1.1595 - tof_gate_loss: 7.9337e-06 - val_loss: 1.3308 - val_main_output_accuracy: 0.7319 - val_main_output_loss: 1.2670 - val_tof_gate_loss: 2.2911e-06
# Epoch 89/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.1071 - main_output_accuracy: 0.9046 - main_output_loss: 1.0432 - tof_gate_loss: 7.0092e-06 - val_loss: 1.3087 - val_main_output_accuracy: 0.7405 - val_main_output_loss: 1.2458 - val_tof_gate_loss: 1.4267e-06
# Epoch 90/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 1.2063 - main_output_accuracy: 0.8775 - main_output_loss: 1.1422 - tof_gate_loss: 7.5014e-06 - val_loss: 1.3530 - val_main_output_accuracy: 0.7362 - val_main_output_loss: 1.2918 - val_tof_gate_loss: 1.7948e-06
# Epoch 91/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1577 - main_output_accuracy: 0.9045 - main_output_loss: 1.0937 - tof_gate_loss: 6.4369e-06 - val_loss: 1.3277 - val_main_output_accuracy: 0.7429 - val_main_output_loss: 1.2653 - val_tof_gate_loss: 2.3630e-06
# Epoch 92/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.0746 - main_output_accuracy: 0.9177 - main_output_loss: 1.0131 - tof_gate_loss: 4.4820e-06 - val_loss: 1.3840 - val_main_output_accuracy: 0.7301 - val_main_output_loss: 1.3242 - val_tof_gate_loss: 1.0704e-06
# Epoch 93/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.0548 - main_output_accuracy: 0.9353 - main_output_loss: 0.9908 - tof_gate_loss: 3.6141e-06 - val_loss: 1.3555 - val_main_output_accuracy: 0.7380 - val_main_output_loss: 1.2948 - val_tof_gate_loss: 2.6040e-06
# Epoch 94/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.1095 - main_output_accuracy: 0.9277 - main_output_loss: 1.0458 - tof_gate_loss: 4.4697e-06 - val_loss: 1.3462 - val_main_output_accuracy: 0.7411 - val_main_output_loss: 1.2850 - val_tof_gate_loss: 1.3985e-06
# Epoch 95/150
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 1.1124 - main_output_accuracy: 0.9167 - main_output_loss: 1.0493 - tof_gate_loss: 3.8835e-06 - val_loss: 1.3883 - val_main_output_accuracy: 0.7264 - val_main_output_loss: 1.3302 - val_tof_gate_loss: 9.6048e-07
# --- Fold 5 Best Epoch: 75 ---
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step
# Fold 5 Accuracy: 0.7454
#
# === OOF Summary for In_Model_FE ===
# Per-fold Accuracies: [0.7664, 0.7479, 0.7448, 0.7423, 0.7454]
# Mean Accuracy: 0.7494 ± 0.0087
# Best epochs per fold: [np.int64(119), np.int64(60), np.int64(95), np.int64(82), np.int64(75)]
# Average best epoch: 86
#
# === Overall Classification Report ===
#                                             precision    recall  f1-score   support
#
#                      Above ear - pull hair     0.7924    0.7476    0.7694       638
#                         Cheek - pinch skin     0.5769    0.6656    0.6181       637
#                      Drink from bottle/cup     0.9686    0.9565    0.9625       161
#                        Eyebrow - pull hair     0.5156    0.4922    0.5036       638
#                        Eyelash - pull hair     0.5934    0.5609    0.5767       640
# Feel around in tray and pull out an object     0.9290    0.8944    0.9114       161
#                   Forehead - pull hairline     0.7802    0.7156    0.7465       640
#                         Forehead - scratch     0.8202    0.8125    0.8163       640
#                             Glasses on/off     0.9625    0.9565    0.9595       161
#                          Neck - pinch skin     0.5954    0.6875    0.6381       640
#                             Neck - scratch     0.6915    0.6375    0.6634       640
#                        Pinch knee/leg skin     0.6885    0.7826    0.7326       161
#                  Pull air toward your face     0.9563    0.9623    0.9592       477
#                      Scratch knee/leg skin     0.7099    0.5776    0.6370       161
#                              Text on phone     0.9127    0.9469    0.9294       640
#                                 Wave hello     0.9254    0.9079    0.9166       478
#                          Write name in air     0.8706    0.8889    0.8797       477
#                          Write name on leg     0.7037    0.7081    0.7059       161
#
#                                   accuracy                         0.7494      8151
#                                  macro avg     0.7774    0.7723    0.7737      8151
#                               weighted avg     0.7516    0.7494    0.7494      8151
#
#
# ============================================================
# ▶ FINAL MODEL EXPERIMENT SUMMARY
# ============================================================
#   - In_Model_FE: Mean Accuracy = 0.7494, Avg Best Epoch = 86

# %%
import traceback
# =====================================================================================
# ARCHITECTURE SANITY CHECK
# =====================================================================================

# --- Step 1: Get a sample batch and define shapes ---
# (This part of your code is correct)
# Make sure your train_dataset is created before this block
try:
    sample_batch = next(iter(train_dataset))
    sample_input = sample_batch[0]
    input_shape = sample_input.shape[1:]
    imu_dim = len(imu_cols) # Assuming imu_cols is defined
    print(f"Sample input shape for testing: {sample_input.shape}\n")
except Exception as e:
    print(f"Could not get a sample from the dataset. Error: {e}")
    # Exit if we can't get a sample to test with
    exit()

# --- Step 2: Create a list of all model-building functions ---
# (This part of your code is correct)
# model_builders = [
#     ("CNN_Baseline", lambda: create_model_1_cnn_baseline(input_shape)),
#     ("GRU_Baseline", lambda: create_model_2_gru_baseline(input_shape)),
#     ("CNN_RNN_Hybrid", lambda: create_model_3_cnn_rnn_hybrid(input_shape)),
#     ("WaveNet_Style", lambda: create_model_4_wavenet_style(input_shape)),
#     ("UNet_Style", lambda: create_model_5_unet_style(input_shape)),
#     ("Transformer", lambda: create_model_6_transformer(input_shape)),
#     ("CNN_Transformer", lambda: create_model_7_cnn_transformer(input_shape)),
#     # For your two-branch model, you'll need the full IMU+ToF dataset
#     # ("Two_Branch", lambda: create_model_8_two_branch(input_shape, imu_dim)),
# ]

model_builders = [
    ("wave_net", lambda: create_wave_net(input_shape, imu_dim)),
    ("unet_wave", lambda: create_advanced_model_3_unet_wave(input_shape, imu_dim)),
    ("Advanced_Dual_UNet", lambda: create_advanced_model_A_dual_unet(input_shape, imu_dim)),
    ("Hyper UNet", lambda: create_advanced_model_B_hyper_unet(input_shape, imu_dim)),
]

# --- Step 3: Loop through the models, build them, and test with the sample ---
print("--- Testing all model architectures with a sample batch ---")
for model_name, model_builder in model_builders:
    print("\n" + "="*60)
    print(f"▶ Testing Model: {model_name}")
    print("="*60)
    
    try:
        # 1. Build the model using the builder function
        model = model_builder()
        
        # Optional: Print the model summary to check its structure
        print(f"Model Summary for {model_name}:")
        model.summary()
        
        # 2. Pass the sample input through the model
        print(f"\nPerforming forward pass for {model_name}...")
        output = model(sample_input)
        
        # 3. Print the output shape to verify it's correct
        print(f"✅ SUCCESS: Model '{model_name}' ran successfully.")
        # For multi-output models, output might be a list/dict. For single, it's a tensor.
        if isinstance(output, dict):
            for key, value in output.items():
                print(f"   Output '{key}' shape: {value.shape}")
        elif isinstance(output, list):
            for i, value in enumerate(output):
                print(f"   Output {i} shape: {value.shape}")
        else:
            print(f"   Output shape: {output.shape}")

    except Exception as e:
        print(f"❌ ERROR: Model '{model_name}' failed to build or run.")
        traceback.print_exc() # This will print the full error traceback
        
    # Clean up the created model to save memory
    del model
    gc.collect()

print("\n--- Model architecture testing complete. ---")
# Out:
# Could not get a sample from the dataset. Error: name 'train_dataset' is not defined
# --- Testing all model architectures with a sample batch ---
#
# ============================================================
# ▶ Testing Model: wave_net
# ============================================================
# Model Summary for wave_net:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5       │ (None, 128, 61)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_40 (Lambda)  │ (None, 128, 6)    │          0 │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_40 (Conv1D)  │ (None, 128, 128)  │        896 │ lambda_40[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_41 (Conv1D)  │ (None, 128, 128)  │     49,280 │ conv1d_40[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_42 (Conv1D)  │ (None, 128, 128)  │     49,280 │ conv1d_40[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_10         │ (None, 128, 128)  │          0 │ conv1d_41[0][0],  │
# │ (Multiply)          │                   │            │ conv1d_42[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_30          │ (None, 128, 128)  │          0 │ multiply_10[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_43 (Conv1D)  │ (None, 128, 128)  │     16,512 │ dropout_30[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 128, 128)  │          0 │ conv1d_40[0][0],  │
# │                     │                   │            │ conv1d_43[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 128, 128)  │        256 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_44 (Conv1D)  │ (None, 128, 128)  │     49,280 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_45 (Conv1D)  │ (None, 128, 128)  │     49,280 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_11         │ (None, 128, 128)  │          0 │ conv1d_44[0][0],  │
# │ (Multiply)          │                   │            │ conv1d_45[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 128, 128)  │          0 │ multiply_11[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_46 (Conv1D)  │ (None, 128, 128)  │     16,512 │ dropout_31[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 128, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ conv1d_46[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 128)  │        256 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_47 (Conv1D)  │ (None, 128, 128)  │     49,280 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_48 (Conv1D)  │ (None, 128, 128)  │     49,280 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_12         │ (None, 128, 128)  │          0 │ conv1d_47[0][0],  │
# │ (Multiply)          │                   │            │ conv1d_48[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 128, 128)  │          0 │ multiply_12[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_41 (Lambda)  │ (None, 128, 55)   │          0 │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_49 (Conv1D)  │ (None, 128, 128)  │     16,512 │ dropout_32[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_53 (Conv1D)  │ (None, 128, 64)   │     10,560 │ lambda_41[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 128, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ conv1d_49[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 64)   │        256 │ conv1d_53[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 128)  │        256 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 128, 64)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_50 (Conv1D)  │ (None, 128, 128)  │     49,280 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_51 (Conv1D)  │ (None, 128, 128)  │     49,280 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_20    │ (None, 64, 64)    │          0 │ activation_40[0]… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_13         │ (None, 128, 128)  │          0 │ conv1d_50[0][0],  │
# │ (Multiply)          │                   │            │ conv1d_51[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_34          │ (None, 64, 64)    │          0 │ max_pooling1d_20… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_33          │ (None, 128, 128)  │          0 │ multiply_13[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_54 (Conv1D)  │ (None, 64, 128)   │     24,576 │ dropout_34[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 55)        │          0 │ lambda_41[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_52 (Conv1D)  │ (None, 128, 128)  │     16,512 │ dropout_33[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 128)   │        512 │ conv1d_54[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 16)        │        896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 128, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ conv1d_52[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 64, 128)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tof_gate_dense      │ (None, 1)         │         17 │ dense_30[0][0]    │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 128)  │        256 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_14         │ (None, 64, 128)   │          0 │ activation_41[0]… │
# │ (Multiply)          │                   │            │ tof_gate_dense[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_42 (Lambda)  │ [(None, 64, 128), │          0 │ layer_normalizat… │
# │                     │ (None, 64, 128)]  │            │ multiply_14[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 64, 256)   │          0 │ lambda_42[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_42[0][1]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_noise      │ (None, 64, 256)   │          0 │ concatenate_10[0… │
# │ (GaussianNoise)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional       │ (None, 64, 256)   │    394,240 │ concatenate_10[0… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_1     │ (None, 64, 256)   │    296,448 │ concatenate_10[0… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 64, 16)    │      4,112 │ gaussian_noise[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 64, 528)   │          0 │ bidirectional[0]… │
# │ (Concatenate)       │                   │            │ bidirectional_1[… │
# │                     │                   │            │ dense_31[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_35          │ (None, 64, 528)   │          0 │ concatenate_11[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 64, 1)     │        529 │ dropout_35[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_43 (Lambda)  │ (None, 64)        │          0 │ dense_32[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 64)        │          0 │ lambda_43[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_44 (Lambda)  │ (None, 64, 1)     │          0 │ activation_42[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_15         │ (None, 64, 528)   │          0 │ dropout_35[0][0], │
# │ (Multiply)          │                   │            │ lambda_44[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_45 (Lambda)  │ (None, 528)       │          0 │ multiply_15[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 256)       │    135,168 │ lambda_45[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_33[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 256)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_36          │ (None, 256)       │          0 │ activation_43[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_34 (Dense)    │ (None, 128)       │     32,768 │ dropout_36[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_34[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_44       │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_37          │ (None, 128)       │          0 │ activation_44[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_38          │ (None, 128)       │          0 │ dropout_37[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_output (Dense) │ (None, 18)        │      2,322 │ dropout_38[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tof_gate (Dense)    │ (None, 1)         │        129 │ dropout_38[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,366,277 (5.21 MB)
#  Trainable params: 1,365,125 (5.21 MB)
#  Non-trainable params: 1,152 (4.50 KB)
# Performing forward pass for wave_net...
# ❌ ERROR: Model 'wave_net' failed to build or run.
#
# ============================================================
# ▶ Testing Model: unet_wave
# ============================================================
# Traceback (most recent call last):
#   File "/tmp/ipykernel_4081569/3681017911.py", line 58, in <module>
#     output = model(sample_input)
#                    ^^^^^^^^^^^^
# NameError: name 'sample_input' is not defined
# Model Summary for unet_wave:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 128, 61)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_46 (Lambda)  │ (None, 128, 6)    │          0 │ input_layer_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_55 (Conv1D)  │ (None, 128, 64)   │      1,920 │ lambda_46[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 64)   │        256 │ conv1d_55[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_45       │ (None, 128, 64)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_56 (Conv1D)  │ (None, 128, 64)   │     20,480 │ activation_45[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 64)   │        256 │ conv1d_56[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_46       │ (None, 128, 64)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ activation_46[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_35 (Dense)    │ (None, 8)         │        520 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_36 (Dense)    │ (None, 64)        │        576 │ dense_35[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_10          │ (None, 1, 64)     │          0 │ dense_36[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_57 (Conv1D)  │ (None, 128, 64)   │        384 │ lambda_46[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_16         │ (None, 128, 64)   │          0 │ activation_46[0]… │
# │ (Multiply)          │                   │            │ reshape_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 64)   │        256 │ conv1d_57[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 128, 64)   │          0 │ multiply_16[0][0… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_47       │ (None, 128, 64)   │          0 │ add_14[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_21    │ (None, 64, 64)    │          0 │ activation_47[0]… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_39          │ (None, 64, 64)    │          0 │ max_pooling1d_21… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_58 (Conv1D)  │ (None, 64, 128)   │     40,960 │ dropout_39[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 128)   │        512 │ conv1d_58[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_48       │ (None, 64, 128)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_59 (Conv1D)  │ (None, 64, 128)   │     81,920 │ activation_48[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 128)   │        512 │ conv1d_59[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_49       │ (None, 64, 128)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_49[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_37 (Dense)    │ (None, 16)        │      2,064 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_38 (Dense)    │ (None, 128)       │      2,176 │ dense_37[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_11          │ (None, 1, 128)    │          0 │ dense_38[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_60 (Conv1D)  │ (None, 64, 128)   │      8,192 │ dropout_39[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_17         │ (None, 64, 128)   │          0 │ activation_49[0]… │
# │ (Multiply)          │                   │            │ reshape_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 128)   │        512 │ conv1d_60[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 64, 128)   │          0 │ multiply_17[0][0… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_50       │ (None, 64, 128)   │          0 │ add_15[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_22    │ (None, 32, 128)   │          0 │ activation_50[0]… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_40          │ (None, 32, 128)   │          0 │ max_pooling1d_22… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_61 (Conv1D)  │ (None, 32, 256)   │    163,840 │ dropout_40[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 256)   │      1,024 │ conv1d_61[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_51       │ (None, 32, 256)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_62 (Conv1D)  │ (None, 32, 256)   │    327,680 │ activation_51[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 256)   │      1,024 │ conv1d_62[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_52       │ (None, 32, 256)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ activation_52[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_39 (Dense)    │ (None, 32)        │      8,224 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_40 (Dense)    │ (None, 256)       │      8,448 │ dense_39[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_12          │ (None, 1, 256)    │          0 │ dense_40[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_63 (Conv1D)  │ (None, 32, 256)   │     32,768 │ dropout_40[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_18         │ (None, 32, 256)   │          0 │ activation_52[0]… │
# │ (Multiply)          │                   │            │ reshape_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 256)   │      1,024 │ conv1d_63[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 32, 256)   │          0 │ multiply_18[0][0… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_53       │ (None, 32, 256)   │          0 │ add_16[0][0]      │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_23    │ (None, 16, 256)   │          0 │ activation_53[0]… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_41          │ (None, 16, 256)   │          0 │ max_pooling1d_23… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_41 (Dense)    │ (None, 16, 128)   │     32,896 │ dropout_41[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_42 (Dense)    │ (None, 16, 256)   │     33,024 │ dense_41[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling1d       │ (None, 32, 256)   │          0 │ dense_42[0][0]    │
# │ (UpSampling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_64 (Conv1D)  │ (None, 32, 256)   │    327,680 │ up_sampling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 32, 256)   │        512 │ conv1d_64[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_54       │ (None, 32, 256)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_48 (Lambda)  │ [(None, 16, 256), │          0 │ activation_54[0]… │
# │                     │ (None, 16, 256)]  │            │ dropout_41[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 16, 512)   │          0 │ lambda_48[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_48[0][1]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_65 (Conv1D)  │ (None, 16, 256)   │    655,360 │ concatenate_12[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 16, 256)   │        512 │ conv1d_65[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_55       │ (None, 16, 256)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ activation_55[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_43 (Dense)    │ (None, 32)        │      8,224 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_44 (Dense)    │ (None, 256)       │      8,448 │ dense_43[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_13          │ (None, 1, 256)    │          0 │ dense_44[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_19         │ (None, 16, 256)   │          0 │ activation_55[0]… │
# │ (Multiply)          │                   │            │ reshape_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_42          │ (None, 16, 256)   │          0 │ multiply_19[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_70 (Conv1D)  │ (None, 128, 64)   │        448 │ lambda_46[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling1d_1     │ (None, 32, 256)   │          0 │ dropout_42[0][0]  │
# │ (UpSampling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_71 (Conv1D)  │ (None, 128, 64)   │     12,352 │ conv1d_70[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_72 (Conv1D)  │ (None, 128, 64)   │     12,352 │ conv1d_70[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_66 (Conv1D)  │ (None, 32, 128)   │    163,840 │ up_sampling1d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_22         │ (None, 128, 64)   │          0 │ conv1d_71[0][0],  │
# │ (Multiply)          │                   │            │ conv1d_72[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 32, 128)   │        256 │ conv1d_66[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_45          │ (None, 128, 64)   │          0 │ multiply_22[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_56       │ (None, 32, 128)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_73 (Conv1D)  │ (None, 128, 64)   │      4,160 │ dropout_45[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_49 (Lambda)  │ [(None, 32, 128), │          0 │ activation_56[0]… │
# │                     │ (None, 32, 128)]  │            │ dropout_40[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 128, 64)   │          0 │ conv1d_70[0][0],  │
# │                     │                   │            │ conv1d_73[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 32, 256)   │          0 │ lambda_49[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_49[0][1]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 64)   │        128 │ add_17[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_67 (Conv1D)  │ (None, 32, 128)   │    163,840 │ concatenate_13[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_74 (Conv1D)  │ (None, 128, 64)   │     12,352 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_75 (Conv1D)  │ (None, 128, 64)   │     12,352 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 32, 128)   │        256 │ conv1d_67[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_23         │ (None, 128, 64)   │          0 │ conv1d_74[0][0],  │
# │ (Multiply)          │                   │            │ conv1d_75[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_57       │ (None, 32, 128)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_46          │ (None, 128, 64)   │          0 │ multiply_23[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_57[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_76 (Conv1D)  │ (None, 128, 64)   │      4,160 │ dropout_46[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_45 (Dense)    │ (None, 16)        │      2,064 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 128, 64)   │          0 │ layer_normalizat… │
# │                     │                   │            │ conv1d_76[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_46 (Dense)    │ (None, 128)       │      2,176 │ dense_45[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 64)   │        128 │ add_18[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_14          │ (None, 1, 128)    │          0 │ dense_46[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_77 (Conv1D)  │ (None, 128, 64)   │     12,352 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_78 (Conv1D)  │ (None, 128, 64)   │     12,352 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_20         │ (None, 32, 128)   │          0 │ activation_57[0]… │
# │ (Multiply)          │                   │            │ reshape_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_24         │ (None, 128, 64)   │          0 │ conv1d_77[0][0],  │
# │ (Multiply)          │                   │            │ conv1d_78[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_43          │ (None, 32, 128)   │          0 │ multiply_20[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_47          │ (None, 128, 64)   │          0 │ multiply_24[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling1d_2     │ (None, 64, 128)   │          0 │ dropout_43[0][0]  │
# │ (UpSampling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_79 (Conv1D)  │ (None, 128, 64)   │      4,160 │ dropout_47[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_68 (Conv1D)  │ (None, 64, 64)    │     40,960 │ up_sampling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 128, 64)   │          0 │ layer_normalizat… │
# │                     │                   │            │ conv1d_79[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ conv1d_68[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 64)   │        128 │ add_19[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_58       │ (None, 64, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_80 (Conv1D)  │ (None, 128, 64)   │     12,352 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_81 (Conv1D)  │ (None, 128, 64)   │     12,352 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_50 (Lambda)  │ [(None, 64, 64),  │          0 │ activation_58[0]… │
# │                     │ (None, 64, 64)]   │            │ dropout_39[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_25         │ (None, 128, 64)   │          0 │ conv1d_80[0][0],  │
# │ (Multiply)          │                   │            │ conv1d_81[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 64, 128)   │          0 │ lambda_50[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_50[0][1]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_48          │ (None, 128, 64)   │          0 │ multiply_25[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_69 (Conv1D)  │ (None, 64, 64)    │     40,960 │ concatenate_14[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_82 (Conv1D)  │ (None, 128, 64)   │      4,160 │ dropout_48[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 64)    │        128 │ conv1d_69[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 128, 64)   │          0 │ layer_normalizat… │
# │                     │                   │            │ conv1d_82[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_47 (Lambda)  │ (None, 128, 55)   │          0 │ input_layer_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_59       │ (None, 64, 64)    │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 64)   │        128 │ add_20[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_86 (Conv1D)  │ (None, 128, 64)   │     10,560 │ lambda_47[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ activation_59[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_83 (Conv1D)  │ (None, 128, 64)   │     12,352 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_84 (Conv1D)  │ (None, 128, 64)   │     12,352 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 64)   │        256 │ conv1d_86[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_47 (Dense)    │ (None, 8)         │        520 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_26         │ (None, 128, 64)   │          0 │ conv1d_83[0][0],  │
# │ (Multiply)          │                   │            │ conv1d_84[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_60       │ (None, 128, 64)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_48 (Dense)    │ (None, 64)        │        576 │ dense_47[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_49          │ (None, 128, 64)   │          0 │ multiply_26[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_24    │ (None, 64, 64)    │          0 │ activation_60[0]… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_15          │ (None, 1, 64)     │          0 │ dense_48[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_85 (Conv1D)  │ (None, 128, 64)   │      4,160 │ dropout_49[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_50          │ (None, 64, 64)    │          0 │ max_pooling1d_24… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_21         │ (None, 64, 64)    │          0 │ activation_59[0]… │
# │ (Multiply)          │                   │            │ reshape_15[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 128, 64)   │          0 │ layer_normalizat… │
# │                     │                   │            │ conv1d_85[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_87 (Conv1D)  │ (None, 64, 128)   │     24,576 │ dropout_50[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 55)        │          0 │ lambda_47[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_44          │ (None, 64, 64)    │          0 │ multiply_21[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 128, 64)   │        128 │ add_21[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 128)   │        512 │ conv1d_87[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_49 (Dense)    │ (None, 16)        │        896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_51 (Lambda)  │ [(None, 64, 64),  │          0 │ dropout_44[0][0], │
# │                     │ (None, 64, 64)]   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_61       │ (None, 64, 128)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tof_gate_dense      │ (None, 1)         │         17 │ dense_49[0][0]    │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 64, 128)   │          0 │ lambda_51[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_51[0][1]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_27         │ (None, 64, 128)   │          0 │ activation_61[0]… │
# │ (Multiply)          │                   │            │ tof_gate_dense[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_52 (Lambda)  │ [(None, 64, 128), │          0 │ concatenate_15[0… │
# │                     │ (None, 64, 128)]  │            │ multiply_27[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 64, 256)   │          0 │ lambda_52[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_52[0][1]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_noise_1    │ (None, 64, 256)   │          0 │ concatenate_16[0… │
# │ (GaussianNoise)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_2     │ (None, 64, 256)   │    394,240 │ concatenate_16[0… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_3     │ (None, 64, 256)   │    296,448 │ concatenate_16[0… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_50 (Dense)    │ (None, 64, 16)    │      4,112 │ gaussian_noise_1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 64, 528)   │          0 │ bidirectional_2[… │
# │ (Concatenate)       │                   │            │ bidirectional_3[… │
# │                     │                   │            │ dense_50[0][0]    │
# ...
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_106 (Dense)   │ (None, 64)        │     32,832 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_107 (Dense)   │ (None, 512)       │     33,280 │ dense_106[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_37          │ (None, 1, 512)    │          0 │ dense_107[0][0]   │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_51         │ (None, 16, 512)   │          0 │ activation_123[0… │
# │ (Multiply)          │                   │            │ reshape_37[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_80          │ (None, 16, 512)   │          0 │ multiply_51[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling1d_13    │ (None, 32, 512)   │          0 │ dropout_80[0][0]  │
# │ (UpSampling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_144 (Conv1D) │ (None, 32, 256)   │    655,360 │ up_sampling1d_13… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 32, 256)   │        512 │ conv1d_144[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_124      │ (None, 32, 256)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_74 (Lambda)  │ [(None, 32, 256), │          0 │ activation_124[0… │
# │                     │ (None, 32, 256)]  │            │ dropout_74[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_30      │ (None, 32, 512)   │          0 │ lambda_74[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_74[0][1]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_145 (Conv1D) │ (None, 32, 256)   │    655,360 │ concatenate_30[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 32, 256)   │        512 │ conv1d_145[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_125      │ (None, 32, 256)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ activation_125[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_108 (Dense)   │ (None, 32)        │      8,224 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_109 (Dense)   │ (None, 256)       │      8,448 │ dense_108[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_38          │ (None, 1, 256)    │          0 │ dense_109[0][0]   │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_52         │ (None, 32, 256)   │          0 │ activation_125[0… │
# │ (Multiply)          │                   │            │ reshape_38[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_81          │ (None, 32, 256)   │          0 │ multiply_52[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling1d_14    │ (None, 64, 256)   │          0 │ dropout_81[0][0]  │
# │ (UpSampling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_146 (Conv1D) │ (None, 64, 128)   │    163,840 │ up_sampling1d_14… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ conv1d_146[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_126      │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_75 (Lambda)  │ [(None, 64, 128), │          0 │ activation_126[0… │
# │                     │ (None, 64, 128)]  │            │ dropout_73[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_70 (Lambda)  │ (None, 128, 55)   │          0 │ input_layer_8[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_31      │ (None, 64, 256)   │          0 │ lambda_75[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_75[0][1]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_148 (Conv1D) │ (None, 128, 64)   │     10,560 │ lambda_70[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_147 (Conv1D) │ (None, 64, 128)   │    163,840 │ concatenate_31[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 64)   │        256 │ conv1d_148[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 64, 128)   │        256 │ conv1d_147[0][0]  │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_128      │ (None, 128, 64)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_127      │ (None, 64, 128)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_37    │ (None, 64, 64)    │          0 │ activation_128[0… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_127[0… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_83          │ (None, 64, 64)    │          0 │ max_pooling1d_37… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_110 (Dense)   │ (None, 16)        │      2,064 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_149 (Conv1D) │ (None, 64, 128)   │     24,576 │ dropout_83[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_111 (Dense)   │ (None, 128)       │      2,176 │ dense_110[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 128)   │        512 │ conv1d_149[0][0]  │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_39          │ (None, 1, 128)    │          0 │ dense_111[0][0]   │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_129      │ (None, 64, 128)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_53         │ (None, 64, 128)   │          0 │ activation_127[0… │
# │ (Multiply)          │                   │            │ reshape_39[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_38    │ (None, 32, 128)   │          0 │ activation_129[0… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_82          │ (None, 64, 128)   │          0 │ multiply_53[0][0] │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_84          │ (None, 32, 128)   │          0 │ max_pooling1d_38… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_150 (Conv1D) │ (None, 64, 128)   │     16,512 │ dropout_82[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_151 (Conv1D) │ (None, 32, 128)   │     16,512 │ dropout_84[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_76 (Lambda)  │ [(None, 32, 128), │          0 │ conv1d_150[0][0], │
# │                     │ (None, 32, 128)]  │            │ conv1d_151[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_32      │ (None, 32, 256)   │          0 │ lambda_76[0][0],  │
# │ (Concatenate)       │                   │            │ lambda_76[0][1]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_noise_3    │ (None, 32, 256)   │          0 │ concatenate_32[0… │
# │ (GaussianNoise)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_6     │ (None, 32, 256)   │    394,240 │ concatenate_32[0… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bidirectional_7     │ (None, 32, 256)   │    296,448 │ concatenate_32[0… │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_112 (Dense)   │ (None, 32, 16)    │      4,112 │ gaussian_noise_3… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_33      │ (None, 32, 528)   │          0 │ bidirectional_6[… │
# │ (Concatenate)       │                   │            │ bidirectional_7[… │
# │                     │                   │            │ dense_112[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_85          │ (None, 32, 528)   │          0 │ concatenate_33[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_113 (Dense)   │ (None, 32, 1)     │        529 │ dropout_85[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_77 (Lambda)  │ (None, 32)        │          0 │ dense_113[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_130      │ (None, 32)        │          0 │ lambda_77[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_78 (Lambda)  │ (None, 32, 1)     │          0 │ activation_130[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_54         │ (None, 32, 528)   │          0 │ dropout_85[0][0], │
# │ (Multiply)          │                   │            │ lambda_78[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_79 (Lambda)  │ (None, 528)       │          0 │ multiply_54[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_114 (Dense)   │ (None, 256)       │    135,168 │ lambda_79[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_114[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_131      │ (None, 256)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_86          │ (None, 256)       │          0 │ activation_131[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_115 (Dense)   │ (None, 128)       │     32,768 │ dropout_86[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_115[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_132      │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_87          │ (None, 128)       │          0 │ activation_132[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_88          │ (None, 128)       │          0 │ dropout_87[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ main_output (Dense) │ (None, 18)        │      2,322 │ dropout_88[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tof_gate (Dense)    │ (None, 1)         │        129 │ dropout_88[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 139,746,900 (533.09 MB)
#  Trainable params: 139,721,940 (533.00 MB)
#  Non-trainable params: 24,960 (97.50 KB)
# Performing forward pass for Hyper UNet...
# ❌ ERROR: Model 'Hyper UNet' failed to build or run.
#
# --- Model architecture testing complete. ---
# Traceback (most recent call last):
#   File "/tmp/ipykernel_4081569/3681017911.py", line 58, in <module>
#     output = model(sample_input)
#                    ^^^^^^^^^^^^
# NameError: name 'sample_input' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
